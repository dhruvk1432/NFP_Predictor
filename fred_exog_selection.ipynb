# %% [markdown]
# # FRED Exogenous Feature Selection
#
# Analyze all FRED exogenous features (levels + MoM diffs + z-scores) using VIF to determine which transformations provide unique explanatory power and prune multicollinearity.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 200)

# %% [markdown]
# ## 1. Load 2025-12 Snapshot & Pivot to Wide Format

# %%
snap_path = Path('data/Exogenous_data/exogenous_fred_data/decades/2020s/2025/2025-12.parquet')
df = pd.read_parquet(snap_path)
print(f"Raw shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Unique series: {df['series_name'].nunique()}")
print(f"\nAll series names:")
for s in sorted(df['series_name'].unique()):
    print(f"  {s}")
# Out:
# Raw shape: (3528490, 6)
# Columns: ['date', 'release_date', 'series_code', 'snapshot_date', 'series_name', 'value']
# Unique series: 8658
#
# All series names:
#   CCNSA_max_spike
#   CCNSA_max_spike_chg_12m
#   CCNSA_max_spike_chg_12m_lag_12m
#   CCNSA_max_spike_chg_12m_lag_18m
#   CCNSA_max_spike_chg_12m_lag_1m
#   CCNSA_max_spike_chg_12m_lag_3m
#   CCNSA_max_spike_chg_12m_lag_6m
#   CCNSA_max_spike_chg_3m
#   CCNSA_max_spike_chg_3m_lag_12m
#   CCNSA_max_spike_chg_3m_lag_18m
#   CCNSA_max_spike_chg_3m_lag_1m
#   CCNSA_max_spike_chg_3m_lag_3m
#   CCNSA_max_spike_chg_3m_lag_6m
#   CCNSA_max_spike_chg_6m
#   CCNSA_max_spike_chg_6m_lag_12m
#   CCNSA_max_spike_chg_6m_lag_18m
#   CCNSA_max_spike_chg_6m_lag_1m
#   CCNSA_max_spike_chg_6m_lag_3m
#   CCNSA_max_spike_chg_6m_lag_6m
#   CCNSA_max_spike_diff
#   CCNSA_max_spike_diff_lag_12m
#   CCNSA_max_spike_diff_lag_18m
#   CCNSA_max_spike_diff_lag_1m
#   CCNSA_max_spike_diff_lag_3m
#   CCNSA_max_spike_diff_lag_6m
#   CCNSA_max_spike_diff_zscore_12m
#   CCNSA_max_spike_diff_zscore_12m_lag_12m
#   CCNSA_max_spike_diff_zscore_12m_lag_18m
#   CCNSA_max_spike_diff_zscore_12m_lag_1m
#   CCNSA_max_spike_diff_zscore_12m_lag_3m
#   CCNSA_max_spike_diff_zscore_12m_lag_6m
#   CCNSA_max_spike_diff_zscore_3m
#   CCNSA_max_spike_diff_zscore_3m_lag_12m
#   CCNSA_max_spike_diff_zscore_3m_lag_18m
#   CCNSA_max_spike_diff_zscore_3m_lag_1m
#   CCNSA_max_spike_diff_zscore_3m_lag_3m
#   CCNSA_max_spike_diff_zscore_3m_lag_6m
#   CCNSA_max_spike_lag_12m
#   CCNSA_max_spike_lag_18m
#   CCNSA_max_spike_lag_1m
#   CCNSA_max_spike_lag_3m
#   CCNSA_max_spike_lag_6m
#   CCNSA_max_spike_pct_chg
#   CCNSA_max_spike_pct_chg_lag_12m
#   CCNSA_max_spike_pct_chg_lag_18m
#   CCNSA_max_spike_pct_chg_lag_1m
#   CCNSA_max_spike_pct_chg_lag_3m
#   CCNSA_max_spike_pct_chg_lag_6m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_max_spike_pct_chg_rolling_std_6m
#   CCNSA_max_spike_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_max_spike_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_max_spike_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_max_spike_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_max_spike_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_max_spike_pct_chg_zscore_12m
#   CCNSA_max_spike_pct_chg_zscore_12m_lag_12m
#   CCNSA_max_spike_pct_chg_zscore_12m_lag_18m
#   CCNSA_max_spike_pct_chg_zscore_12m_lag_1m
#   CCNSA_max_spike_pct_chg_zscore_12m_lag_3m
#   CCNSA_max_spike_pct_chg_zscore_12m_lag_6m
#   CCNSA_max_spike_pct_chg_zscore_3m
#   CCNSA_max_spike_pct_chg_zscore_3m_lag_12m
#   CCNSA_max_spike_pct_chg_zscore_3m_lag_18m
#   CCNSA_max_spike_pct_chg_zscore_3m_lag_1m
#   CCNSA_max_spike_pct_chg_zscore_3m_lag_3m
#   CCNSA_max_spike_pct_chg_zscore_3m_lag_6m
#   CCNSA_max_spike_rolling_mean_3m
#   CCNSA_max_spike_rolling_mean_3m_lag_12m
#   CCNSA_max_spike_rolling_mean_3m_lag_18m
#   CCNSA_max_spike_rolling_mean_3m_lag_1m
#   CCNSA_max_spike_rolling_mean_3m_lag_3m
#   CCNSA_max_spike_rolling_mean_3m_lag_6m
#   CCNSA_max_spike_rolling_std_6m
#   CCNSA_max_spike_rolling_std_6m_lag_12m
#   CCNSA_max_spike_rolling_std_6m_lag_18m
#   CCNSA_max_spike_rolling_std_6m_lag_1m
#   CCNSA_max_spike_rolling_std_6m_lag_3m
#   CCNSA_max_spike_rolling_std_6m_lag_6m
#   CCNSA_max_spike_symlog
#   CCNSA_max_spike_symlog_chg_12m
#   CCNSA_max_spike_symlog_chg_12m_lag_12m
#   CCNSA_max_spike_symlog_chg_12m_lag_18m
#   CCNSA_max_spike_symlog_chg_12m_lag_1m
#   CCNSA_max_spike_symlog_chg_12m_lag_3m
#   CCNSA_max_spike_symlog_chg_12m_lag_6m
#   CCNSA_max_spike_symlog_chg_3m
#   CCNSA_max_spike_symlog_chg_3m_lag_12m
#   CCNSA_max_spike_symlog_chg_3m_lag_18m
#   CCNSA_max_spike_symlog_chg_3m_lag_1m
#   CCNSA_max_spike_symlog_chg_3m_lag_3m
#   CCNSA_max_spike_symlog_chg_3m_lag_6m
#   CCNSA_max_spike_symlog_chg_6m
#   CCNSA_max_spike_symlog_chg_6m_lag_12m
#   CCNSA_max_spike_symlog_chg_6m_lag_18m
#   CCNSA_max_spike_symlog_chg_6m_lag_1m
#   CCNSA_max_spike_symlog_chg_6m_lag_3m
#   CCNSA_max_spike_symlog_chg_6m_lag_6m
#   CCNSA_max_spike_symlog_diff
#   CCNSA_max_spike_symlog_diff_lag_12m
#   CCNSA_max_spike_symlog_diff_lag_18m
#   CCNSA_max_spike_symlog_diff_lag_1m
#   CCNSA_max_spike_symlog_diff_lag_3m
#   CCNSA_max_spike_symlog_diff_lag_6m
#   CCNSA_max_spike_symlog_diff_zscore_12m
#   CCNSA_max_spike_symlog_diff_zscore_12m_lag_12m
#   CCNSA_max_spike_symlog_diff_zscore_12m_lag_18m
#   CCNSA_max_spike_symlog_diff_zscore_12m_lag_1m
#   CCNSA_max_spike_symlog_diff_zscore_12m_lag_3m
#   CCNSA_max_spike_symlog_diff_zscore_12m_lag_6m
#   CCNSA_max_spike_symlog_diff_zscore_3m
#   CCNSA_max_spike_symlog_diff_zscore_3m_lag_12m
#   CCNSA_max_spike_symlog_diff_zscore_3m_lag_18m
#   CCNSA_max_spike_symlog_diff_zscore_3m_lag_1m
#   CCNSA_max_spike_symlog_diff_zscore_3m_lag_3m
#   CCNSA_max_spike_symlog_diff_zscore_3m_lag_6m
#   CCNSA_max_spike_symlog_lag_12m
#   CCNSA_max_spike_symlog_lag_18m
#   CCNSA_max_spike_symlog_lag_1m
#   CCNSA_max_spike_symlog_lag_3m
#   CCNSA_max_spike_symlog_lag_6m
#   CCNSA_max_spike_symlog_pct_chg
#   CCNSA_max_spike_symlog_pct_chg_lag_12m
#   CCNSA_max_spike_symlog_pct_chg_lag_18m
#   CCNSA_max_spike_symlog_pct_chg_lag_1m
#   CCNSA_max_spike_symlog_pct_chg_lag_3m
#   CCNSA_max_spike_symlog_pct_chg_lag_6m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_12m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_18m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_1m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_3m
#   CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_6m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_12m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_18m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_1m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_3m
#   CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_6m
#   CCNSA_max_spike_symlog_rolling_mean_3m
#   CCNSA_max_spike_symlog_rolling_mean_3m_lag_12m
#   CCNSA_max_spike_symlog_rolling_mean_3m_lag_18m
#   CCNSA_max_spike_symlog_rolling_mean_3m_lag_1m
#   CCNSA_max_spike_symlog_rolling_mean_3m_lag_3m
#   CCNSA_max_spike_symlog_rolling_mean_3m_lag_6m
#   CCNSA_max_spike_symlog_rolling_std_6m
#   CCNSA_max_spike_symlog_rolling_std_6m_lag_12m
#   CCNSA_max_spike_symlog_rolling_std_6m_lag_18m
#   CCNSA_max_spike_symlog_rolling_std_6m_lag_1m
#   CCNSA_max_spike_symlog_rolling_std_6m_lag_3m
#   CCNSA_max_spike_symlog_rolling_std_6m_lag_6m
#   CCNSA_max_spike_symlog_zscore_12m
#   CCNSA_max_spike_symlog_zscore_12m_lag_12m
#   CCNSA_max_spike_symlog_zscore_12m_lag_18m
#   CCNSA_max_spike_symlog_zscore_12m_lag_1m
#   CCNSA_max_spike_symlog_zscore_12m_lag_3m
#   CCNSA_max_spike_symlog_zscore_12m_lag_6m
#   CCNSA_max_spike_symlog_zscore_3m
#   CCNSA_max_spike_symlog_zscore_3m_lag_12m
#   CCNSA_max_spike_symlog_zscore_3m_lag_18m
#   CCNSA_max_spike_symlog_zscore_3m_lag_1m
#   CCNSA_max_spike_symlog_zscore_3m_lag_3m
#   CCNSA_max_spike_symlog_zscore_3m_lag_6m
#   CCNSA_max_spike_zscore_12m
#   CCNSA_max_spike_zscore_12m_lag_12m
#   CCNSA_max_spike_zscore_12m_lag_18m
#   CCNSA_max_spike_zscore_12m_lag_1m
#   CCNSA_max_spike_zscore_12m_lag_3m
#   CCNSA_max_spike_zscore_12m_lag_6m
#   CCNSA_max_spike_zscore_3m
#   CCNSA_max_spike_zscore_3m_lag_12m
#   CCNSA_max_spike_zscore_3m_lag_18m
#   CCNSA_max_spike_zscore_3m_lag_1m
#   CCNSA_max_spike_zscore_3m_lag_3m
#   CCNSA_max_spike_zscore_3m_lag_6m
#   CCNSA_monthly_avg
#   CCNSA_monthly_avg_chg_12m
#   CCNSA_monthly_avg_chg_12m_lag_12m
#   CCNSA_monthly_avg_chg_12m_lag_18m
#   CCNSA_monthly_avg_chg_12m_lag_1m
#   CCNSA_monthly_avg_chg_12m_lag_3m
#   CCNSA_monthly_avg_chg_12m_lag_6m
#   CCNSA_monthly_avg_chg_3m
#   CCNSA_monthly_avg_chg_3m_lag_12m
#   CCNSA_monthly_avg_chg_3m_lag_18m
#   CCNSA_monthly_avg_chg_3m_lag_1m
#   CCNSA_monthly_avg_chg_3m_lag_3m
#   CCNSA_monthly_avg_chg_3m_lag_6m
#   CCNSA_monthly_avg_chg_6m
#   CCNSA_monthly_avg_chg_6m_lag_12m
#   CCNSA_monthly_avg_chg_6m_lag_18m
#   CCNSA_monthly_avg_chg_6m_lag_1m
#   CCNSA_monthly_avg_chg_6m_lag_3m
#   CCNSA_monthly_avg_chg_6m_lag_6m
#   CCNSA_monthly_avg_diff
#   CCNSA_monthly_avg_diff_lag_12m
#   CCNSA_monthly_avg_diff_lag_18m
#   CCNSA_monthly_avg_diff_lag_1m
#   CCNSA_monthly_avg_diff_lag_3m
#   CCNSA_monthly_avg_diff_lag_6m
#   CCNSA_monthly_avg_diff_zscore_12m
#   CCNSA_monthly_avg_diff_zscore_12m_lag_12m
#   CCNSA_monthly_avg_diff_zscore_12m_lag_18m
#   CCNSA_monthly_avg_diff_zscore_12m_lag_1m
#   CCNSA_monthly_avg_diff_zscore_12m_lag_3m
#   CCNSA_monthly_avg_diff_zscore_12m_lag_6m
#   CCNSA_monthly_avg_diff_zscore_3m
#   CCNSA_monthly_avg_diff_zscore_3m_lag_12m
#   CCNSA_monthly_avg_diff_zscore_3m_lag_18m
#   CCNSA_monthly_avg_diff_zscore_3m_lag_1m
#   CCNSA_monthly_avg_diff_zscore_3m_lag_3m
#   CCNSA_monthly_avg_diff_zscore_3m_lag_6m
#   CCNSA_monthly_avg_lag_12m
#   CCNSA_monthly_avg_lag_18m
#   CCNSA_monthly_avg_lag_1m
#   CCNSA_monthly_avg_lag_3m
#   CCNSA_monthly_avg_lag_6m
#   CCNSA_monthly_avg_pct_chg
#   CCNSA_monthly_avg_pct_chg_lag_12m
#   CCNSA_monthly_avg_pct_chg_lag_18m
#   CCNSA_monthly_avg_pct_chg_lag_1m
#   CCNSA_monthly_avg_pct_chg_lag_3m
#   CCNSA_monthly_avg_pct_chg_lag_6m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_monthly_avg_pct_chg_zscore_12m
#   CCNSA_monthly_avg_pct_chg_zscore_12m_lag_12m
#   CCNSA_monthly_avg_pct_chg_zscore_12m_lag_18m
#   CCNSA_monthly_avg_pct_chg_zscore_12m_lag_1m
#   CCNSA_monthly_avg_pct_chg_zscore_12m_lag_3m
#   CCNSA_monthly_avg_pct_chg_zscore_12m_lag_6m
#   CCNSA_monthly_avg_pct_chg_zscore_3m
#   CCNSA_monthly_avg_pct_chg_zscore_3m_lag_12m
#   CCNSA_monthly_avg_pct_chg_zscore_3m_lag_18m
#   CCNSA_monthly_avg_pct_chg_zscore_3m_lag_1m
#   CCNSA_monthly_avg_pct_chg_zscore_3m_lag_3m
#   CCNSA_monthly_avg_pct_chg_zscore_3m_lag_6m
#   CCNSA_monthly_avg_rolling_mean_3m
#   CCNSA_monthly_avg_rolling_mean_3m_lag_12m
#   CCNSA_monthly_avg_rolling_mean_3m_lag_18m
#   CCNSA_monthly_avg_rolling_mean_3m_lag_1m
#   CCNSA_monthly_avg_rolling_mean_3m_lag_3m
#   CCNSA_monthly_avg_rolling_mean_3m_lag_6m
#   CCNSA_monthly_avg_rolling_std_6m
#   CCNSA_monthly_avg_rolling_std_6m_lag_12m
#   CCNSA_monthly_avg_rolling_std_6m_lag_18m
#   CCNSA_monthly_avg_rolling_std_6m_lag_1m
#   CCNSA_monthly_avg_rolling_std_6m_lag_3m
#   CCNSA_monthly_avg_rolling_std_6m_lag_6m
#   CCNSA_monthly_avg_symlog
#   CCNSA_monthly_avg_symlog_chg_12m
#   CCNSA_monthly_avg_symlog_chg_12m_lag_12m
#   CCNSA_monthly_avg_symlog_chg_12m_lag_18m
#   CCNSA_monthly_avg_symlog_chg_12m_lag_1m
#   CCNSA_monthly_avg_symlog_chg_12m_lag_3m
#   CCNSA_monthly_avg_symlog_chg_12m_lag_6m
#   CCNSA_monthly_avg_symlog_chg_3m
#   CCNSA_monthly_avg_symlog_chg_3m_lag_12m
#   CCNSA_monthly_avg_symlog_chg_3m_lag_18m
#   CCNSA_monthly_avg_symlog_chg_3m_lag_1m
#   CCNSA_monthly_avg_symlog_chg_3m_lag_3m
#   CCNSA_monthly_avg_symlog_chg_3m_lag_6m
#   CCNSA_monthly_avg_symlog_chg_6m
#   CCNSA_monthly_avg_symlog_chg_6m_lag_12m
#   CCNSA_monthly_avg_symlog_chg_6m_lag_18m
#   CCNSA_monthly_avg_symlog_chg_6m_lag_1m
#   CCNSA_monthly_avg_symlog_chg_6m_lag_3m
#   CCNSA_monthly_avg_symlog_chg_6m_lag_6m
#   CCNSA_monthly_avg_symlog_diff
#   CCNSA_monthly_avg_symlog_diff_lag_12m
#   CCNSA_monthly_avg_symlog_diff_lag_18m
#   CCNSA_monthly_avg_symlog_diff_lag_1m
#   CCNSA_monthly_avg_symlog_diff_lag_3m
#   CCNSA_monthly_avg_symlog_diff_lag_6m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m_lag_12m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m_lag_18m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m_lag_1m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m_lag_3m
#   CCNSA_monthly_avg_symlog_diff_zscore_12m_lag_6m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m_lag_12m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m_lag_18m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m_lag_1m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m_lag_3m
#   CCNSA_monthly_avg_symlog_diff_zscore_3m_lag_6m
#   CCNSA_monthly_avg_symlog_lag_12m
#   CCNSA_monthly_avg_symlog_lag_18m
#   CCNSA_monthly_avg_symlog_lag_1m
#   CCNSA_monthly_avg_symlog_lag_3m
#   CCNSA_monthly_avg_symlog_lag_6m
#   CCNSA_monthly_avg_symlog_pct_chg
#   CCNSA_monthly_avg_symlog_pct_chg_lag_12m
#   CCNSA_monthly_avg_symlog_pct_chg_lag_18m
#   CCNSA_monthly_avg_symlog_pct_chg_lag_1m
#   CCNSA_monthly_avg_symlog_pct_chg_lag_3m
#   CCNSA_monthly_avg_symlog_pct_chg_lag_6m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_12m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_18m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_1m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_3m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_6m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_12m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_18m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_1m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_3m
#   CCNSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_6m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m_lag_12m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m_lag_18m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m_lag_1m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m_lag_3m
#   CCNSA_monthly_avg_symlog_rolling_mean_3m_lag_6m
#   CCNSA_monthly_avg_symlog_rolling_std_6m
#   CCNSA_monthly_avg_symlog_rolling_std_6m_lag_12m
#   CCNSA_monthly_avg_symlog_rolling_std_6m_lag_18m
#   CCNSA_monthly_avg_symlog_rolling_std_6m_lag_1m
#   CCNSA_monthly_avg_symlog_rolling_std_6m_lag_3m
#   CCNSA_monthly_avg_symlog_rolling_std_6m_lag_6m
#   CCNSA_monthly_avg_symlog_zscore_12m
#   CCNSA_monthly_avg_symlog_zscore_12m_lag_12m
#   CCNSA_monthly_avg_symlog_zscore_12m_lag_18m
#   CCNSA_monthly_avg_symlog_zscore_12m_lag_1m
#   CCNSA_monthly_avg_symlog_zscore_12m_lag_3m
#   CCNSA_monthly_avg_symlog_zscore_12m_lag_6m
#   CCNSA_monthly_avg_symlog_zscore_3m
#   CCNSA_monthly_avg_symlog_zscore_3m_lag_12m
#   CCNSA_monthly_avg_symlog_zscore_3m_lag_18m
#   CCNSA_monthly_avg_symlog_zscore_3m_lag_1m
#   CCNSA_monthly_avg_symlog_zscore_3m_lag_3m
#   CCNSA_monthly_avg_symlog_zscore_3m_lag_6m
#   CCNSA_monthly_avg_zscore_12m
#   CCNSA_monthly_avg_zscore_12m_lag_12m
#   CCNSA_monthly_avg_zscore_12m_lag_18m
#   CCNSA_monthly_avg_zscore_12m_lag_1m
#   CCNSA_monthly_avg_zscore_12m_lag_3m
#   CCNSA_monthly_avg_zscore_12m_lag_6m
#   CCNSA_monthly_avg_zscore_3m
#   CCNSA_monthly_avg_zscore_3m_lag_12m
#   CCNSA_monthly_avg_zscore_3m_lag_18m
#   CCNSA_monthly_avg_zscore_3m_lag_1m
#   CCNSA_monthly_avg_zscore_3m_lag_3m
#   CCNSA_monthly_avg_zscore_3m_lag_6m
#   CCNSA_weeks_high
#   CCNSA_weeks_high_chg_12m
#   CCNSA_weeks_high_chg_12m_lag_12m
#   CCNSA_weeks_high_chg_12m_lag_18m
#   CCNSA_weeks_high_chg_12m_lag_1m
#   CCNSA_weeks_high_chg_12m_lag_3m
#   CCNSA_weeks_high_chg_12m_lag_6m
#   CCNSA_weeks_high_chg_3m
#   CCNSA_weeks_high_chg_3m_lag_12m
#   CCNSA_weeks_high_chg_3m_lag_18m
#   CCNSA_weeks_high_chg_3m_lag_1m
#   CCNSA_weeks_high_chg_3m_lag_3m
#   CCNSA_weeks_high_chg_3m_lag_6m
#   CCNSA_weeks_high_chg_6m
#   CCNSA_weeks_high_chg_6m_lag_12m
#   CCNSA_weeks_high_chg_6m_lag_18m
#   CCNSA_weeks_high_chg_6m_lag_1m
#   CCNSA_weeks_high_chg_6m_lag_3m
#   CCNSA_weeks_high_chg_6m_lag_6m
#   CCNSA_weeks_high_diff
#   CCNSA_weeks_high_diff_lag_12m
#   CCNSA_weeks_high_diff_lag_18m
#   CCNSA_weeks_high_diff_lag_1m
#   CCNSA_weeks_high_diff_lag_3m
#   CCNSA_weeks_high_diff_lag_6m
#   CCNSA_weeks_high_diff_zscore_12m
#   CCNSA_weeks_high_diff_zscore_12m_lag_12m
#   CCNSA_weeks_high_diff_zscore_12m_lag_18m
#   CCNSA_weeks_high_diff_zscore_12m_lag_1m
#   CCNSA_weeks_high_diff_zscore_12m_lag_3m
#   CCNSA_weeks_high_diff_zscore_12m_lag_6m
#   CCNSA_weeks_high_diff_zscore_3m
#   CCNSA_weeks_high_diff_zscore_3m_lag_12m
#   CCNSA_weeks_high_diff_zscore_3m_lag_18m
#   CCNSA_weeks_high_diff_zscore_3m_lag_1m
#   CCNSA_weeks_high_diff_zscore_3m_lag_3m
#   CCNSA_weeks_high_diff_zscore_3m_lag_6m
#   CCNSA_weeks_high_lag_12m
#   CCNSA_weeks_high_lag_18m
#   CCNSA_weeks_high_lag_1m
#   CCNSA_weeks_high_lag_3m
#   CCNSA_weeks_high_lag_6m
#   CCNSA_weeks_high_pct_chg
#   CCNSA_weeks_high_pct_chg_lag_12m
#   CCNSA_weeks_high_pct_chg_lag_18m
#   CCNSA_weeks_high_pct_chg_lag_1m
#   CCNSA_weeks_high_pct_chg_lag_3m
#   CCNSA_weeks_high_pct_chg_lag_6m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_weeks_high_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_weeks_high_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_weeks_high_pct_chg_zscore_12m
#   CCNSA_weeks_high_pct_chg_zscore_12m_lag_12m
#   CCNSA_weeks_high_pct_chg_zscore_12m_lag_18m
#   CCNSA_weeks_high_pct_chg_zscore_12m_lag_1m
#   CCNSA_weeks_high_pct_chg_zscore_12m_lag_3m
#   CCNSA_weeks_high_pct_chg_zscore_12m_lag_6m
#   CCNSA_weeks_high_pct_chg_zscore_3m
#   CCNSA_weeks_high_pct_chg_zscore_3m_lag_12m
#   CCNSA_weeks_high_pct_chg_zscore_3m_lag_18m
#   CCNSA_weeks_high_pct_chg_zscore_3m_lag_1m
#   CCNSA_weeks_high_pct_chg_zscore_3m_lag_3m
#   CCNSA_weeks_high_pct_chg_zscore_3m_lag_6m
#   CCNSA_weeks_high_rolling_mean_3m
#   CCNSA_weeks_high_rolling_mean_3m_lag_12m
#   CCNSA_weeks_high_rolling_mean_3m_lag_18m
#   CCNSA_weeks_high_rolling_mean_3m_lag_1m
#   CCNSA_weeks_high_rolling_mean_3m_lag_3m
#   CCNSA_weeks_high_rolling_mean_3m_lag_6m
#   CCNSA_weeks_high_rolling_std_6m
#   CCNSA_weeks_high_rolling_std_6m_lag_12m
#   CCNSA_weeks_high_rolling_std_6m_lag_18m
#   CCNSA_weeks_high_rolling_std_6m_lag_1m
#   CCNSA_weeks_high_rolling_std_6m_lag_3m
#   CCNSA_weeks_high_rolling_std_6m_lag_6m
#   CCNSA_weeks_high_symlog
#   CCNSA_weeks_high_symlog_chg_12m
#   CCNSA_weeks_high_symlog_chg_12m_lag_12m
#   CCNSA_weeks_high_symlog_chg_12m_lag_18m
#   CCNSA_weeks_high_symlog_chg_12m_lag_1m
#   CCNSA_weeks_high_symlog_chg_12m_lag_3m
#   CCNSA_weeks_high_symlog_chg_12m_lag_6m
#   CCNSA_weeks_high_symlog_chg_3m
#   CCNSA_weeks_high_symlog_chg_3m_lag_12m
#   CCNSA_weeks_high_symlog_chg_3m_lag_18m
#   CCNSA_weeks_high_symlog_chg_3m_lag_1m
#   CCNSA_weeks_high_symlog_chg_3m_lag_3m
#   CCNSA_weeks_high_symlog_chg_3m_lag_6m
#   CCNSA_weeks_high_symlog_chg_6m
#   CCNSA_weeks_high_symlog_chg_6m_lag_12m
#   CCNSA_weeks_high_symlog_chg_6m_lag_18m
#   CCNSA_weeks_high_symlog_chg_6m_lag_1m
#   CCNSA_weeks_high_symlog_chg_6m_lag_3m
#   CCNSA_weeks_high_symlog_chg_6m_lag_6m
#   CCNSA_weeks_high_symlog_diff
#   CCNSA_weeks_high_symlog_diff_lag_12m
#   CCNSA_weeks_high_symlog_diff_lag_18m
#   CCNSA_weeks_high_symlog_diff_lag_1m
#   CCNSA_weeks_high_symlog_diff_lag_3m
#   CCNSA_weeks_high_symlog_diff_lag_6m
#   CCNSA_weeks_high_symlog_diff_zscore_12m
#   CCNSA_weeks_high_symlog_diff_zscore_12m_lag_12m
#   CCNSA_weeks_high_symlog_diff_zscore_12m_lag_18m
#   CCNSA_weeks_high_symlog_diff_zscore_12m_lag_1m
#   CCNSA_weeks_high_symlog_diff_zscore_12m_lag_3m
#   CCNSA_weeks_high_symlog_diff_zscore_12m_lag_6m
#   CCNSA_weeks_high_symlog_diff_zscore_3m
#   CCNSA_weeks_high_symlog_diff_zscore_3m_lag_12m
#   CCNSA_weeks_high_symlog_diff_zscore_3m_lag_18m
#   CCNSA_weeks_high_symlog_diff_zscore_3m_lag_1m
#   CCNSA_weeks_high_symlog_diff_zscore_3m_lag_3m
#   CCNSA_weeks_high_symlog_diff_zscore_3m_lag_6m
#   CCNSA_weeks_high_symlog_lag_12m
#   CCNSA_weeks_high_symlog_lag_18m
#   CCNSA_weeks_high_symlog_lag_1m
#   CCNSA_weeks_high_symlog_lag_3m
#   CCNSA_weeks_high_symlog_lag_6m
#   CCNSA_weeks_high_symlog_pct_chg
#   CCNSA_weeks_high_symlog_pct_chg_lag_12m
#   CCNSA_weeks_high_symlog_pct_chg_lag_18m
#   CCNSA_weeks_high_symlog_pct_chg_lag_1m
#   CCNSA_weeks_high_symlog_pct_chg_lag_3m
#   CCNSA_weeks_high_symlog_pct_chg_lag_6m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCNSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m_lag_12m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m_lag_18m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m_lag_1m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m_lag_3m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_12m_lag_6m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m_lag_12m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m_lag_18m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m_lag_1m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m_lag_3m
#   CCNSA_weeks_high_symlog_pct_chg_zscore_3m_lag_6m
#   CCNSA_weeks_high_symlog_rolling_mean_3m
#   CCNSA_weeks_high_symlog_rolling_mean_3m_lag_12m
#   CCNSA_weeks_high_symlog_rolling_mean_3m_lag_18m
#   CCNSA_weeks_high_symlog_rolling_mean_3m_lag_1m
#   CCNSA_weeks_high_symlog_rolling_mean_3m_lag_3m
#   CCNSA_weeks_high_symlog_rolling_mean_3m_lag_6m
#   CCNSA_weeks_high_symlog_rolling_std_6m
#   CCNSA_weeks_high_symlog_rolling_std_6m_lag_12m
#   CCNSA_weeks_high_symlog_rolling_std_6m_lag_18m
#   CCNSA_weeks_high_symlog_rolling_std_6m_lag_1m
#   CCNSA_weeks_high_symlog_rolling_std_6m_lag_3m
#   CCNSA_weeks_high_symlog_rolling_std_6m_lag_6m
#   CCNSA_weeks_high_symlog_zscore_12m
#   CCNSA_weeks_high_symlog_zscore_12m_lag_12m
#   CCNSA_weeks_high_symlog_zscore_12m_lag_18m
#   CCNSA_weeks_high_symlog_zscore_12m_lag_1m
#   CCNSA_weeks_high_symlog_zscore_12m_lag_3m
#   CCNSA_weeks_high_symlog_zscore_12m_lag_6m
#   CCNSA_weeks_high_symlog_zscore_3m
#   CCNSA_weeks_high_symlog_zscore_3m_lag_12m
#   CCNSA_weeks_high_symlog_zscore_3m_lag_18m
#   CCNSA_weeks_high_symlog_zscore_3m_lag_1m
#   CCNSA_weeks_high_symlog_zscore_3m_lag_3m
#   CCNSA_weeks_high_symlog_zscore_3m_lag_6m
#   CCNSA_weeks_high_zscore_12m
#   CCNSA_weeks_high_zscore_12m_lag_12m
#   CCNSA_weeks_high_zscore_12m_lag_18m
#   CCNSA_weeks_high_zscore_12m_lag_1m
#   CCNSA_weeks_high_zscore_12m_lag_3m
#   CCNSA_weeks_high_zscore_12m_lag_6m
#   CCNSA_weeks_high_zscore_3m
#   CCNSA_weeks_high_zscore_3m_lag_12m
#   CCNSA_weeks_high_zscore_3m_lag_18m
#   CCNSA_weeks_high_zscore_3m_lag_1m
#   CCNSA_weeks_high_zscore_3m_lag_3m
#   CCNSA_weeks_high_zscore_3m_lag_6m
#   CCSA_max_spike
#   CCSA_max_spike_chg_12m
#   CCSA_max_spike_chg_12m_lag_12m
#   CCSA_max_spike_chg_12m_lag_18m
#   CCSA_max_spike_chg_12m_lag_1m
#   CCSA_max_spike_chg_12m_lag_3m
#   CCSA_max_spike_chg_12m_lag_6m
#   CCSA_max_spike_chg_3m
#   CCSA_max_spike_chg_3m_lag_12m
#   CCSA_max_spike_chg_3m_lag_18m
#   CCSA_max_spike_chg_3m_lag_1m
#   CCSA_max_spike_chg_3m_lag_3m
#   CCSA_max_spike_chg_3m_lag_6m
#   CCSA_max_spike_chg_6m
#   CCSA_max_spike_chg_6m_lag_12m
#   CCSA_max_spike_chg_6m_lag_18m
#   CCSA_max_spike_chg_6m_lag_1m
#   CCSA_max_spike_chg_6m_lag_3m
#   CCSA_max_spike_chg_6m_lag_6m
#   CCSA_max_spike_diff
#   CCSA_max_spike_diff_lag_12m
#   CCSA_max_spike_diff_lag_18m
#   CCSA_max_spike_diff_lag_1m
#   CCSA_max_spike_diff_lag_3m
#   CCSA_max_spike_diff_lag_6m
#   CCSA_max_spike_diff_zscore_12m
#   CCSA_max_spike_diff_zscore_12m_lag_12m
#   CCSA_max_spike_diff_zscore_12m_lag_18m
#   CCSA_max_spike_diff_zscore_12m_lag_1m
#   CCSA_max_spike_diff_zscore_12m_lag_3m
#   CCSA_max_spike_diff_zscore_12m_lag_6m
#   CCSA_max_spike_diff_zscore_3m
#   CCSA_max_spike_diff_zscore_3m_lag_12m
#   CCSA_max_spike_diff_zscore_3m_lag_18m
#   CCSA_max_spike_diff_zscore_3m_lag_1m
#   CCSA_max_spike_diff_zscore_3m_lag_3m
#   CCSA_max_spike_diff_zscore_3m_lag_6m
#   CCSA_max_spike_lag_12m
#   CCSA_max_spike_lag_18m
#   CCSA_max_spike_lag_1m
#   CCSA_max_spike_lag_3m
#   CCSA_max_spike_lag_6m
#   CCSA_max_spike_pct_chg
#   CCSA_max_spike_pct_chg_lag_12m
#   CCSA_max_spike_pct_chg_lag_18m
#   CCSA_max_spike_pct_chg_lag_1m
#   CCSA_max_spike_pct_chg_lag_3m
#   CCSA_max_spike_pct_chg_lag_6m
#   CCSA_max_spike_pct_chg_rolling_mean_3m
#   CCSA_max_spike_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_max_spike_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_max_spike_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_max_spike_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_max_spike_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_max_spike_pct_chg_rolling_std_6m
#   CCSA_max_spike_pct_chg_rolling_std_6m_lag_12m
#   CCSA_max_spike_pct_chg_rolling_std_6m_lag_18m
#   CCSA_max_spike_pct_chg_rolling_std_6m_lag_1m
#   CCSA_max_spike_pct_chg_rolling_std_6m_lag_3m
#   CCSA_max_spike_pct_chg_rolling_std_6m_lag_6m
#   CCSA_max_spike_pct_chg_zscore_12m
#   CCSA_max_spike_pct_chg_zscore_12m_lag_12m
#   CCSA_max_spike_pct_chg_zscore_12m_lag_18m
#   CCSA_max_spike_pct_chg_zscore_12m_lag_1m
#   CCSA_max_spike_pct_chg_zscore_12m_lag_3m
#   CCSA_max_spike_pct_chg_zscore_12m_lag_6m
#   CCSA_max_spike_pct_chg_zscore_3m
#   CCSA_max_spike_pct_chg_zscore_3m_lag_12m
#   CCSA_max_spike_pct_chg_zscore_3m_lag_18m
#   CCSA_max_spike_pct_chg_zscore_3m_lag_1m
#   CCSA_max_spike_pct_chg_zscore_3m_lag_3m
#   CCSA_max_spike_pct_chg_zscore_3m_lag_6m
#   CCSA_max_spike_rolling_mean_3m
#   CCSA_max_spike_rolling_mean_3m_lag_12m
#   CCSA_max_spike_rolling_mean_3m_lag_18m
#   CCSA_max_spike_rolling_mean_3m_lag_1m
#   CCSA_max_spike_rolling_mean_3m_lag_3m
#   CCSA_max_spike_rolling_mean_3m_lag_6m
#   CCSA_max_spike_rolling_std_6m
#   CCSA_max_spike_rolling_std_6m_lag_12m
#   CCSA_max_spike_rolling_std_6m_lag_18m
#   CCSA_max_spike_rolling_std_6m_lag_1m
#   CCSA_max_spike_rolling_std_6m_lag_3m
#   CCSA_max_spike_rolling_std_6m_lag_6m
#   CCSA_max_spike_symlog
#   CCSA_max_spike_symlog_chg_12m
#   CCSA_max_spike_symlog_chg_12m_lag_12m
#   CCSA_max_spike_symlog_chg_12m_lag_18m
#   CCSA_max_spike_symlog_chg_12m_lag_1m
#   CCSA_max_spike_symlog_chg_12m_lag_3m
#   CCSA_max_spike_symlog_chg_12m_lag_6m
#   CCSA_max_spike_symlog_chg_3m
#   CCSA_max_spike_symlog_chg_3m_lag_12m
#   CCSA_max_spike_symlog_chg_3m_lag_18m
#   CCSA_max_spike_symlog_chg_3m_lag_1m
#   CCSA_max_spike_symlog_chg_3m_lag_3m
#   CCSA_max_spike_symlog_chg_3m_lag_6m
#   CCSA_max_spike_symlog_chg_6m
#   CCSA_max_spike_symlog_chg_6m_lag_12m
#   CCSA_max_spike_symlog_chg_6m_lag_18m
#   CCSA_max_spike_symlog_chg_6m_lag_1m
#   CCSA_max_spike_symlog_chg_6m_lag_3m
#   CCSA_max_spike_symlog_chg_6m_lag_6m
#   CCSA_max_spike_symlog_diff
#   CCSA_max_spike_symlog_diff_lag_12m
#   CCSA_max_spike_symlog_diff_lag_18m
#   CCSA_max_spike_symlog_diff_lag_1m
#   CCSA_max_spike_symlog_diff_lag_3m
#   CCSA_max_spike_symlog_diff_lag_6m
#   CCSA_max_spike_symlog_diff_zscore_12m
#   CCSA_max_spike_symlog_diff_zscore_12m_lag_12m
#   CCSA_max_spike_symlog_diff_zscore_12m_lag_18m
#   CCSA_max_spike_symlog_diff_zscore_12m_lag_1m
#   CCSA_max_spike_symlog_diff_zscore_12m_lag_3m
#   CCSA_max_spike_symlog_diff_zscore_12m_lag_6m
#   CCSA_max_spike_symlog_diff_zscore_3m
#   CCSA_max_spike_symlog_diff_zscore_3m_lag_12m
#   CCSA_max_spike_symlog_diff_zscore_3m_lag_18m
#   CCSA_max_spike_symlog_diff_zscore_3m_lag_1m
#   CCSA_max_spike_symlog_diff_zscore_3m_lag_3m
#   CCSA_max_spike_symlog_diff_zscore_3m_lag_6m
#   CCSA_max_spike_symlog_lag_12m
#   CCSA_max_spike_symlog_lag_18m
#   CCSA_max_spike_symlog_lag_1m
#   CCSA_max_spike_symlog_lag_3m
#   CCSA_max_spike_symlog_lag_6m
#   CCSA_max_spike_symlog_pct_chg
#   CCSA_max_spike_symlog_pct_chg_lag_12m
#   CCSA_max_spike_symlog_pct_chg_lag_18m
#   CCSA_max_spike_symlog_pct_chg_lag_1m
#   CCSA_max_spike_symlog_pct_chg_lag_3m
#   CCSA_max_spike_symlog_pct_chg_lag_6m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_max_spike_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m_lag_12m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m_lag_18m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m_lag_1m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m_lag_3m
#   CCSA_max_spike_symlog_pct_chg_zscore_12m_lag_6m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m_lag_12m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m_lag_18m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m_lag_1m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m_lag_3m
#   CCSA_max_spike_symlog_pct_chg_zscore_3m_lag_6m
#   CCSA_max_spike_symlog_rolling_mean_3m
#   CCSA_max_spike_symlog_rolling_mean_3m_lag_12m
#   CCSA_max_spike_symlog_rolling_mean_3m_lag_18m
#   CCSA_max_spike_symlog_rolling_mean_3m_lag_1m
#   CCSA_max_spike_symlog_rolling_mean_3m_lag_3m
#   CCSA_max_spike_symlog_rolling_mean_3m_lag_6m
#   CCSA_max_spike_symlog_rolling_std_6m
#   CCSA_max_spike_symlog_rolling_std_6m_lag_12m
#   CCSA_max_spike_symlog_rolling_std_6m_lag_18m
#   CCSA_max_spike_symlog_rolling_std_6m_lag_1m
#   CCSA_max_spike_symlog_rolling_std_6m_lag_3m
#   CCSA_max_spike_symlog_rolling_std_6m_lag_6m
#   CCSA_max_spike_symlog_zscore_12m
#   CCSA_max_spike_symlog_zscore_12m_lag_12m
#   CCSA_max_spike_symlog_zscore_12m_lag_18m
#   CCSA_max_spike_symlog_zscore_12m_lag_1m
#   CCSA_max_spike_symlog_zscore_12m_lag_3m
#   CCSA_max_spike_symlog_zscore_12m_lag_6m
#   CCSA_max_spike_symlog_zscore_3m
#   CCSA_max_spike_symlog_zscore_3m_lag_12m
#   CCSA_max_spike_symlog_zscore_3m_lag_18m
#   CCSA_max_spike_symlog_zscore_3m_lag_1m
#   CCSA_max_spike_symlog_zscore_3m_lag_3m
#   CCSA_max_spike_symlog_zscore_3m_lag_6m
#   CCSA_max_spike_zscore_12m
#   CCSA_max_spike_zscore_12m_lag_12m
#   CCSA_max_spike_zscore_12m_lag_18m
#   CCSA_max_spike_zscore_12m_lag_1m
#   CCSA_max_spike_zscore_12m_lag_3m
#   CCSA_max_spike_zscore_12m_lag_6m
#   CCSA_max_spike_zscore_3m
#   CCSA_max_spike_zscore_3m_lag_12m
#   CCSA_max_spike_zscore_3m_lag_18m
#   CCSA_max_spike_zscore_3m_lag_1m
#   CCSA_max_spike_zscore_3m_lag_3m
#   CCSA_max_spike_zscore_3m_lag_6m
#   CCSA_monthly_avg
#   CCSA_monthly_avg_chg_12m
#   CCSA_monthly_avg_chg_12m_lag_12m
#   CCSA_monthly_avg_chg_12m_lag_18m
#   CCSA_monthly_avg_chg_12m_lag_1m
#   CCSA_monthly_avg_chg_12m_lag_3m
#   CCSA_monthly_avg_chg_12m_lag_6m
#   CCSA_monthly_avg_chg_3m
#   CCSA_monthly_avg_chg_3m_lag_12m
#   CCSA_monthly_avg_chg_3m_lag_18m
#   CCSA_monthly_avg_chg_3m_lag_1m
#   CCSA_monthly_avg_chg_3m_lag_3m
#   CCSA_monthly_avg_chg_3m_lag_6m
#   CCSA_monthly_avg_chg_6m
#   CCSA_monthly_avg_chg_6m_lag_12m
#   CCSA_monthly_avg_chg_6m_lag_18m
#   CCSA_monthly_avg_chg_6m_lag_1m
#   CCSA_monthly_avg_chg_6m_lag_3m
#   CCSA_monthly_avg_chg_6m_lag_6m
#   CCSA_monthly_avg_diff
#   CCSA_monthly_avg_diff_lag_12m
#   CCSA_monthly_avg_diff_lag_18m
#   CCSA_monthly_avg_diff_lag_1m
#   CCSA_monthly_avg_diff_lag_3m
#   CCSA_monthly_avg_diff_lag_6m
#   CCSA_monthly_avg_diff_zscore_12m
#   CCSA_monthly_avg_diff_zscore_12m_lag_12m
#   CCSA_monthly_avg_diff_zscore_12m_lag_18m
#   CCSA_monthly_avg_diff_zscore_12m_lag_1m
#   CCSA_monthly_avg_diff_zscore_12m_lag_3m
#   CCSA_monthly_avg_diff_zscore_12m_lag_6m
#   CCSA_monthly_avg_diff_zscore_3m
#   CCSA_monthly_avg_diff_zscore_3m_lag_12m
#   CCSA_monthly_avg_diff_zscore_3m_lag_18m
#   CCSA_monthly_avg_diff_zscore_3m_lag_1m
#   CCSA_monthly_avg_diff_zscore_3m_lag_3m
#   CCSA_monthly_avg_diff_zscore_3m_lag_6m
#   CCSA_monthly_avg_lag_12m
#   CCSA_monthly_avg_lag_18m
#   CCSA_monthly_avg_lag_1m
#   CCSA_monthly_avg_lag_3m
#   CCSA_monthly_avg_lag_6m
#   CCSA_monthly_avg_pct_chg
#   CCSA_monthly_avg_pct_chg_lag_12m
#   CCSA_monthly_avg_pct_chg_lag_18m
#   CCSA_monthly_avg_pct_chg_lag_1m
#   CCSA_monthly_avg_pct_chg_lag_3m
#   CCSA_monthly_avg_pct_chg_lag_6m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_monthly_avg_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m_lag_12m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m_lag_18m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m_lag_1m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m_lag_3m
#   CCSA_monthly_avg_pct_chg_rolling_std_6m_lag_6m
#   CCSA_monthly_avg_pct_chg_zscore_12m
#   CCSA_monthly_avg_pct_chg_zscore_12m_lag_12m
#   CCSA_monthly_avg_pct_chg_zscore_12m_lag_18m
#   CCSA_monthly_avg_pct_chg_zscore_12m_lag_1m
#   CCSA_monthly_avg_pct_chg_zscore_12m_lag_3m
#   CCSA_monthly_avg_pct_chg_zscore_12m_lag_6m
#   CCSA_monthly_avg_pct_chg_zscore_3m
#   CCSA_monthly_avg_pct_chg_zscore_3m_lag_12m
#   CCSA_monthly_avg_pct_chg_zscore_3m_lag_18m
#   CCSA_monthly_avg_pct_chg_zscore_3m_lag_1m
#   CCSA_monthly_avg_pct_chg_zscore_3m_lag_3m
#   CCSA_monthly_avg_pct_chg_zscore_3m_lag_6m
#   CCSA_monthly_avg_rolling_mean_3m
#   CCSA_monthly_avg_rolling_mean_3m_lag_12m
#   CCSA_monthly_avg_rolling_mean_3m_lag_18m
#   CCSA_monthly_avg_rolling_mean_3m_lag_1m
#   CCSA_monthly_avg_rolling_mean_3m_lag_3m
#   CCSA_monthly_avg_rolling_mean_3m_lag_6m
#   CCSA_monthly_avg_rolling_std_6m
#   CCSA_monthly_avg_rolling_std_6m_lag_12m
#   CCSA_monthly_avg_rolling_std_6m_lag_18m
#   CCSA_monthly_avg_rolling_std_6m_lag_1m
#   CCSA_monthly_avg_rolling_std_6m_lag_3m
#   CCSA_monthly_avg_rolling_std_6m_lag_6m
#   CCSA_monthly_avg_symlog
#   CCSA_monthly_avg_symlog_chg_12m
#   CCSA_monthly_avg_symlog_chg_12m_lag_12m
#   CCSA_monthly_avg_symlog_chg_12m_lag_18m
#   CCSA_monthly_avg_symlog_chg_12m_lag_1m
#   CCSA_monthly_avg_symlog_chg_12m_lag_3m
#   CCSA_monthly_avg_symlog_chg_12m_lag_6m
#   CCSA_monthly_avg_symlog_chg_3m
#   CCSA_monthly_avg_symlog_chg_3m_lag_12m
#   CCSA_monthly_avg_symlog_chg_3m_lag_18m
#   CCSA_monthly_avg_symlog_chg_3m_lag_1m
#   CCSA_monthly_avg_symlog_chg_3m_lag_3m
#   CCSA_monthly_avg_symlog_chg_3m_lag_6m
#   CCSA_monthly_avg_symlog_chg_6m
#   CCSA_monthly_avg_symlog_chg_6m_lag_12m
#   CCSA_monthly_avg_symlog_chg_6m_lag_18m
#   CCSA_monthly_avg_symlog_chg_6m_lag_1m
#   CCSA_monthly_avg_symlog_chg_6m_lag_3m
#   CCSA_monthly_avg_symlog_chg_6m_lag_6m
#   CCSA_monthly_avg_symlog_diff
#   CCSA_monthly_avg_symlog_diff_lag_12m
#   CCSA_monthly_avg_symlog_diff_lag_18m
#   CCSA_monthly_avg_symlog_diff_lag_1m
#   CCSA_monthly_avg_symlog_diff_lag_3m
#   CCSA_monthly_avg_symlog_diff_lag_6m
#   CCSA_monthly_avg_symlog_diff_zscore_12m
#   CCSA_monthly_avg_symlog_diff_zscore_12m_lag_12m
#   CCSA_monthly_avg_symlog_diff_zscore_12m_lag_18m
#   CCSA_monthly_avg_symlog_diff_zscore_12m_lag_1m
#   CCSA_monthly_avg_symlog_diff_zscore_12m_lag_3m
#   CCSA_monthly_avg_symlog_diff_zscore_12m_lag_6m
#   CCSA_monthly_avg_symlog_diff_zscore_3m
#   CCSA_monthly_avg_symlog_diff_zscore_3m_lag_12m
#   CCSA_monthly_avg_symlog_diff_zscore_3m_lag_18m
#   CCSA_monthly_avg_symlog_diff_zscore_3m_lag_1m
#   CCSA_monthly_avg_symlog_diff_zscore_3m_lag_3m
#   CCSA_monthly_avg_symlog_diff_zscore_3m_lag_6m
#   CCSA_monthly_avg_symlog_lag_12m
#   CCSA_monthly_avg_symlog_lag_18m
#   CCSA_monthly_avg_symlog_lag_1m
#   CCSA_monthly_avg_symlog_lag_3m
#   CCSA_monthly_avg_symlog_lag_6m
#   CCSA_monthly_avg_symlog_pct_chg
#   CCSA_monthly_avg_symlog_pct_chg_lag_12m
#   CCSA_monthly_avg_symlog_pct_chg_lag_18m
#   CCSA_monthly_avg_symlog_pct_chg_lag_1m
#   CCSA_monthly_avg_symlog_pct_chg_lag_3m
#   CCSA_monthly_avg_symlog_pct_chg_lag_6m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCSA_monthly_avg_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_12m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_18m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_1m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_3m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_12m_lag_6m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_12m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_18m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_1m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_3m
#   CCSA_monthly_avg_symlog_pct_chg_zscore_3m_lag_6m
#   CCSA_monthly_avg_symlog_rolling_mean_3m
#   CCSA_monthly_avg_symlog_rolling_mean_3m_lag_12m
#   CCSA_monthly_avg_symlog_rolling_mean_3m_lag_18m
#   CCSA_monthly_avg_symlog_rolling_mean_3m_lag_1m
#   CCSA_monthly_avg_symlog_rolling_mean_3m_lag_3m
#   CCSA_monthly_avg_symlog_rolling_mean_3m_lag_6m
#   CCSA_monthly_avg_symlog_rolling_std_6m
#   CCSA_monthly_avg_symlog_rolling_std_6m_lag_12m
#   CCSA_monthly_avg_symlog_rolling_std_6m_lag_18m
#   CCSA_monthly_avg_symlog_rolling_std_6m_lag_1m
#   CCSA_monthly_avg_symlog_rolling_std_6m_lag_3m
#   CCSA_monthly_avg_symlog_rolling_std_6m_lag_6m
#   CCSA_monthly_avg_symlog_zscore_12m
#   CCSA_monthly_avg_symlog_zscore_12m_lag_12m
#   CCSA_monthly_avg_symlog_zscore_12m_lag_18m
#   CCSA_monthly_avg_symlog_zscore_12m_lag_1m
#   CCSA_monthly_avg_symlog_zscore_12m_lag_3m
#   CCSA_monthly_avg_symlog_zscore_12m_lag_6m
#   CCSA_monthly_avg_symlog_zscore_3m
#   CCSA_monthly_avg_symlog_zscore_3m_lag_12m
#   CCSA_monthly_avg_symlog_zscore_3m_lag_18m
#   CCSA_monthly_avg_symlog_zscore_3m_lag_1m
#   CCSA_monthly_avg_symlog_zscore_3m_lag_3m
#   CCSA_monthly_avg_symlog_zscore_3m_lag_6m
#   CCSA_monthly_avg_zscore_12m
#   CCSA_monthly_avg_zscore_12m_lag_12m
#   CCSA_monthly_avg_zscore_12m_lag_18m
#   CCSA_monthly_avg_zscore_12m_lag_1m
#   CCSA_monthly_avg_zscore_12m_lag_3m
#   CCSA_monthly_avg_zscore_12m_lag_6m
#   CCSA_monthly_avg_zscore_3m
#   CCSA_monthly_avg_zscore_3m_lag_12m
#   CCSA_monthly_avg_zscore_3m_lag_18m
#   CCSA_monthly_avg_zscore_3m_lag_1m
#   CCSA_monthly_avg_zscore_3m_lag_3m
#   CCSA_monthly_avg_zscore_3m_lag_6m
#   CCSA_weeks_high
#   CCSA_weeks_high_chg_12m
#   CCSA_weeks_high_chg_12m_lag_12m
#   CCSA_weeks_high_chg_12m_lag_18m
#   CCSA_weeks_high_chg_12m_lag_1m
#   CCSA_weeks_high_chg_12m_lag_3m
#   CCSA_weeks_high_chg_12m_lag_6m
#   CCSA_weeks_high_chg_3m
#   CCSA_weeks_high_chg_3m_lag_12m
#   CCSA_weeks_high_chg_3m_lag_18m
#   CCSA_weeks_high_chg_3m_lag_1m
#   CCSA_weeks_high_chg_3m_lag_3m
#   CCSA_weeks_high_chg_3m_lag_6m
#   CCSA_weeks_high_chg_6m
#   CCSA_weeks_high_chg_6m_lag_12m
#   CCSA_weeks_high_chg_6m_lag_18m
#   CCSA_weeks_high_chg_6m_lag_1m
#   CCSA_weeks_high_chg_6m_lag_3m
#   CCSA_weeks_high_chg_6m_lag_6m
#   CCSA_weeks_high_diff
#   CCSA_weeks_high_diff_lag_12m
#   CCSA_weeks_high_diff_lag_18m
#   CCSA_weeks_high_diff_lag_1m
#   CCSA_weeks_high_diff_lag_3m
#   CCSA_weeks_high_diff_lag_6m
#   CCSA_weeks_high_diff_zscore_12m
#   CCSA_weeks_high_diff_zscore_12m_lag_12m
#   CCSA_weeks_high_diff_zscore_12m_lag_18m
#   CCSA_weeks_high_diff_zscore_12m_lag_1m
#   CCSA_weeks_high_diff_zscore_12m_lag_3m
#   CCSA_weeks_high_diff_zscore_12m_lag_6m
#   CCSA_weeks_high_diff_zscore_3m
#   CCSA_weeks_high_diff_zscore_3m_lag_12m
#   CCSA_weeks_high_diff_zscore_3m_lag_18m
#   CCSA_weeks_high_diff_zscore_3m_lag_1m
#   CCSA_weeks_high_diff_zscore_3m_lag_3m
#   CCSA_weeks_high_diff_zscore_3m_lag_6m
#   CCSA_weeks_high_lag_12m
#   CCSA_weeks_high_lag_18m
#   CCSA_weeks_high_lag_1m
#   CCSA_weeks_high_lag_3m
#   CCSA_weeks_high_lag_6m
#   CCSA_weeks_high_pct_chg
#   CCSA_weeks_high_pct_chg_lag_12m
#   CCSA_weeks_high_pct_chg_lag_18m
#   CCSA_weeks_high_pct_chg_lag_1m
#   CCSA_weeks_high_pct_chg_lag_3m
#   CCSA_weeks_high_pct_chg_lag_6m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_weeks_high_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_weeks_high_pct_chg_rolling_std_6m
#   CCSA_weeks_high_pct_chg_rolling_std_6m_lag_12m
#   CCSA_weeks_high_pct_chg_rolling_std_6m_lag_18m
#   CCSA_weeks_high_pct_chg_rolling_std_6m_lag_1m
#   CCSA_weeks_high_pct_chg_rolling_std_6m_lag_3m
#   CCSA_weeks_high_pct_chg_rolling_std_6m_lag_6m
#   CCSA_weeks_high_pct_chg_zscore_12m
#   CCSA_weeks_high_pct_chg_zscore_12m_lag_12m
#   CCSA_weeks_high_pct_chg_zscore_12m_lag_18m
#   CCSA_weeks_high_pct_chg_zscore_12m_lag_1m
#   CCSA_weeks_high_pct_chg_zscore_12m_lag_3m
#   CCSA_weeks_high_pct_chg_zscore_12m_lag_6m
#   CCSA_weeks_high_pct_chg_zscore_3m
#   CCSA_weeks_high_pct_chg_zscore_3m_lag_12m
#   CCSA_weeks_high_pct_chg_zscore_3m_lag_18m
#   CCSA_weeks_high_pct_chg_zscore_3m_lag_1m
#   CCSA_weeks_high_pct_chg_zscore_3m_lag_3m
#   CCSA_weeks_high_pct_chg_zscore_3m_lag_6m
#   CCSA_weeks_high_rolling_mean_3m
#   CCSA_weeks_high_rolling_mean_3m_lag_12m
#   CCSA_weeks_high_rolling_mean_3m_lag_18m
#   CCSA_weeks_high_rolling_mean_3m_lag_1m
#   CCSA_weeks_high_rolling_mean_3m_lag_3m
#   CCSA_weeks_high_rolling_mean_3m_lag_6m
#   CCSA_weeks_high_rolling_std_6m
#   CCSA_weeks_high_rolling_std_6m_lag_12m
#   CCSA_weeks_high_rolling_std_6m_lag_18m
#   CCSA_weeks_high_rolling_std_6m_lag_1m
#   CCSA_weeks_high_rolling_std_6m_lag_3m
#   CCSA_weeks_high_rolling_std_6m_lag_6m
#   CCSA_weeks_high_symlog
#   CCSA_weeks_high_symlog_chg_12m
#   CCSA_weeks_high_symlog_chg_12m_lag_12m
#   CCSA_weeks_high_symlog_chg_12m_lag_18m
#   CCSA_weeks_high_symlog_chg_12m_lag_1m
#   CCSA_weeks_high_symlog_chg_12m_lag_3m
#   CCSA_weeks_high_symlog_chg_12m_lag_6m
#   CCSA_weeks_high_symlog_chg_3m
#   CCSA_weeks_high_symlog_chg_3m_lag_12m
#   CCSA_weeks_high_symlog_chg_3m_lag_18m
#   CCSA_weeks_high_symlog_chg_3m_lag_1m
#   CCSA_weeks_high_symlog_chg_3m_lag_3m
#   CCSA_weeks_high_symlog_chg_3m_lag_6m
#   CCSA_weeks_high_symlog_chg_6m
#   CCSA_weeks_high_symlog_chg_6m_lag_12m
#   CCSA_weeks_high_symlog_chg_6m_lag_18m
#   CCSA_weeks_high_symlog_chg_6m_lag_1m
#   CCSA_weeks_high_symlog_chg_6m_lag_3m
#   CCSA_weeks_high_symlog_chg_6m_lag_6m
#   CCSA_weeks_high_symlog_diff
#   CCSA_weeks_high_symlog_diff_lag_12m
#   CCSA_weeks_high_symlog_diff_lag_18m
#   CCSA_weeks_high_symlog_diff_lag_1m
#   CCSA_weeks_high_symlog_diff_lag_3m
#   CCSA_weeks_high_symlog_diff_lag_6m
#   CCSA_weeks_high_symlog_diff_zscore_12m
#   CCSA_weeks_high_symlog_diff_zscore_12m_lag_12m
#   CCSA_weeks_high_symlog_diff_zscore_12m_lag_18m
#   CCSA_weeks_high_symlog_diff_zscore_12m_lag_1m
#   CCSA_weeks_high_symlog_diff_zscore_12m_lag_3m
#   CCSA_weeks_high_symlog_diff_zscore_12m_lag_6m
#   CCSA_weeks_high_symlog_diff_zscore_3m
#   CCSA_weeks_high_symlog_diff_zscore_3m_lag_12m
#   CCSA_weeks_high_symlog_diff_zscore_3m_lag_18m
#   CCSA_weeks_high_symlog_diff_zscore_3m_lag_1m
#   CCSA_weeks_high_symlog_diff_zscore_3m_lag_3m
#   CCSA_weeks_high_symlog_diff_zscore_3m_lag_6m
#   CCSA_weeks_high_symlog_lag_12m
#   CCSA_weeks_high_symlog_lag_18m
#   CCSA_weeks_high_symlog_lag_1m
#   CCSA_weeks_high_symlog_lag_3m
#   CCSA_weeks_high_symlog_lag_6m
#   CCSA_weeks_high_symlog_pct_chg
#   CCSA_weeks_high_symlog_pct_chg_lag_12m
#   CCSA_weeks_high_symlog_pct_chg_lag_18m
#   CCSA_weeks_high_symlog_pct_chg_lag_1m
#   CCSA_weeks_high_symlog_pct_chg_lag_3m
#   CCSA_weeks_high_symlog_pct_chg_lag_6m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_12m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_18m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_1m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_3m
#   CCSA_weeks_high_symlog_pct_chg_rolling_mean_3m_lag_6m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_12m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_18m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_1m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_3m
#   CCSA_weeks_high_symlog_pct_chg_rolling_std_6m_lag_6m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m_lag_12m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m_lag_18m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m_lag_1m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m_lag_3m
#   CCSA_weeks_high_symlog_pct_chg_zscore_12m_lag_6m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m_lag_12m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m_lag_18m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m_lag_1m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m_lag_3m
#   CCSA_weeks_high_symlog_pct_chg_zscore_3m_lag_6m
#   CCSA_weeks_high_symlog_rolling_mean_3m
#   CCSA_weeks_high_symlog_rolling_mean_3m_lag_12m
#   CCSA_weeks_high_symlog_rolling_mean_3m_lag_18m
#   CCSA_weeks_high_symlog_rolling_mean_3m_lag_1m
#   CCSA_weeks_high_symlog_rolling_mean_3m_lag_3m
#   CCSA_weeks_high_symlog_rolling_mean_3m_lag_6m
#   CCSA_weeks_high_symlog_rolling_std_6m
#   CCSA_weeks_high_symlog_rolling_std_6m_lag_12m
#   CCSA_weeks_high_symlog_rolling_std_6m_lag_18m
#   CCSA_weeks_high_symlog_rolling_std_6m_lag_1m
#   CCSA_weeks_high_symlog_rolling_std_6m_lag_3m
#   CCSA_weeks_high_symlog_rolling_std_6m_lag_6m
#   CCSA_weeks_high_symlog_zscore_12m
#   CCSA_weeks_high_symlog_zscore_12m_lag_12m
#   CCSA_weeks_high_symlog_zscore_12m_lag_18m
#   CCSA_weeks_high_symlog_zscore_12m_lag_1m
#   CCSA_weeks_high_symlog_zscore_12m_lag_3m
#   CCSA_weeks_high_symlog_zscore_12m_lag_6m
#   CCSA_weeks_high_symlog_zscore_3m
#   CCSA_weeks_high_symlog_zscore_3m_lag_12m
#   CCSA_weeks_high_symlog_zscore_3m_lag_18m
#   CCSA_weeks_high_symlog_zscore_3m_lag_1m
#   CCSA_weeks_high_symlog_zscore_3m_lag_3m
#   CCSA_weeks_high_symlog_zscore_3m_lag_6m
#   CCSA_weeks_high_zscore_12m
#   CCSA_weeks_high_zscore_12m_lag_12m
#   CCSA_weeks_high_zscore_12m_lag_18m
#   CCSA_weeks_high_zscore_12m_lag_1m
#   CCSA_weeks_high_zscore_12m_lag_3m
#   CCSA_weeks_high_zscore_12m_lag_6m
#   CCSA_weeks_high_zscore_3m
#   CCSA_weeks_high_zscore_3m_lag_12m
#   CCSA_weeks_high_zscore_3m_lag_18m
#   CCSA_weeks_high_zscore_3m_lag_1m
#   CCSA_weeks_high_zscore_3m_lag_3m
#   CCSA_weeks_high_zscore_3m_lag_6m
#   Credit_Spreads_accel_volatility
#   Credit_Spreads_accel_volatility_chg_12m
#   Credit_Spreads_accel_volatility_chg_12m_lag_12m
#   Credit_Spreads_accel_volatility_chg_12m_lag_18m
#   Credit_Spreads_accel_volatility_chg_12m_lag_1m
#   Credit_Spreads_accel_volatility_chg_12m_lag_3m
#   Credit_Spreads_accel_volatility_chg_12m_lag_6m
#   Credit_Spreads_accel_volatility_chg_3m
#   Credit_Spreads_accel_volatility_chg_3m_lag_12m
#   Credit_Spreads_accel_volatility_chg_3m_lag_18m
#   Credit_Spreads_accel_volatility_chg_3m_lag_1m
#   Credit_Spreads_accel_volatility_chg_3m_lag_3m
#   Credit_Spreads_accel_volatility_chg_3m_lag_6m
#   Credit_Spreads_accel_volatility_chg_6m
#   Credit_Spreads_accel_volatility_chg_6m_lag_12m
#   Credit_Spreads_accel_volatility_chg_6m_lag_18m
#   Credit_Spreads_accel_volatility_chg_6m_lag_1m
#   Credit_Spreads_accel_volatility_chg_6m_lag_3m
# ...
#   Yield_Curve_vol_of_changes_pct_chg_zscore_12m_lag_1m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_12m_lag_3m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_12m_lag_6m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m_lag_12m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m_lag_18m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m_lag_1m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m_lag_3m
#   Yield_Curve_vol_of_changes_pct_chg_zscore_3m_lag_6m
#   Yield_Curve_vol_of_changes_rolling_mean_3m
#   Yield_Curve_vol_of_changes_rolling_mean_3m_lag_12m
#   Yield_Curve_vol_of_changes_rolling_mean_3m_lag_18m
#   Yield_Curve_vol_of_changes_rolling_mean_3m_lag_1m
#   Yield_Curve_vol_of_changes_rolling_mean_3m_lag_3m
#   Yield_Curve_vol_of_changes_rolling_mean_3m_lag_6m
#   Yield_Curve_vol_of_changes_rolling_std_6m
#   Yield_Curve_vol_of_changes_rolling_std_6m_lag_12m
#   Yield_Curve_vol_of_changes_rolling_std_6m_lag_18m
#   Yield_Curve_vol_of_changes_rolling_std_6m_lag_1m
#   Yield_Curve_vol_of_changes_rolling_std_6m_lag_3m
#   Yield_Curve_vol_of_changes_rolling_std_6m_lag_6m
#   Yield_Curve_vol_of_changes_symlog
#   Yield_Curve_vol_of_changes_symlog_chg_12m
#   Yield_Curve_vol_of_changes_symlog_chg_12m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_chg_12m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_chg_12m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_chg_12m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_chg_12m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_chg_3m
#   Yield_Curve_vol_of_changes_symlog_chg_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_chg_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_chg_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_chg_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_chg_3m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_chg_6m
#   Yield_Curve_vol_of_changes_symlog_chg_6m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_chg_6m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_chg_6m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_chg_6m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_chg_6m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_diff
#   Yield_Curve_vol_of_changes_symlog_diff_lag_12m
#   Yield_Curve_vol_of_changes_symlog_diff_lag_18m
#   Yield_Curve_vol_of_changes_symlog_diff_lag_1m
#   Yield_Curve_vol_of_changes_symlog_diff_lag_3m
#   Yield_Curve_vol_of_changes_symlog_diff_lag_6m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_12m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_diff_zscore_3m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_lag_12m
#   Yield_Curve_vol_of_changes_symlog_lag_18m
#   Yield_Curve_vol_of_changes_symlog_lag_1m
#   Yield_Curve_vol_of_changes_symlog_lag_3m
#   Yield_Curve_vol_of_changes_symlog_lag_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg
#   Yield_Curve_vol_of_changes_symlog_pct_chg_lag_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_lag_18m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_lag_1m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_lag_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_lag_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_mean_3m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_rolling_std_6m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_12m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_pct_chg_zscore_3m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_rolling_mean_3m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_rolling_std_6m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_zscore_12m_lag_6m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m_lag_12m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m_lag_18m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m_lag_1m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m_lag_3m
#   Yield_Curve_vol_of_changes_symlog_zscore_3m_lag_6m
#   Yield_Curve_vol_of_changes_zscore_12m
#   Yield_Curve_vol_of_changes_zscore_12m_lag_12m
#   Yield_Curve_vol_of_changes_zscore_12m_lag_18m
#   Yield_Curve_vol_of_changes_zscore_12m_lag_1m
#   Yield_Curve_vol_of_changes_zscore_12m_lag_3m
#   Yield_Curve_vol_of_changes_zscore_12m_lag_6m
#   Yield_Curve_vol_of_changes_zscore_3m
#   Yield_Curve_vol_of_changes_zscore_3m_lag_12m
#   Yield_Curve_vol_of_changes_zscore_3m_lag_18m
#   Yield_Curve_vol_of_changes_zscore_3m_lag_1m
#   Yield_Curve_vol_of_changes_zscore_3m_lag_3m
#   Yield_Curve_vol_of_changes_zscore_3m_lag_6m
#   Yield_Curve_zscore_max
#   Yield_Curve_zscore_max_chg_12m
#   Yield_Curve_zscore_max_chg_12m_lag_12m
#   Yield_Curve_zscore_max_chg_12m_lag_18m
#   Yield_Curve_zscore_max_chg_12m_lag_1m
#   Yield_Curve_zscore_max_chg_12m_lag_3m
#   Yield_Curve_zscore_max_chg_12m_lag_6m
#   Yield_Curve_zscore_max_chg_3m
#   Yield_Curve_zscore_max_chg_3m_lag_12m
#   Yield_Curve_zscore_max_chg_3m_lag_18m
#   Yield_Curve_zscore_max_chg_3m_lag_1m
#   Yield_Curve_zscore_max_chg_3m_lag_3m
#   Yield_Curve_zscore_max_chg_3m_lag_6m
#   Yield_Curve_zscore_max_chg_6m
#   Yield_Curve_zscore_max_chg_6m_lag_12m
#   Yield_Curve_zscore_max_chg_6m_lag_18m
#   Yield_Curve_zscore_max_chg_6m_lag_1m
#   Yield_Curve_zscore_max_chg_6m_lag_3m
#   Yield_Curve_zscore_max_chg_6m_lag_6m
#   Yield_Curve_zscore_max_diff
#   Yield_Curve_zscore_max_diff_lag_12m
#   Yield_Curve_zscore_max_diff_lag_18m
#   Yield_Curve_zscore_max_diff_lag_1m
#   Yield_Curve_zscore_max_diff_lag_3m
#   Yield_Curve_zscore_max_diff_lag_6m
#   Yield_Curve_zscore_max_diff_zscore_12m
#   Yield_Curve_zscore_max_diff_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_diff_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_diff_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_diff_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_diff_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_diff_zscore_3m
#   Yield_Curve_zscore_max_diff_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_diff_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_diff_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_diff_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_diff_zscore_3m_lag_6m
#   Yield_Curve_zscore_max_lag_12m
#   Yield_Curve_zscore_max_lag_18m
#   Yield_Curve_zscore_max_lag_1m
#   Yield_Curve_zscore_max_lag_3m
#   Yield_Curve_zscore_max_lag_6m
#   Yield_Curve_zscore_max_pct_chg
#   Yield_Curve_zscore_max_pct_chg_lag_12m
#   Yield_Curve_zscore_max_pct_chg_lag_18m
#   Yield_Curve_zscore_max_pct_chg_lag_1m
#   Yield_Curve_zscore_max_pct_chg_lag_3m
#   Yield_Curve_zscore_max_pct_chg_lag_6m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m_lag_12m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m_lag_18m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m_lag_1m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m_lag_3m
#   Yield_Curve_zscore_max_pct_chg_rolling_mean_3m_lag_6m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m_lag_12m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m_lag_18m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m_lag_1m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m_lag_3m
#   Yield_Curve_zscore_max_pct_chg_rolling_std_6m_lag_6m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_pct_chg_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_pct_chg_zscore_3m_lag_6m
#   Yield_Curve_zscore_max_rolling_mean_3m
#   Yield_Curve_zscore_max_rolling_mean_3m_lag_12m
#   Yield_Curve_zscore_max_rolling_mean_3m_lag_18m
#   Yield_Curve_zscore_max_rolling_mean_3m_lag_1m
#   Yield_Curve_zscore_max_rolling_mean_3m_lag_3m
#   Yield_Curve_zscore_max_rolling_mean_3m_lag_6m
#   Yield_Curve_zscore_max_rolling_std_6m
#   Yield_Curve_zscore_max_rolling_std_6m_lag_12m
#   Yield_Curve_zscore_max_rolling_std_6m_lag_18m
#   Yield_Curve_zscore_max_rolling_std_6m_lag_1m
#   Yield_Curve_zscore_max_rolling_std_6m_lag_3m
#   Yield_Curve_zscore_max_rolling_std_6m_lag_6m
#   Yield_Curve_zscore_max_symlog
#   Yield_Curve_zscore_max_symlog_chg_12m
#   Yield_Curve_zscore_max_symlog_chg_12m_lag_12m
#   Yield_Curve_zscore_max_symlog_chg_12m_lag_18m
#   Yield_Curve_zscore_max_symlog_chg_12m_lag_1m
#   Yield_Curve_zscore_max_symlog_chg_12m_lag_3m
#   Yield_Curve_zscore_max_symlog_chg_12m_lag_6m
#   Yield_Curve_zscore_max_symlog_chg_3m
#   Yield_Curve_zscore_max_symlog_chg_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_chg_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_chg_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_chg_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_chg_3m_lag_6m
#   Yield_Curve_zscore_max_symlog_chg_6m
#   Yield_Curve_zscore_max_symlog_chg_6m_lag_12m
#   Yield_Curve_zscore_max_symlog_chg_6m_lag_18m
#   Yield_Curve_zscore_max_symlog_chg_6m_lag_1m
#   Yield_Curve_zscore_max_symlog_chg_6m_lag_3m
#   Yield_Curve_zscore_max_symlog_chg_6m_lag_6m
#   Yield_Curve_zscore_max_symlog_diff
#   Yield_Curve_zscore_max_symlog_diff_lag_12m
#   Yield_Curve_zscore_max_symlog_diff_lag_18m
#   Yield_Curve_zscore_max_symlog_diff_lag_1m
#   Yield_Curve_zscore_max_symlog_diff_lag_3m
#   Yield_Curve_zscore_max_symlog_diff_lag_6m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_symlog_diff_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_diff_zscore_3m_lag_6m
#   Yield_Curve_zscore_max_symlog_lag_12m
#   Yield_Curve_zscore_max_symlog_lag_18m
#   Yield_Curve_zscore_max_symlog_lag_1m
#   Yield_Curve_zscore_max_symlog_lag_3m
#   Yield_Curve_zscore_max_symlog_lag_6m
#   Yield_Curve_zscore_max_symlog_pct_chg
#   Yield_Curve_zscore_max_symlog_pct_chg_lag_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_lag_18m
#   Yield_Curve_zscore_max_symlog_pct_chg_lag_1m
#   Yield_Curve_zscore_max_symlog_pct_chg_lag_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_lag_6m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_mean_3m_lag_6m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m_lag_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m_lag_18m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m_lag_1m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m_lag_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_rolling_std_6m_lag_6m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_pct_chg_zscore_3m_lag_6m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_rolling_mean_3m_lag_6m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m_lag_12m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m_lag_18m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m_lag_1m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m_lag_3m
#   Yield_Curve_zscore_max_symlog_rolling_std_6m_lag_6m
#   Yield_Curve_zscore_max_symlog_zscore_12m
#   Yield_Curve_zscore_max_symlog_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_symlog_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_symlog_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_symlog_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_symlog_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_symlog_zscore_3m
#   Yield_Curve_zscore_max_symlog_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_symlog_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_symlog_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_symlog_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_symlog_zscore_3m_lag_6m
#   Yield_Curve_zscore_max_zscore_12m
#   Yield_Curve_zscore_max_zscore_12m_lag_12m
#   Yield_Curve_zscore_max_zscore_12m_lag_18m
#   Yield_Curve_zscore_max_zscore_12m_lag_1m
#   Yield_Curve_zscore_max_zscore_12m_lag_3m
#   Yield_Curve_zscore_max_zscore_12m_lag_6m
#   Yield_Curve_zscore_max_zscore_3m
#   Yield_Curve_zscore_max_zscore_3m_lag_12m
#   Yield_Curve_zscore_max_zscore_3m_lag_18m
#   Yield_Curve_zscore_max_zscore_3m_lag_1m
#   Yield_Curve_zscore_max_zscore_3m_lag_3m
#   Yield_Curve_zscore_max_zscore_3m_lag_6m

# %%
# Pivot to wide format
wide = df.pivot_table(index='date', columns='series_name', values='value', aggfunc='first')
wide = wide.sort_index()
print(f"Wide shape: {wide.shape}")
print(f"Date range: {wide.index.min()} to {wide.index.max()}")
print(f"\nNaN counts per feature (top 20):")
print(wide.isna().sum().sort_values(ascending=False).head(20))
# Out:
# Wide shape: (595, 8658)
# Date range: 1976-06-01 00:00:00 to 2025-12-01 00:00:00
#
# NaN counts per feature (top 20):
# series_name
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m_lag_6m          591
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m_lag_3m          591
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m                 591
# SP500_days_circuit_breaker_pct_chg_zscore_3m_lag_6m                 591
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m_lag_1m          591
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m_lag_18m         591
# SP500_days_circuit_breaker_symlog_pct_chg_zscore_3m_lag_12m         591
# SP500_days_circuit_breaker_pct_chg_zscore_3m_lag_3m                 591
# SP500_days_circuit_breaker_pct_chg_zscore_3m_lag_1m                 591
# SP500_days_circuit_breaker_pct_chg_zscore_3m_lag_18m                591
# SP500_days_circuit_breaker_pct_chg_zscore_3m_lag_12m                591
# SP500_days_circuit_breaker_pct_chg_zscore_3m                        591
# SP500_days_circuit_breaker_symlog_pct_chg_rolling_mean_3m_lag_1m    590
# SP500_days_circuit_breaker_symlog_pct_chg_rolling_mean_3m_lag_6m    590
# SP500_days_circuit_breaker_symlog_pct_chg_rolling_mean_3m_lag_3m    590
# SP500_days_circuit_breaker_pct_chg_rolling_mean_3m_lag_6m           590
# SP500_days_circuit_breaker_symlog_pct_chg_rolling_mean_3m           590
# SP500_days_circuit_breaker_pct_chg_rolling_mean_3m_lag_3m           590
# SP500_days_circuit_breaker_pct_chg_rolling_mean_3m_lag_1m           590
# SP500_days_circuit_breaker_pct_chg_rolling_mean_3m_lag_18m          590
# dtype: int64

# %% [markdown]
# ## 2. Define Feature Groups

# %%
# Group by series type
SERIES_GROUPS = {
    'VIX': [c for c in wide.columns if c.startswith('VIX_')],
    'SP500': [c for c in wide.columns if c.startswith('SP500_')],
    'Credit_Spreads': [c for c in wide.columns if c.startswith('Credit_Spreads_')],
    'Yield_Curve': [c for c in wide.columns if c.startswith('Yield_Curve_')],
    'Oil_Prices': [c for c in wide.columns if c.startswith('Oil_Prices_') or c.startswith('Oil_worst')],
    'ICSA': [c for c in wide.columns if c.startswith('ICSA_')],
    'ICNSA': [c for c in wide.columns if c.startswith('ICNSA_')],
    'CCSA': [c for c in wide.columns if c.startswith('CCSA_')],
    'CCNSA': [c for c in wide.columns if c.startswith('CCNSA_')],
    'Weekly_Econ_Index': [c for c in wide.columns if c.startswith('Weekly_Econ_Index_')],
    'Financial_Stress': [c for c in wide.columns if c.startswith('Financial_Stress_')],
}

# Group by transformation type
TRANSFORM_GROUPS = {
    'level': [c for c in wide.columns if not c.endswith('_diff') and 
              not c.endswith('_diff_zscore_12m') and not c.endswith('_diff_zscore_3m')],
    'diff': [c for c in wide.columns if c.endswith('_diff')],
    'diff_zscore_12m': [c for c in wide.columns if c.endswith('_diff_zscore_12m')],
    'diff_zscore_3m': [c for c in wide.columns if c.endswith('_diff_zscore_3m')],
}

print("Feature counts by series group:")
for group, feats in SERIES_GROUPS.items():
    print(f"  {group}: {len(feats)} features")

print(f"\nFeature counts by transformation:")
for ttype, feats in TRANSFORM_GROUPS.items():
    print(f"  {ttype}: {len(feats)} features")

print(f"\nTotal features: {len(wide.columns)}")
# Out:
# Feature counts by series group:
#   VIX: 972 features
#   SP500: 1734 features
#   Credit_Spreads: 1344 features
#   Yield_Curve: 1344 features
#   Oil_Prices: 960 features
#   ICSA: 0 features
#   ICNSA: 0 features
#   CCSA: 576 features
#   CCNSA: 576 features
#   Weekly_Econ_Index: 576 features
#   Financial_Stress: 576 features
#
# Feature counts by transformation:
#   level: 8388 features
#   diff: 90 features
#   diff_zscore_12m: 90 features
#   diff_zscore_3m: 90 features
#
# Total features: 8658

# %% [markdown]
# ## 3. VIF Helper Functions

# %%
def compute_group_vif(df_wide, feature_list, group_name, min_obs=50):
    """Compute VIF for a group of features."""
    cols = [c for c in feature_list if c in df_wide.columns]
    if len(cols) < 2:
        return pd.DataFrame()
    
    X = df_wide[cols].dropna()
    if len(X) < min_obs:
        print(f"  WARNING: {group_name} has only {len(X)} complete rows (need {min_obs})")
        # Try with less restrictive NaN handling
        X = df_wide[cols].fillna(method='ffill').dropna()
    
    # Drop zero-variance columns
    zero_var = X.columns[X.var() == 0]
    if len(zero_var) > 0:
        print(f"  Dropping {len(zero_var)} zero-variance cols: {list(zero_var)}")
        X = X.loc[:, X.var() > 0]
    
    if X.shape[1] < 2:
        return pd.DataFrame()
    
    # Replace inf with NaN and drop
    X = X.replace([np.inf, -np.inf], np.nan).dropna()
    
    X_const = X.copy()
    X_const['_const'] = 1.0
    
    vif_data = []
    for col in [c for c in X_const.columns if c != '_const']:
        try:
            vif = variance_inflation_factor(X_const.values, X_const.columns.get_loc(col))
            vif_data.append({'group': group_name, 'feature': col, 'VIF': round(vif, 2)})
        except Exception as e:
            vif_data.append({'group': group_name, 'feature': col, 'VIF': np.nan})
    
    return pd.DataFrame(vif_data).sort_values('VIF', ascending=False)


def iterative_vif_pruning(df_wide, features, threshold=10.0, protected=None, verbose=True):
    """Iteratively remove highest-VIF feature until all below threshold."""
    protected = protected or set()
    cols = [c for c in features if c in df_wide.columns]
    X = df_wide[cols].replace([np.inf, -np.inf], np.nan).dropna()
    X = X.loc[:, X.var() > 0]
    removed = []
    
    iteration = 0
    while len(X.columns) > 2:
        iteration += 1
        X_const = X.copy()
        X_const['_const'] = 1.0
        
        vifs = {}
        for col in [c for c in X_const.columns if c != '_const']:
            try:
                vifs[col] = variance_inflation_factor(X_const.values, X_const.columns.get_loc(col))
            except:
                vifs[col] = np.inf
        
        # Find highest VIF among non-protected features
        non_protected_vifs = {k: v for k, v in vifs.items() if k not in protected}
        if not non_protected_vifs:
            break
        
        max_col = max(non_protected_vifs, key=non_protected_vifs.get)
        max_vif = non_protected_vifs[max_col]
        
        if max_vif <= threshold:
            break
        
        X = X.drop(columns=[max_col])
        removed.append((max_col, round(max_vif, 2)))
        if verbose:
            print(f"  Iter {iteration}: Removed {max_col} (VIF={max_vif:.1f}), {len(X.columns)} features remain")
    
    return X.columns.tolist(), removed

# %% [markdown]
# ## 4. Within-Group VIF Analysis
#
# For each series group, compute VIF to see which transformations (level, diff, zscore) are redundant within the same indicator.

# %%
all_vif_results = []

for group_name, features in SERIES_GROUPS.items():
    print(f"\n{'='*60}")
    print(f"{group_name} ({len(features)} features)")
    print(f"{'='*60}")
    
    vif_df = compute_group_vif(wide, features, group_name)
    if not vif_df.empty:
        all_vif_results.append(vif_df)
        print(vif_df.to_string(index=False))
        
        high_vif = vif_df[vif_df['VIF'] > 10]
        if len(high_vif) > 0:
            print(f"\n  >> {len(high_vif)} features with VIF > 10 (multicollinearity concern)")
        else:
            print(f"\n  >> All features have VIF <= 10 (OK)")
    else:
        print("  (not enough features for VIF)")

within_group_vif = pd.concat(all_vif_results, ignore_index=True) if all_vif_results else pd.DataFrame()
# Out:
# ============================================================
# VIX (972 features)
# ============================================================
# group                                                 feature  VIF
#   VIX                                           VIX_30d_spike  inf
#   VIX                         VIX_mean_symlog_chg_12m_lag_12m  inf
#   VIX                  VIX_mean_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX                  VIX_mean_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                             VIX_mean_pct_chg_zscore_12m  inf
#   VIX                     VIX_mean_pct_chg_zscore_12m_lag_12m  inf
#   VIX                     VIX_mean_pct_chg_zscore_12m_lag_18m  inf
#   VIX                      VIX_mean_pct_chg_zscore_12m_lag_1m  inf
#   VIX                      VIX_mean_pct_chg_zscore_12m_lag_3m  inf
#   VIX                      VIX_mean_pct_chg_zscore_12m_lag_6m  inf
#   VIX                              VIX_mean_pct_chg_zscore_3m  inf
#   VIX                      VIX_mean_pct_chg_zscore_3m_lag_12m  inf
#   VIX                      VIX_mean_pct_chg_zscore_3m_lag_18m  inf
#   VIX                       VIX_mean_pct_chg_zscore_3m_lag_1m  inf
#   VIX                       VIX_mean_pct_chg_zscore_3m_lag_3m  inf
#   VIX                       VIX_mean_pct_chg_zscore_3m_lag_6m  inf
#   VIX                                VIX_mean_rolling_mean_3m  inf
#   VIX                        VIX_mean_rolling_mean_3m_lag_12m  inf
#   VIX                        VIX_mean_rolling_mean_3m_lag_18m  inf
#   VIX                         VIX_mean_rolling_mean_3m_lag_1m  inf
#   VIX                         VIX_mean_rolling_mean_3m_lag_3m  inf
#   VIX                         VIX_mean_rolling_mean_3m_lag_6m  inf
#   VIX                                 VIX_mean_rolling_std_6m  inf
#   VIX                         VIX_mean_rolling_std_6m_lag_12m  inf
#   VIX                         VIX_mean_rolling_std_6m_lag_18m  inf
#   VIX                          VIX_mean_rolling_std_6m_lag_1m  inf
#   VIX                          VIX_mean_rolling_std_6m_lag_3m  inf
#   VIX                          VIX_mean_rolling_std_6m_lag_6m  inf
#   VIX                                         VIX_mean_symlog  inf
#   VIX                  VIX_mean_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX                 VIX_mean_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX                 VIX_mean_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX                                         VIX_mean_lag_3m  inf
#   VIX                         VIX_mean_diff_zscore_12m_lag_1m  inf
#   VIX                         VIX_mean_diff_zscore_12m_lag_3m  inf
#   VIX                         VIX_mean_diff_zscore_12m_lag_6m  inf
#   VIX                                 VIX_mean_diff_zscore_3m  inf
#   VIX                         VIX_mean_diff_zscore_3m_lag_12m  inf
#   VIX                         VIX_mean_diff_zscore_3m_lag_18m  inf
#   VIX                          VIX_mean_diff_zscore_3m_lag_1m  inf
#   VIX                          VIX_mean_diff_zscore_3m_lag_3m  inf
#   VIX                          VIX_mean_diff_zscore_3m_lag_6m  inf
#   VIX                                        VIX_mean_lag_12m  inf
#   VIX                                        VIX_mean_lag_18m  inf
#   VIX                                         VIX_mean_lag_1m  inf
#   VIX                                         VIX_mean_lag_6m  inf
#   VIX                         VIX_mean_pct_chg_rolling_std_6m  inf
#   VIX                                        VIX_mean_pct_chg  inf
#   VIX                                VIX_mean_pct_chg_lag_12m  inf
#   VIX                                VIX_mean_pct_chg_lag_18m  inf
#   VIX                                 VIX_mean_pct_chg_lag_1m  inf
#   VIX                                 VIX_mean_pct_chg_lag_3m  inf
#   VIX                                 VIX_mean_pct_chg_lag_6m  inf
#   VIX                        VIX_mean_pct_chg_rolling_mean_3m  inf
#   VIX                VIX_mean_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX                VIX_mean_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX                 VIX_mean_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX                 VIX_mean_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX                 VIX_mean_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX                                 VIX_mean_symlog_chg_12m  inf
#   VIX                         VIX_mean_symlog_chg_12m_lag_18m  inf
#   VIX                        VIX_mean_diff_zscore_12m_lag_12m  inf
#   VIX                          VIX_mean_symlog_chg_12m_lag_1m  inf
#   VIX                   VIX_mean_symlog_diff_zscore_3m_lag_3m  inf
#   VIX                   VIX_mean_symlog_diff_zscore_3m_lag_6m  inf
#   VIX                                 VIX_mean_symlog_lag_12m  inf
#   VIX                                 VIX_mean_symlog_lag_18m  inf
#   VIX                                  VIX_mean_symlog_lag_1m  inf
#   VIX                                  VIX_mean_symlog_lag_3m  inf
#   VIX                                  VIX_mean_symlog_lag_6m  inf
#   VIX                                 VIX_mean_symlog_pct_chg  inf
#   VIX                         VIX_mean_symlog_pct_chg_lag_12m  inf
#   VIX                         VIX_mean_symlog_pct_chg_lag_18m  inf
#   VIX                          VIX_mean_symlog_pct_chg_lag_1m  inf
#   VIX                          VIX_mean_symlog_pct_chg_lag_3m  inf
#   VIX                          VIX_mean_symlog_pct_chg_lag_6m  inf
#   VIX                 VIX_mean_symlog_pct_chg_rolling_mean_3m  inf
#   VIX         VIX_mean_symlog_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX         VIX_mean_symlog_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX          VIX_mean_symlog_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX          VIX_mean_symlog_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX          VIX_mean_symlog_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX                  VIX_mean_symlog_pct_chg_rolling_std_6m  inf
#   VIX          VIX_mean_symlog_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX          VIX_mean_symlog_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX           VIX_mean_symlog_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX           VIX_mean_symlog_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX           VIX_mean_symlog_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                      VIX_mean_symlog_pct_chg_zscore_12m  inf
#   VIX              VIX_mean_symlog_pct_chg_zscore_12m_lag_12m  inf
#   VIX                   VIX_mean_symlog_diff_zscore_3m_lag_1m  inf
#   VIX                  VIX_mean_symlog_diff_zscore_3m_lag_18m  inf
#   VIX                  VIX_mean_symlog_diff_zscore_3m_lag_12m  inf
#   VIX                           VIX_mean_symlog_chg_6m_lag_3m  inf
#   VIX                          VIX_mean_symlog_chg_12m_lag_3m  inf
#   VIX                          VIX_mean_symlog_chg_12m_lag_6m  inf
#   VIX                                  VIX_mean_symlog_chg_3m  inf
#   VIX                          VIX_mean_symlog_chg_3m_lag_12m  inf
#   VIX                          VIX_mean_symlog_chg_3m_lag_18m  inf
#   VIX                           VIX_mean_symlog_chg_3m_lag_1m  inf
#   VIX                           VIX_mean_symlog_chg_3m_lag_3m  inf
#   VIX                           VIX_mean_symlog_chg_3m_lag_6m  inf
#   VIX                                  VIX_mean_symlog_chg_6m  inf
#   VIX                          VIX_mean_symlog_chg_6m_lag_12m  inf
#   VIX                          VIX_mean_symlog_chg_6m_lag_18m  inf
#   VIX                           VIX_mean_symlog_chg_6m_lag_1m  inf
#   VIX                           VIX_mean_symlog_chg_6m_lag_6m  inf
#   VIX                          VIX_mean_symlog_diff_zscore_3m  inf
#   VIX                                    VIX_mean_symlog_diff  inf
#   VIX                            VIX_mean_symlog_diff_lag_12m  inf
#   VIX                            VIX_mean_symlog_diff_lag_18m  inf
#   VIX                             VIX_mean_symlog_diff_lag_1m  inf
#   VIX                             VIX_mean_symlog_diff_lag_3m  inf
#   VIX                             VIX_mean_symlog_diff_lag_6m  inf
#   VIX                         VIX_mean_symlog_diff_zscore_12m  inf
#   VIX                 VIX_mean_symlog_diff_zscore_12m_lag_12m  inf
#   VIX                 VIX_mean_symlog_diff_zscore_12m_lag_18m  inf
#   VIX                  VIX_mean_symlog_diff_zscore_12m_lag_1m  inf
#   VIX                  VIX_mean_symlog_diff_zscore_12m_lag_3m  inf
#   VIX                  VIX_mean_symlog_diff_zscore_12m_lag_6m  inf
#   VIX                        VIX_mean_diff_zscore_12m_lag_18m  inf
#   VIX                                VIX_mean_diff_zscore_12m  inf
#   VIX                                   VIX_30d_spike_chg_12m  inf
#   VIX                          VIX_max_symlog_rolling_mean_3m  inf
#   VIX                          VIX_max_symlog_pct_chg_lag_18m  inf
#   VIX                           VIX_max_symlog_pct_chg_lag_1m  inf
#   VIX                           VIX_max_symlog_pct_chg_lag_3m  inf
#   VIX                           VIX_max_symlog_pct_chg_lag_6m  inf
#   VIX                  VIX_max_symlog_pct_chg_rolling_mean_3m  inf
#   VIX          VIX_max_symlog_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX          VIX_max_symlog_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX           VIX_max_symlog_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX           VIX_max_symlog_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX           VIX_max_symlog_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX                   VIX_max_symlog_pct_chg_rolling_std_6m  inf
#   VIX           VIX_max_symlog_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX           VIX_max_symlog_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX            VIX_max_symlog_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX            VIX_max_symlog_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX            VIX_max_symlog_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                       VIX_max_symlog_pct_chg_zscore_12m  inf
#   VIX               VIX_max_symlog_pct_chg_zscore_12m_lag_12m  inf
#   VIX               VIX_max_symlog_pct_chg_zscore_12m_lag_18m  inf
#   VIX                VIX_max_symlog_pct_chg_zscore_12m_lag_1m  inf
#   VIX                VIX_max_symlog_pct_chg_zscore_12m_lag_3m  inf
#   VIX                VIX_max_symlog_pct_chg_zscore_12m_lag_6m  inf
#   VIX                        VIX_max_symlog_pct_chg_zscore_3m  inf
#   VIX                VIX_max_symlog_pct_chg_zscore_3m_lag_12m  inf
#   VIX                VIX_max_symlog_pct_chg_zscore_3m_lag_18m  inf
#   VIX                 VIX_max_symlog_pct_chg_zscore_3m_lag_1m  inf
#   VIX                 VIX_max_symlog_pct_chg_zscore_3m_lag_3m  inf
#   VIX                          VIX_max_symlog_pct_chg_lag_12m  inf
#   VIX                                  VIX_max_symlog_pct_chg  inf
#   VIX                                   VIX_max_symlog_lag_6m  inf
#   VIX                  VIX_max_symlog_diff_zscore_12m_lag_12m  inf
#   VIX                           VIX_max_symlog_chg_6m_lag_12m  inf
#   VIX                           VIX_max_symlog_chg_6m_lag_18m  inf
#   VIX                            VIX_max_symlog_chg_6m_lag_1m  inf
#   VIX                            VIX_max_symlog_chg_6m_lag_3m  inf
#   VIX                            VIX_max_symlog_chg_6m_lag_6m  inf
#   VIX                                     VIX_max_symlog_diff  inf
#   VIX                             VIX_max_symlog_diff_lag_12m  inf
#   VIX                             VIX_max_symlog_diff_lag_18m  inf
#   VIX                              VIX_max_symlog_diff_lag_1m  inf
#   VIX                              VIX_max_symlog_diff_lag_3m  inf
#   VIX                              VIX_max_symlog_diff_lag_6m  inf
#   VIX                          VIX_max_symlog_diff_zscore_12m  inf
#   VIX                  VIX_max_symlog_diff_zscore_12m_lag_18m  inf
#   VIX                                   VIX_max_symlog_lag_3m  inf
#   VIX                   VIX_max_symlog_diff_zscore_12m_lag_1m  inf
#   VIX                   VIX_max_symlog_diff_zscore_12m_lag_3m  inf
#   VIX                   VIX_max_symlog_diff_zscore_12m_lag_6m  inf
#   VIX                           VIX_max_symlog_diff_zscore_3m  inf
#   VIX                   VIX_max_symlog_diff_zscore_3m_lag_12m  inf
#   VIX                   VIX_max_symlog_diff_zscore_3m_lag_18m  inf
#   VIX                    VIX_max_symlog_diff_zscore_3m_lag_1m  inf
#   VIX                    VIX_max_symlog_diff_zscore_3m_lag_3m  inf
#   VIX                    VIX_max_symlog_diff_zscore_3m_lag_6m  inf
#   VIX                                  VIX_max_symlog_lag_12m  inf
#   VIX                                  VIX_max_symlog_lag_18m  inf
#   VIX                                   VIX_max_symlog_lag_1m  inf
#   VIX                 VIX_max_symlog_pct_chg_zscore_3m_lag_6m  inf
#   VIX                  VIX_max_symlog_rolling_mean_3m_lag_12m  inf
#   VIX                                    VIX_mean_diff_lag_6m  inf
#   VIX                  VIX_max_symlog_rolling_mean_3m_lag_18m  inf
#   VIX                                VIX_max_zscore_3m_lag_1m  inf
#   VIX                                VIX_max_zscore_3m_lag_3m  inf
#   VIX                                VIX_max_zscore_3m_lag_6m  inf
#   VIX                                                VIX_mean  inf
#   VIX                                        VIX_mean_chg_12m  inf
#   VIX                                VIX_mean_chg_12m_lag_12m  inf
#   VIX                                VIX_mean_chg_12m_lag_18m  inf
#   VIX                                 VIX_mean_chg_12m_lag_1m  inf
#   VIX                                 VIX_mean_chg_12m_lag_3m  inf
#   VIX                                 VIX_mean_chg_12m_lag_6m  inf
#   VIX                                         VIX_mean_chg_3m  inf
#   VIX                                 VIX_mean_chg_3m_lag_12m  inf
#   VIX                                 VIX_mean_chg_3m_lag_18m  inf
#   VIX                                  VIX_mean_chg_3m_lag_1m  inf
#   VIX                                  VIX_mean_chg_3m_lag_3m  inf
#   VIX                                  VIX_mean_chg_3m_lag_6m  inf
#   VIX                                         VIX_mean_chg_6m  inf
#   VIX                                 VIX_mean_chg_6m_lag_12m  inf
#   VIX                                 VIX_mean_chg_6m_lag_18m  inf
#   VIX                                  VIX_mean_chg_6m_lag_1m  inf
#   VIX                                  VIX_mean_chg_6m_lag_3m  inf
#   VIX                                  VIX_mean_chg_6m_lag_6m  inf
#   VIX                                           VIX_mean_diff  inf
#   VIX                                   VIX_mean_diff_lag_12m  inf
#   VIX                                   VIX_mean_diff_lag_18m  inf
#   VIX                                    VIX_mean_diff_lag_1m  inf
#   VIX                                    VIX_mean_diff_lag_3m  inf
#   VIX                               VIX_max_zscore_3m_lag_18m  inf
#   VIX                               VIX_max_zscore_3m_lag_12m  inf
#   VIX                                       VIX_max_zscore_3m  inf
#   VIX                        VIX_max_symlog_zscore_12m_lag_1m  inf
#   VIX                   VIX_max_symlog_rolling_mean_3m_lag_1m  inf
#   VIX                   VIX_max_symlog_rolling_mean_3m_lag_3m  inf
#   VIX                   VIX_max_symlog_rolling_mean_3m_lag_6m  inf
#   VIX                           VIX_max_symlog_rolling_std_6m  inf
#   VIX                   VIX_max_symlog_rolling_std_6m_lag_12m  inf
#   VIX                   VIX_max_symlog_rolling_std_6m_lag_18m  inf
#   VIX                    VIX_max_symlog_rolling_std_6m_lag_1m  inf
#   VIX                    VIX_max_symlog_rolling_std_6m_lag_3m  inf
#   VIX                    VIX_max_symlog_rolling_std_6m_lag_6m  inf
#   VIX                               VIX_max_symlog_zscore_12m  inf
#   VIX                       VIX_max_symlog_zscore_12m_lag_12m  inf
#   VIX                       VIX_max_symlog_zscore_12m_lag_18m  inf
#   VIX                        VIX_max_symlog_zscore_12m_lag_3m  inf
#   VIX                               VIX_max_zscore_12m_lag_6m  inf
#   VIX                        VIX_max_symlog_zscore_12m_lag_6m  inf
#   VIX                                VIX_max_symlog_zscore_3m  inf
#   VIX                        VIX_max_symlog_zscore_3m_lag_12m  inf
#   VIX                        VIX_max_symlog_zscore_3m_lag_18m  inf
#   VIX                         VIX_max_symlog_zscore_3m_lag_1m  inf
#   VIX                         VIX_max_symlog_zscore_3m_lag_3m  inf
#   VIX                         VIX_max_symlog_zscore_3m_lag_6m  inf
#   VIX                                      VIX_max_zscore_12m  inf
#   VIX                              VIX_max_zscore_12m_lag_12m  inf
#   VIX                              VIX_max_zscore_12m_lag_18m  inf
#   VIX                               VIX_max_zscore_12m_lag_1m  inf
#   VIX                               VIX_max_zscore_12m_lag_3m  inf
#   VIX              VIX_mean_symlog_pct_chg_zscore_12m_lag_18m  inf
#   VIX               VIX_mean_symlog_pct_chg_zscore_12m_lag_1m  inf
#   VIX               VIX_mean_symlog_pct_chg_zscore_12m_lag_3m  inf
#   VIX                    VIX_volatility_symlog_pct_chg_lag_6m  inf
#   VIX                              VIX_volatility_symlog_diff  inf
#   VIX                      VIX_volatility_symlog_diff_lag_12m  inf
#   VIX                      VIX_volatility_symlog_diff_lag_18m  inf
#   VIX                       VIX_volatility_symlog_diff_lag_1m  inf
#   VIX                       VIX_volatility_symlog_diff_lag_3m  inf
#   VIX                       VIX_volatility_symlog_diff_lag_6m  inf
#   VIX                   VIX_volatility_symlog_diff_zscore_12m  inf
#   VIX           VIX_volatility_symlog_diff_zscore_12m_lag_12m  inf
#   VIX           VIX_volatility_symlog_diff_zscore_12m_lag_18m  inf
#   VIX            VIX_volatility_symlog_diff_zscore_12m_lag_1m  inf
#   VIX            VIX_volatility_symlog_diff_zscore_12m_lag_3m  inf
#   VIX            VIX_volatility_symlog_diff_zscore_12m_lag_6m  inf
#   VIX                    VIX_volatility_symlog_diff_zscore_3m  inf
#   VIX            VIX_volatility_symlog_diff_zscore_3m_lag_12m  inf
#   VIX            VIX_volatility_symlog_diff_zscore_3m_lag_18m  inf
#   VIX             VIX_volatility_symlog_diff_zscore_3m_lag_1m  inf
#   VIX             VIX_volatility_symlog_diff_zscore_3m_lag_3m  inf
#   VIX             VIX_volatility_symlog_diff_zscore_3m_lag_6m  inf
#   VIX                           VIX_volatility_symlog_lag_12m  inf
#   VIX                           VIX_volatility_symlog_lag_18m  inf
#   VIX                            VIX_volatility_symlog_lag_1m  inf
#   VIX                            VIX_volatility_symlog_lag_3m  inf
#   VIX                            VIX_volatility_symlog_lag_6m  inf
#   VIX                           VIX_volatility_symlog_pct_chg  inf
#   VIX                   VIX_volatility_symlog_pct_chg_lag_12m  inf
#   VIX                   VIX_volatility_symlog_pct_chg_lag_18m  inf
#   VIX                    VIX_volatility_symlog_pct_chg_lag_1m  inf
#   VIX                     VIX_volatility_symlog_chg_6m_lag_6m  inf
#   VIX                     VIX_volatility_symlog_chg_6m_lag_3m  inf
#   VIX                     VIX_volatility_symlog_chg_6m_lag_1m  inf
#   VIX                           VIX_volatility_symlog_chg_12m  inf
#   VIX                  VIX_volatility_rolling_mean_3m_lag_12m  inf
#   VIX                  VIX_volatility_rolling_mean_3m_lag_18m  inf
#   VIX                   VIX_volatility_rolling_mean_3m_lag_1m  inf
#   VIX                   VIX_volatility_rolling_mean_3m_lag_3m  inf
#   VIX                   VIX_volatility_rolling_mean_3m_lag_6m  inf
#   VIX                           VIX_volatility_rolling_std_6m  inf
#   VIX                   VIX_volatility_rolling_std_6m_lag_12m  inf
#   VIX                   VIX_volatility_rolling_std_6m_lag_18m  inf
#   VIX                    VIX_volatility_rolling_std_6m_lag_1m  inf
#   VIX                    VIX_volatility_rolling_std_6m_lag_3m  inf
#   VIX                    VIX_volatility_rolling_std_6m_lag_6m  inf
#   VIX                                   VIX_volatility_symlog  inf
#   VIX                   VIX_volatility_symlog_chg_12m_lag_12m  inf
#   VIX                    VIX_volatility_symlog_chg_6m_lag_18m  inf
#   VIX                   VIX_volatility_symlog_chg_12m_lag_18m  inf
#   VIX                    VIX_volatility_symlog_chg_12m_lag_1m  inf
#   VIX                    VIX_volatility_symlog_chg_12m_lag_3m  inf
#   VIX                    VIX_volatility_symlog_chg_12m_lag_6m  inf
#   VIX                            VIX_volatility_symlog_chg_3m  inf
#   VIX                    VIX_volatility_symlog_chg_3m_lag_12m  inf
#   VIX                    VIX_volatility_symlog_chg_3m_lag_18m  inf
#   VIX                     VIX_volatility_symlog_chg_3m_lag_1m  inf
#   VIX                     VIX_volatility_symlog_chg_3m_lag_3m  inf
#   VIX                     VIX_volatility_symlog_chg_3m_lag_6m  inf
#   VIX                            VIX_volatility_symlog_chg_6m  inf
#   VIX                    VIX_volatility_symlog_chg_6m_lag_12m  inf
#   VIX                    VIX_volatility_symlog_pct_chg_lag_3m  inf
#   VIX           VIX_volatility_symlog_pct_chg_rolling_mean_3m  inf
#   VIX               VIX_mean_symlog_pct_chg_zscore_12m_lag_6m  inf
#   VIX   VIX_volatility_symlog_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX            VIX_volatility_symlog_rolling_std_6m_lag_18m  inf
#   VIX             VIX_volatility_symlog_rolling_std_6m_lag_1m  inf
#   VIX             VIX_volatility_symlog_rolling_std_6m_lag_3m  inf
#   VIX             VIX_volatility_symlog_rolling_std_6m_lag_6m  inf
#   VIX                        VIX_volatility_symlog_zscore_12m  inf
#   VIX                VIX_volatility_symlog_zscore_12m_lag_12m  inf
#   VIX                VIX_volatility_symlog_zscore_12m_lag_18m  inf
#   VIX                 VIX_volatility_symlog_zscore_12m_lag_1m  inf
#   VIX                 VIX_volatility_symlog_zscore_12m_lag_3m  inf
#   VIX                 VIX_volatility_symlog_zscore_12m_lag_6m  inf
#   VIX                         VIX_volatility_symlog_zscore_3m  inf
#   VIX                 VIX_volatility_symlog_zscore_3m_lag_12m  inf
#   VIX                 VIX_volatility_symlog_zscore_3m_lag_18m  inf
#   VIX                  VIX_volatility_symlog_zscore_3m_lag_1m  inf
#   VIX                  VIX_volatility_symlog_zscore_3m_lag_3m  inf
#   VIX                  VIX_volatility_symlog_zscore_3m_lag_6m  inf
#   VIX                               VIX_volatility_zscore_12m  inf
#   VIX                       VIX_volatility_zscore_12m_lag_12m  inf
#   VIX                       VIX_volatility_zscore_12m_lag_18m  inf
#   VIX                        VIX_volatility_zscore_12m_lag_1m  inf
#   VIX                        VIX_volatility_zscore_12m_lag_3m  inf
#   VIX                        VIX_volatility_zscore_12m_lag_6m  inf
#   VIX                                VIX_volatility_zscore_3m  inf
#   VIX                        VIX_volatility_zscore_3m_lag_12m  inf
#   VIX                        VIX_volatility_zscore_3m_lag_18m  inf
#   VIX                         VIX_volatility_zscore_3m_lag_1m  inf
#   VIX                         VIX_volatility_zscore_3m_lag_3m  inf
#   VIX            VIX_volatility_symlog_rolling_std_6m_lag_12m  inf
#   VIX                    VIX_volatility_symlog_rolling_std_6m  inf
#   VIX            VIX_volatility_symlog_rolling_mean_3m_lag_6m  inf
#   VIX        VIX_volatility_symlog_pct_chg_zscore_12m_lag_18m  inf
#   VIX   VIX_volatility_symlog_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX    VIX_volatility_symlog_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX    VIX_volatility_symlog_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX    VIX_volatility_symlog_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX            VIX_volatility_symlog_pct_chg_rolling_std_6m  inf
#   VIX    VIX_volatility_symlog_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX    VIX_volatility_symlog_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX     VIX_volatility_symlog_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX     VIX_volatility_symlog_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX     VIX_volatility_symlog_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                VIX_volatility_symlog_pct_chg_zscore_12m  inf
#   VIX        VIX_volatility_symlog_pct_chg_zscore_12m_lag_12m  inf
#   VIX         VIX_volatility_symlog_pct_chg_zscore_12m_lag_1m  inf
#   VIX            VIX_volatility_symlog_rolling_mean_3m_lag_3m  inf
#   VIX         VIX_volatility_symlog_pct_chg_zscore_12m_lag_3m  inf
#   VIX         VIX_volatility_symlog_pct_chg_zscore_12m_lag_6m  inf
#   VIX                 VIX_volatility_symlog_pct_chg_zscore_3m  inf
#   VIX         VIX_volatility_symlog_pct_chg_zscore_3m_lag_12m  inf
#   VIX         VIX_volatility_symlog_pct_chg_zscore_3m_lag_18m  inf
#   VIX          VIX_volatility_symlog_pct_chg_zscore_3m_lag_1m  inf
#   VIX          VIX_volatility_symlog_pct_chg_zscore_3m_lag_3m  inf
#   VIX          VIX_volatility_symlog_pct_chg_zscore_3m_lag_6m  inf
#   VIX                   VIX_volatility_symlog_rolling_mean_3m  inf
#   VIX           VIX_volatility_symlog_rolling_mean_3m_lag_12m  inf
#   VIX           VIX_volatility_symlog_rolling_mean_3m_lag_18m  inf
#   VIX            VIX_volatility_symlog_rolling_mean_3m_lag_1m  inf
#   VIX                          VIX_volatility_rolling_mean_3m  inf
#   VIX                 VIX_volatility_pct_chg_zscore_3m_lag_6m  inf
#   VIX                 VIX_volatility_pct_chg_zscore_3m_lag_3m  inf
#   VIX                 VIX_volatility_pct_chg_zscore_3m_lag_1m  inf
#   VIX                                     VIX_mean_zscore_12m  inf
#   VIX                             VIX_mean_zscore_12m_lag_12m  inf
#   VIX                             VIX_mean_zscore_12m_lag_18m  inf
#   VIX                              VIX_mean_zscore_12m_lag_1m  inf
#   VIX                              VIX_mean_zscore_12m_lag_3m  inf
#   VIX                              VIX_mean_zscore_12m_lag_6m  inf
#   VIX                                      VIX_mean_zscore_3m  inf
#   VIX                              VIX_mean_zscore_3m_lag_12m  inf
#   VIX                              VIX_mean_zscore_3m_lag_18m  inf
#   VIX                               VIX_mean_zscore_3m_lag_1m  inf
#   VIX                               VIX_mean_zscore_3m_lag_3m  inf
#   VIX                               VIX_mean_zscore_3m_lag_6m  inf
#   VIX                                        VIX_panic_regime  inf
#   VIX                                VIX_panic_regime_lag_12m  inf
#   VIX                                VIX_panic_regime_lag_18m  inf
#   VIX                                 VIX_panic_regime_lag_1m  inf
#   VIX                                 VIX_panic_regime_lag_3m  inf
#   VIX                                 VIX_panic_regime_lag_6m  inf
#   VIX                                          VIX_volatility  inf
#   VIX                                  VIX_volatility_chg_12m  inf
#   VIX                          VIX_volatility_chg_12m_lag_12m  inf
#   VIX                          VIX_volatility_chg_12m_lag_18m  inf
#   VIX                           VIX_volatility_chg_12m_lag_1m  inf
#   VIX                           VIX_volatility_chg_12m_lag_3m  inf
#   VIX                           VIX_volatility_chg_12m_lag_6m  inf
#   VIX                                   VIX_volatility_chg_3m  inf
#   VIX                           VIX_volatility_chg_3m_lag_12m  inf
#   VIX                        VIX_mean_symlog_zscore_3m_lag_6m  inf
#   VIX                        VIX_mean_symlog_zscore_3m_lag_3m  inf
#   VIX                        VIX_mean_symlog_zscore_3m_lag_1m  inf
#   VIX                          VIX_mean_symlog_rolling_std_6m  inf
#   VIX                       VIX_mean_symlog_pct_chg_zscore_3m  inf
#   VIX               VIX_mean_symlog_pct_chg_zscore_3m_lag_12m  inf
#   VIX               VIX_mean_symlog_pct_chg_zscore_3m_lag_18m  inf
#   VIX                VIX_mean_symlog_pct_chg_zscore_3m_lag_1m  inf
#   VIX                VIX_mean_symlog_pct_chg_zscore_3m_lag_3m  inf
#   VIX                VIX_mean_symlog_pct_chg_zscore_3m_lag_6m  inf
#   VIX                         VIX_mean_symlog_rolling_mean_3m  inf
#   VIX                 VIX_mean_symlog_rolling_mean_3m_lag_12m  inf
#   VIX                 VIX_mean_symlog_rolling_mean_3m_lag_18m  inf
#   VIX                  VIX_mean_symlog_rolling_mean_3m_lag_1m  inf
#   VIX                  VIX_mean_symlog_rolling_mean_3m_lag_3m  inf
#   VIX                  VIX_mean_symlog_rolling_mean_3m_lag_6m  inf
#   VIX                  VIX_mean_symlog_rolling_std_6m_lag_12m  inf
#   VIX                       VIX_mean_symlog_zscore_3m_lag_18m  inf
#   VIX                  VIX_mean_symlog_rolling_std_6m_lag_18m  inf
#   VIX                   VIX_mean_symlog_rolling_std_6m_lag_1m  inf
#   VIX                   VIX_mean_symlog_rolling_std_6m_lag_3m  inf
#   VIX                   VIX_mean_symlog_rolling_std_6m_lag_6m  inf
#   VIX                              VIX_mean_symlog_zscore_12m  inf
#   VIX                      VIX_mean_symlog_zscore_12m_lag_12m  inf
#   VIX                      VIX_mean_symlog_zscore_12m_lag_18m  inf
#   VIX                       VIX_mean_symlog_zscore_12m_lag_1m  inf
#   VIX                       VIX_mean_symlog_zscore_12m_lag_3m  inf
#   VIX                       VIX_mean_symlog_zscore_12m_lag_6m  inf
#   VIX                               VIX_mean_symlog_zscore_3m  inf
#   VIX                       VIX_mean_symlog_zscore_3m_lag_12m  inf
#   VIX                           VIX_volatility_chg_3m_lag_18m  inf
#   VIX                            VIX_volatility_chg_3m_lag_1m  inf
#   VIX                            VIX_volatility_chg_3m_lag_3m  inf
#   VIX           VIX_volatility_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX                          VIX_volatility_pct_chg_lag_12m  inf
#   VIX                          VIX_volatility_pct_chg_lag_18m  inf
#   VIX                           VIX_volatility_pct_chg_lag_1m  inf
#   VIX                           VIX_volatility_pct_chg_lag_3m  inf
#   VIX                           VIX_volatility_pct_chg_lag_6m  inf
#   VIX                  VIX_volatility_pct_chg_rolling_mean_3m  inf
#   VIX          VIX_volatility_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX          VIX_volatility_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX           VIX_volatility_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX           VIX_volatility_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX           VIX_volatility_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX                   VIX_volatility_pct_chg_rolling_std_6m  inf
#   VIX           VIX_volatility_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX                                   VIX_volatility_lag_6m  inf
#   VIX            VIX_volatility_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX            VIX_volatility_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX            VIX_volatility_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                       VIX_volatility_pct_chg_zscore_12m  inf
#   VIX               VIX_volatility_pct_chg_zscore_12m_lag_12m  inf
#   VIX               VIX_volatility_pct_chg_zscore_12m_lag_18m  inf
#   VIX                VIX_volatility_pct_chg_zscore_12m_lag_1m  inf
#   VIX                VIX_volatility_pct_chg_zscore_12m_lag_3m  inf
#   VIX                VIX_volatility_pct_chg_zscore_12m_lag_6m  inf
#   VIX                        VIX_volatility_pct_chg_zscore_3m  inf
#   VIX                VIX_volatility_pct_chg_zscore_3m_lag_12m  inf
#   VIX                VIX_volatility_pct_chg_zscore_3m_lag_18m  inf
#   VIX                                  VIX_volatility_pct_chg  inf
#   VIX                                   VIX_volatility_lag_3m  inf
#   VIX                            VIX_volatility_chg_3m_lag_6m  inf
#   VIX                          VIX_volatility_diff_zscore_12m  inf
#   VIX                                   VIX_volatility_chg_6m  inf
#   VIX                           VIX_volatility_chg_6m_lag_12m  inf
#   VIX                           VIX_volatility_chg_6m_lag_18m  inf
#   VIX                            VIX_volatility_chg_6m_lag_1m  inf
#   VIX                            VIX_volatility_chg_6m_lag_3m  inf
#   VIX                            VIX_volatility_chg_6m_lag_6m  inf
#   VIX                                     VIX_volatility_diff  inf
#   VIX                             VIX_volatility_diff_lag_12m  inf
#   VIX                             VIX_volatility_diff_lag_18m  inf
#   VIX                              VIX_volatility_diff_lag_1m  inf
#   VIX                              VIX_volatility_diff_lag_3m  inf
#   VIX                              VIX_volatility_diff_lag_6m  inf
#   VIX                  VIX_volatility_diff_zscore_12m_lag_12m  inf
#   VIX                                   VIX_volatility_lag_1m  inf
#   VIX                  VIX_volatility_diff_zscore_12m_lag_18m  inf
#   VIX                   VIX_volatility_diff_zscore_12m_lag_1m  inf
#   VIX                   VIX_volatility_diff_zscore_12m_lag_3m  inf
#   VIX                   VIX_volatility_diff_zscore_12m_lag_6m  inf
#   VIX                           VIX_volatility_diff_zscore_3m  inf
#   VIX                   VIX_volatility_diff_zscore_3m_lag_12m  inf
#   VIX                   VIX_volatility_diff_zscore_3m_lag_18m  inf
#   VIX                    VIX_volatility_diff_zscore_3m_lag_1m  inf
#   VIX                    VIX_volatility_diff_zscore_3m_lag_3m  inf
#   VIX                    VIX_volatility_diff_zscore_3m_lag_6m  inf
#   VIX                                  VIX_volatility_lag_12m  inf
#   VIX                                  VIX_volatility_lag_18m  inf
#   VIX                                   VIX_max_symlog_chg_6m  inf
#   VIX                            VIX_max_symlog_chg_3m_lag_6m  inf
#   VIX                            VIX_max_symlog_chg_3m_lag_3m  inf
#   VIX                        VIX_30d_spike_zscore_12m_lag_12m  inf
#   VIX           VIX_30d_spike_symlog_pct_chg_zscore_3m_lag_1m  inf
#   VIX           VIX_30d_spike_symlog_pct_chg_zscore_3m_lag_3m  inf
#   VIX           VIX_30d_spike_symlog_pct_chg_zscore_3m_lag_6m  inf
#   VIX                    VIX_30d_spike_symlog_rolling_mean_3m  inf
#   VIX            VIX_30d_spike_symlog_rolling_mean_3m_lag_12m  inf
#   VIX            VIX_30d_spike_symlog_rolling_mean_3m_lag_18m  inf
#   VIX             VIX_30d_spike_symlog_rolling_mean_3m_lag_1m  inf
#   VIX             VIX_30d_spike_symlog_rolling_mean_3m_lag_3m  inf
#   VIX             VIX_30d_spike_symlog_rolling_mean_3m_lag_6m  inf
#   VIX                     VIX_30d_spike_symlog_rolling_std_6m  inf
#   VIX             VIX_30d_spike_symlog_rolling_std_6m_lag_12m  inf
#   VIX             VIX_30d_spike_symlog_rolling_std_6m_lag_18m  inf
#   VIX              VIX_30d_spike_symlog_rolling_std_6m_lag_1m  inf
#   VIX              VIX_30d_spike_symlog_rolling_std_6m_lag_3m  inf
#   VIX              VIX_30d_spike_symlog_rolling_std_6m_lag_6m  inf
#   VIX                         VIX_30d_spike_symlog_zscore_12m  inf
#   VIX                 VIX_30d_spike_symlog_zscore_12m_lag_12m  inf
#   VIX                 VIX_30d_spike_symlog_zscore_12m_lag_18m  inf
#   VIX                  VIX_30d_spike_symlog_zscore_12m_lag_1m  inf
#   VIX                  VIX_30d_spike_symlog_zscore_12m_lag_3m  inf
#   VIX                  VIX_30d_spike_symlog_zscore_12m_lag_6m  inf
#   VIX                          VIX_30d_spike_symlog_zscore_3m  inf
#   VIX                  VIX_30d_spike_symlog_zscore_3m_lag_12m  inf
#   VIX                  VIX_30d_spike_symlog_zscore_3m_lag_18m  inf
#   VIX                   VIX_30d_spike_symlog_zscore_3m_lag_1m  inf
#   VIX                   VIX_30d_spike_symlog_zscore_3m_lag_3m  inf
#   VIX                   VIX_30d_spike_symlog_zscore_3m_lag_6m  inf
#   VIX          VIX_30d_spike_symlog_pct_chg_zscore_3m_lag_18m  inf
#   VIX          VIX_30d_spike_symlog_pct_chg_zscore_3m_lag_12m  inf
#   VIX                  VIX_30d_spike_symlog_pct_chg_zscore_3m  inf
#   VIX     VIX_30d_spike_symlog_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX                             VIX_30d_spike_symlog_lag_1m  inf
#   VIX                             VIX_30d_spike_symlog_lag_3m  inf
#   VIX                             VIX_30d_spike_symlog_lag_6m  inf
#   VIX                            VIX_30d_spike_symlog_pct_chg  inf
#   VIX                    VIX_30d_spike_symlog_pct_chg_lag_12m  inf
#   VIX                    VIX_30d_spike_symlog_pct_chg_lag_18m  inf
#   VIX                     VIX_30d_spike_symlog_pct_chg_lag_1m  inf
#   VIX                     VIX_30d_spike_symlog_pct_chg_lag_3m  inf
#   VIX                     VIX_30d_spike_symlog_pct_chg_lag_6m  inf
#   VIX            VIX_30d_spike_symlog_pct_chg_rolling_mean_3m  inf
#   VIX    VIX_30d_spike_symlog_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX    VIX_30d_spike_symlog_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX     VIX_30d_spike_symlog_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX          VIX_30d_spike_symlog_pct_chg_zscore_12m_lag_6m  inf
#   VIX     VIX_30d_spike_symlog_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX             VIX_30d_spike_symlog_pct_chg_rolling_std_6m  inf
#   VIX     VIX_30d_spike_symlog_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX     VIX_30d_spike_symlog_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX      VIX_30d_spike_symlog_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX      VIX_30d_spike_symlog_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX      VIX_30d_spike_symlog_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                 VIX_30d_spike_symlog_pct_chg_zscore_12m  inf
#   VIX         VIX_30d_spike_symlog_pct_chg_zscore_12m_lag_12m  inf
#   VIX         VIX_30d_spike_symlog_pct_chg_zscore_12m_lag_18m  inf
#   VIX          VIX_30d_spike_symlog_pct_chg_zscore_12m_lag_1m  inf
#   VIX          VIX_30d_spike_symlog_pct_chg_zscore_12m_lag_3m  inf
#   VIX                                VIX_30d_spike_zscore_12m  inf
#   VIX                        VIX_30d_spike_zscore_12m_lag_18m  inf
#   VIX                        VIX_max_5d_spike_pct_chg_lag_12m  inf
#   VIX                         VIX_30d_spike_zscore_12m_lag_1m  inf
#   VIX                         VIX_max_5d_spike_chg_6m_lag_18m  inf
#   VIX                          VIX_max_5d_spike_chg_6m_lag_1m  inf
#   VIX                          VIX_max_5d_spike_chg_6m_lag_3m  inf
#   VIX                          VIX_max_5d_spike_chg_6m_lag_6m  inf
#   VIX                                   VIX_max_5d_spike_diff  inf
#   VIX                           VIX_max_5d_spike_diff_lag_12m  inf
#   VIX                           VIX_max_5d_spike_diff_lag_18m  inf
#   VIX                            VIX_max_5d_spike_diff_lag_1m  inf
#   VIX                            VIX_max_5d_spike_diff_lag_3m  inf
#   VIX                            VIX_max_5d_spike_diff_lag_6m  inf
#   VIX                        VIX_max_5d_spike_diff_zscore_12m  inf
#   VIX                VIX_max_5d_spike_diff_zscore_12m_lag_12m  inf
#   VIX                VIX_max_5d_spike_diff_zscore_12m_lag_18m  inf
#   VIX                 VIX_max_5d_spike_diff_zscore_12m_lag_1m  inf
#   VIX                 VIX_max_5d_spike_diff_zscore_12m_lag_3m  inf
#   VIX                 VIX_max_5d_spike_diff_zscore_12m_lag_6m  inf
#   VIX                         VIX_max_5d_spike_diff_zscore_3m  inf
#   VIX                 VIX_max_5d_spike_diff_zscore_3m_lag_12m  inf
#   VIX                 VIX_max_5d_spike_diff_zscore_3m_lag_18m  inf
#   VIX                  VIX_max_5d_spike_diff_zscore_3m_lag_1m  inf
#   VIX                  VIX_max_5d_spike_diff_zscore_3m_lag_3m  inf
#   VIX                  VIX_max_5d_spike_diff_zscore_3m_lag_6m  inf
#   VIX                                VIX_max_5d_spike_lag_12m  inf
#   VIX                                VIX_max_5d_spike_lag_18m  inf
#   VIX                                 VIX_max_5d_spike_lag_1m  inf
#   VIX                                 VIX_max_5d_spike_lag_3m  inf
#   VIX                                 VIX_max_5d_spike_lag_6m  inf
#   VIX                         VIX_max_5d_spike_chg_6m_lag_12m  inf
#   VIX                                 VIX_max_5d_spike_chg_6m  inf
#   VIX                          VIX_max_5d_spike_chg_3m_lag_6m  inf
#   VIX                                  VIX_high_regime_lag_3m  inf
#   VIX                         VIX_30d_spike_zscore_12m_lag_3m  inf
#   VIX                         VIX_30d_spike_zscore_12m_lag_6m  inf
#   VIX                                 VIX_30d_spike_zscore_3m  inf
#   VIX                         VIX_30d_spike_zscore_3m_lag_12m  inf
#   VIX                         VIX_30d_spike_zscore_3m_lag_18m  inf
#   VIX                          VIX_30d_spike_zscore_3m_lag_1m  inf
#   VIX                          VIX_30d_spike_zscore_3m_lag_3m  inf
#   VIX                          VIX_30d_spike_zscore_3m_lag_6m  inf
#   VIX                                         VIX_high_regime  inf
#   VIX                                 VIX_high_regime_lag_12m  inf
#   VIX                                 VIX_high_regime_lag_18m  inf
#   VIX                                  VIX_high_regime_lag_1m  inf
#   VIX                                  VIX_high_regime_lag_6m  inf
#   VIX                          VIX_max_5d_spike_chg_3m_lag_3m  inf
#   VIX                                                 VIX_max  inf
#   VIX                                        VIX_max_5d_spike  inf
#   VIX                                VIX_max_5d_spike_chg_12m  inf
#   VIX                        VIX_max_5d_spike_chg_12m_lag_12m  inf
#   VIX                        VIX_max_5d_spike_chg_12m_lag_18m  inf
#   VIX                         VIX_max_5d_spike_chg_12m_lag_1m  inf
#   VIX                         VIX_max_5d_spike_chg_12m_lag_3m  inf
#   VIX                         VIX_max_5d_spike_chg_12m_lag_6m  inf
#   VIX                                 VIX_max_5d_spike_chg_3m  inf
#   VIX                         VIX_max_5d_spike_chg_3m_lag_12m  inf
#   VIX                         VIX_max_5d_spike_chg_3m_lag_18m  inf
#   VIX                          VIX_max_5d_spike_chg_3m_lag_1m  inf
#   VIX                            VIX_30d_spike_symlog_lag_18m  inf
#   VIX                            VIX_30d_spike_symlog_lag_12m  inf
#   VIX              VIX_30d_spike_symlog_diff_zscore_3m_lag_6m  inf
#   VIX              VIX_30d_spike_symlog_diff_zscore_3m_lag_3m  inf
#   VIX                    VIX_30d_spike_diff_zscore_3m_lag_12m  inf
#   VIX                    VIX_30d_spike_diff_zscore_3m_lag_18m  inf
#   VIX                     VIX_30d_spike_diff_zscore_3m_lag_1m  inf
#   VIX                     VIX_30d_spike_diff_zscore_3m_lag_3m  inf
#   VIX                     VIX_30d_spike_diff_zscore_3m_lag_6m  inf
#   VIX                                   VIX_30d_spike_lag_12m  inf
#   VIX                                   VIX_30d_spike_lag_18m  inf
#   VIX                                    VIX_30d_spike_lag_1m  inf
#   VIX                                    VIX_30d_spike_lag_3m  inf
#   VIX                                    VIX_30d_spike_lag_6m  inf
#   VIX                                   VIX_30d_spike_pct_chg  inf
#   VIX                           VIX_30d_spike_pct_chg_lag_12m  inf
#   VIX                           VIX_30d_spike_pct_chg_lag_18m  inf
#   VIX                            VIX_30d_spike_pct_chg_lag_1m  inf
#   VIX                            VIX_30d_spike_pct_chg_lag_3m  inf
#   VIX                            VIX_30d_spike_pct_chg_lag_6m  inf
#   VIX                   VIX_30d_spike_pct_chg_rolling_mean_3m  inf
#   VIX           VIX_30d_spike_pct_chg_rolling_mean_3m_lag_12m  inf
#   VIX           VIX_30d_spike_pct_chg_rolling_mean_3m_lag_18m  inf
#   VIX            VIX_30d_spike_pct_chg_rolling_mean_3m_lag_1m  inf
#   VIX            VIX_30d_spike_pct_chg_rolling_mean_3m_lag_3m  inf
#   VIX            VIX_30d_spike_pct_chg_rolling_mean_3m_lag_6m  inf
#   VIX                    VIX_30d_spike_pct_chg_rolling_std_6m  inf
#   VIX            VIX_30d_spike_pct_chg_rolling_std_6m_lag_12m  inf
#   VIX            VIX_30d_spike_pct_chg_rolling_std_6m_lag_18m  inf
#   VIX             VIX_30d_spike_pct_chg_rolling_std_6m_lag_1m  inf
#   VIX             VIX_30d_spike_pct_chg_rolling_std_6m_lag_3m  inf
#   VIX                            VIX_30d_spike_diff_zscore_3m  inf
#   VIX                    VIX_30d_spike_diff_zscore_12m_lag_6m  inf
#   VIX                    VIX_30d_spike_diff_zscore_12m_lag_3m  inf
#   VIX                            VIX_30d_spike_chg_6m_lag_12m  inf
#   VIX                           VIX_30d_spike_chg_12m_lag_12m  inf
#   VIX                           VIX_30d_spike_chg_12m_lag_18m  inf
#   VIX                            VIX_30d_spike_chg_12m_lag_1m  inf
#   VIX                            VIX_30d_spike_chg_12m_lag_3m  inf
#   VIX                            VIX_30d_spike_chg_12m_lag_6m  inf
#   VIX                                    VIX_30d_spike_chg_3m  inf
#   VIX                            VIX_30d_spike_chg_3m_lag_12m  inf
#   VIX                            VIX_30d_spike_chg_3m_lag_18m  inf
#   VIX                             VIX_30d_spike_chg_3m_lag_1m  inf
#   VIX                             VIX_30d_spike_chg_3m_lag_3m  inf
#   VIX                             VIX_30d_spike_chg_3m_lag_6m  inf
#   VIX                                    VIX_30d_spike_chg_6m  inf
#   VIX                            VIX_30d_spike_chg_6m_lag_18m  inf
#   VIX                    VIX_30d_spike_diff_zscore_12m_lag_1m  inf
#   VIX                             VIX_30d_spike_chg_6m_lag_1m  inf
#   VIX                             VIX_30d_spike_chg_6m_lag_3m  inf
#   VIX                             VIX_30d_spike_chg_6m_lag_6m  inf
#   VIX                                      VIX_30d_spike_diff  inf
#   VIX                              VIX_30d_spike_diff_lag_12m  inf
#   VIX                              VIX_30d_spike_diff_lag_18m  inf
#   VIX                               VIX_30d_spike_diff_lag_1m  inf
#   VIX                               VIX_30d_spike_diff_lag_3m  inf
#   VIX                               VIX_30d_spike_diff_lag_6m  inf
#   VIX                           VIX_30d_spike_diff_zscore_12m  inf
#   VIX                   VIX_30d_spike_diff_zscore_12m_lag_12m  inf
#   VIX                   VIX_30d_spike_diff_zscore_12m_lag_18m  inf
#   VIX             VIX_30d_spike_pct_chg_rolling_std_6m_lag_6m  inf
#   VIX                        VIX_30d_spike_pct_chg_zscore_12m  inf
#   VIX                VIX_30d_spike_pct_chg_zscore_12m_lag_12m  inf
#   VIX                       VIX_30d_spike_symlog_diff_lag_18m  inf
#   VIX                     VIX_30d_spike_symlog_chg_3m_lag_18m  inf
#   VIX                      VIX_30d_spike_symlog_chg_3m_lag_1m  inf
#   VIX                      VIX_30d_spike_symlog_chg_3m_lag_3m  inf
#   VIX                      VIX_30d_spike_symlog_chg_3m_lag_6m  inf
#   VIX                             VIX_30d_spike_symlog_chg_6m  inf
#   VIX                     VIX_30d_spike_symlog_chg_6m_lag_12m  inf
#   VIX                     VIX_30d_spike_symlog_chg_6m_lag_18m  inf
#   VIX                      VIX_30d_spike_symlog_chg_6m_lag_1m  inf
#   VIX                      VIX_30d_spike_symlog_chg_6m_lag_3m  inf
#   VIX                      VIX_30d_spike_symlog_chg_6m_lag_6m  inf
#   VIX                               VIX_30d_spike_symlog_diff  inf
#   VIX                       VIX_30d_spike_symlog_diff_lag_12m  inf
#   VIX                        VIX_30d_spike_symlog_diff_lag_1m  inf
#   VIX                             VIX_30d_spike_symlog_chg_3m  inf
#   VIX                        VIX_30d_spike_symlog_diff_lag_3m  inf
#   VIX                        VIX_30d_spike_symlog_diff_lag_6m  inf
#   VIX                    VIX_30d_spike_symlog_diff_zscore_12m  inf
#   VIX            VIX_30d_spike_symlog_diff_zscore_12m_lag_12m  inf
#   VIX            VIX_30d_spike_symlog_diff_zscore_12m_lag_18m  inf
#   VIX             VIX_30d_spike_symlog_diff_zscore_12m_lag_1m  inf
#   VIX             VIX_30d_spike_symlog_diff_zscore_12m_lag_3m  inf
#   VIX             VIX_30d_spike_symlog_diff_zscore_12m_lag_6m  inf
#   VIX                     VIX_30d_spike_symlog_diff_zscore_3m  inf
#   VIX             VIX_30d_spike_symlog_diff_zscore_3m_lag_12m  inf
#   VIX             VIX_30d_spike_symlog_diff_zscore_3m_lag_18m  inf
#   VIX              VIX_30d_spike_symlog_diff_zscore_3m_lag_1m  inf
#   VIX                     VIX_30d_spike_symlog_chg_3m_lag_12m  inf
#   VIX                     VIX_30d_spike_symlog_chg_12m_lag_6m  inf
#   VIX                VIX_30d_spike_pct_chg_zscore_12m_lag_18m  inf
#   VIX                    VIX_30d_spike_rolling_mean_3m_lag_1m  inf
#   VIX                 VIX_30d_spike_pct_chg_zscore_12m_lag_1m  inf
#   VIX                 VIX_30d_spike_pct_chg_zscore_12m_lag_3m  inf
#   VIX                 VIX_30d_spike_pct_chg_zscore_12m_lag_6m  inf
#   VIX                         VIX_30d_spike_pct_chg_zscore_3m  inf
#   VIX                 VIX_30d_spike_pct_chg_zscore_3m_lag_12m  inf
#   VIX                 VIX_30d_spike_pct_chg_zscore_3m_lag_18m  inf
#   VIX                  VIX_30d_spike_pct_chg_zscore_3m_lag_1m  inf
#   VIX                  VIX_30d_spike_pct_chg_zscore_3m_lag_3m  inf
#   VIX                  VIX_30d_spike_pct_chg_zscore_3m_lag_6m  inf
#   VIX                           VIX_30d_spike_rolling_mean_3m  inf
#   VIX                   VIX_30d_spike_rolling_mean_3m_lag_12m  inf
# ...
# CCNSA                          CCNSA_max_spike_chg_12m_lag_18m  inf
# CCNSA                           CCNSA_max_spike_chg_12m_lag_1m  inf
# CCNSA                           CCNSA_max_spike_chg_12m_lag_3m  inf
# CCNSA                           CCNSA_max_spike_chg_12m_lag_6m  inf
# CCNSA                                   CCNSA_max_spike_chg_3m  inf
# CCNSA                           CCNSA_max_spike_chg_3m_lag_18m  inf
# CCNSA                            CCNSA_max_spike_chg_6m_lag_1m  inf
# CCNSA                            CCNSA_max_spike_chg_3m_lag_1m  inf
# CCNSA                            CCNSA_max_spike_chg_3m_lag_3m  inf
# CCNSA                            CCNSA_max_spike_chg_3m_lag_6m  inf
# CCNSA                                   CCNSA_max_spike_chg_6m  inf
# CCNSA                           CCNSA_max_spike_chg_6m_lag_12m  inf
# CCNSA                           CCNSA_max_spike_chg_6m_lag_18m  inf
# CCNSA                    CCNSA_max_spike_diff_zscore_3m_lag_1m  inf
# CCNSA                    CCNSA_max_spike_diff_zscore_3m_lag_6m  inf
# CCNSA                 CCNSA_max_spike_pct_chg_zscore_3m_lag_3m  inf
# CCNSA               CCNSA_max_spike_pct_chg_zscore_12m_lag_18m  inf
# CCNSA           CCNSA_max_spike_pct_chg_rolling_std_6m_lag_18m  inf
# CCNSA            CCNSA_max_spike_pct_chg_rolling_std_6m_lag_1m  inf
# CCNSA            CCNSA_max_spike_pct_chg_rolling_std_6m_lag_3m  inf
# CCNSA            CCNSA_max_spike_pct_chg_rolling_std_6m_lag_6m  inf
# CCNSA                       CCNSA_max_spike_pct_chg_zscore_12m  inf
# CCNSA               CCNSA_max_spike_pct_chg_zscore_12m_lag_12m  inf
# CCNSA                CCNSA_max_spike_pct_chg_zscore_12m_lag_1m  inf
# CCNSA                   CCNSA_max_spike_pct_chg_rolling_std_6m  inf
# CCNSA                CCNSA_max_spike_pct_chg_zscore_12m_lag_3m  inf
# CCNSA                CCNSA_max_spike_pct_chg_zscore_12m_lag_6m  inf
# CCNSA                        CCNSA_max_spike_pct_chg_zscore_3m  inf
# CCNSA                CCNSA_max_spike_pct_chg_zscore_3m_lag_12m  inf
# CCNSA                CCNSA_max_spike_pct_chg_zscore_3m_lag_18m  inf
# CCNSA                 CCNSA_max_spike_pct_chg_zscore_3m_lag_1m  inf
# CCNSA           CCNSA_max_spike_pct_chg_rolling_std_6m_lag_12m  inf
# CCNSA           CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_6m  inf
# CCNSA                                  CCNSA_max_spike_lag_12m  inf
# CCNSA                          CCNSA_max_spike_pct_chg_lag_18m  inf
# CCNSA                                  CCNSA_max_spike_lag_18m  inf
# CCNSA                                   CCNSA_max_spike_lag_1m  inf
# CCNSA                                   CCNSA_max_spike_lag_3m  inf
# CCNSA                                   CCNSA_max_spike_lag_6m  inf
# CCNSA                                  CCNSA_max_spike_pct_chg  inf
# CCNSA                          CCNSA_max_spike_pct_chg_lag_12m  inf
# CCNSA                           CCNSA_max_spike_pct_chg_lag_1m  inf
# CCNSA           CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_3m  inf
# CCNSA                           CCNSA_max_spike_pct_chg_lag_3m  inf
# CCNSA                           CCNSA_max_spike_pct_chg_lag_6m  inf
# CCNSA                  CCNSA_max_spike_pct_chg_rolling_mean_3m  inf
# CCNSA          CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_12m  inf
# CCNSA          CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_18m  inf
# CCNSA           CCNSA_max_spike_pct_chg_rolling_mean_3m_lag_1m  inf
# CCNSA     CCNSA_max_spike_symlog_pct_chg_rolling_std_6m_lag_3m  inf
# CCNSA                CCNSA_max_spike_symlog_pct_chg_zscore_12m  inf
# CCNSA                   CCNSA_monthly_avg_symlog_chg_3m_lag_1m  inf
# CCNSA        CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_18m  inf
# CCNSA                        CCNSA_monthly_avg_pct_chg_lag_18m  inf
# CCNSA                         CCNSA_monthly_avg_pct_chg_lag_1m  inf
# CCNSA                         CCNSA_monthly_avg_pct_chg_lag_3m  inf
# CCNSA                         CCNSA_monthly_avg_pct_chg_lag_6m  inf
# CCNSA                CCNSA_monthly_avg_pct_chg_rolling_mean_3m  inf
# CCNSA        CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_12m  inf
# CCNSA         CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_1m  inf
# CCNSA                                CCNSA_monthly_avg_pct_chg  inf
# CCNSA         CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_3m  inf
# CCNSA         CCNSA_monthly_avg_pct_chg_rolling_mean_3m_lag_6m  inf
# CCNSA                 CCNSA_monthly_avg_pct_chg_rolling_std_6m  inf
# CCNSA         CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_12m  inf
# CCNSA         CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_18m  inf
# CCNSA          CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_1m  inf
# CCNSA                        CCNSA_monthly_avg_pct_chg_lag_12m  inf
# CCNSA                                 CCNSA_monthly_avg_lag_6m  inf
# CCNSA          CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_6m  inf
# CCNSA                 CCNSA_monthly_avg_diff_zscore_3m_lag_12m  inf
# CCNSA                CCNSA_monthly_avg_diff_zscore_12m_lag_12m  inf
# CCNSA                CCNSA_monthly_avg_diff_zscore_12m_lag_18m  inf
# CCNSA                 CCNSA_monthly_avg_diff_zscore_12m_lag_1m  inf
# CCNSA                 CCNSA_monthly_avg_diff_zscore_12m_lag_3m  inf
# CCNSA                 CCNSA_monthly_avg_diff_zscore_12m_lag_6m  inf
# CCNSA                         CCNSA_monthly_avg_diff_zscore_3m  inf
# CCNSA                 CCNSA_monthly_avg_diff_zscore_3m_lag_18m  inf
# CCNSA                                 CCNSA_monthly_avg_lag_3m  inf
# CCNSA                  CCNSA_monthly_avg_diff_zscore_3m_lag_1m  inf
# CCNSA                  CCNSA_monthly_avg_diff_zscore_3m_lag_3m  inf
# CCNSA                  CCNSA_monthly_avg_diff_zscore_3m_lag_6m  inf
# CCNSA                                CCNSA_monthly_avg_lag_12m  inf
# CCNSA                                CCNSA_monthly_avg_lag_18m  inf
# CCNSA                                 CCNSA_monthly_avg_lag_1m  inf
# CCNSA          CCNSA_monthly_avg_pct_chg_rolling_std_6m_lag_3m  inf
# CCNSA                     CCNSA_monthly_avg_pct_chg_zscore_12m  inf
# CCNSA                            CCNSA_monthly_avg_diff_lag_6m  inf
# CCNSA                 CCNSA_monthly_avg_symlog_chg_12m_lag_12m  inf
# CCNSA                 CCNSA_monthly_avg_rolling_std_6m_lag_18m  inf
# CCNSA                  CCNSA_monthly_avg_rolling_std_6m_lag_1m  inf
# CCNSA                  CCNSA_monthly_avg_rolling_std_6m_lag_3m  inf
# CCNSA                  CCNSA_monthly_avg_rolling_std_6m_lag_6m  inf
# CCNSA                                 CCNSA_monthly_avg_symlog  inf
# CCNSA                         CCNSA_monthly_avg_symlog_chg_12m  inf
# CCNSA                 CCNSA_monthly_avg_symlog_chg_12m_lag_18m  inf
# CCNSA                         CCNSA_monthly_avg_rolling_std_6m  inf
# CCNSA                  CCNSA_monthly_avg_symlog_chg_12m_lag_1m  inf
# CCNSA                  CCNSA_monthly_avg_symlog_chg_12m_lag_3m  inf
# CCNSA                  CCNSA_monthly_avg_symlog_chg_12m_lag_6m  inf
# CCNSA                          CCNSA_monthly_avg_symlog_chg_3m  inf
# CCNSA                  CCNSA_monthly_avg_symlog_chg_3m_lag_12m  inf
# CCNSA                  CCNSA_monthly_avg_symlog_chg_3m_lag_18m  inf
# CCNSA                 CCNSA_monthly_avg_rolling_std_6m_lag_12m  inf
# CCNSA                 CCNSA_monthly_avg_rolling_mean_3m_lag_6m  inf
# CCNSA             CCNSA_monthly_avg_pct_chg_zscore_12m_lag_12m  inf
# CCNSA              CCNSA_monthly_avg_pct_chg_zscore_3m_lag_18m  inf
# CCNSA             CCNSA_monthly_avg_pct_chg_zscore_12m_lag_18m  inf
# CCNSA              CCNSA_monthly_avg_pct_chg_zscore_12m_lag_1m  inf
# CCNSA              CCNSA_monthly_avg_pct_chg_zscore_12m_lag_3m  inf
# CCNSA              CCNSA_monthly_avg_pct_chg_zscore_12m_lag_6m  inf
# CCNSA                      CCNSA_monthly_avg_pct_chg_zscore_3m  inf
# CCNSA              CCNSA_monthly_avg_pct_chg_zscore_3m_lag_12m  inf
# CCNSA               CCNSA_monthly_avg_pct_chg_zscore_3m_lag_1m  inf
# CCNSA                 CCNSA_monthly_avg_rolling_mean_3m_lag_3m  inf
# CCNSA               CCNSA_monthly_avg_pct_chg_zscore_3m_lag_3m  inf
# CCNSA               CCNSA_monthly_avg_pct_chg_zscore_3m_lag_6m  inf
# CCNSA                        CCNSA_monthly_avg_rolling_mean_3m  inf
# CCNSA                CCNSA_monthly_avg_rolling_mean_3m_lag_12m  inf
# CCNSA                CCNSA_monthly_avg_rolling_mean_3m_lag_18m  inf
# CCNSA                 CCNSA_monthly_avg_rolling_mean_3m_lag_1m  inf
# CCNSA                        CCNSA_monthly_avg_diff_zscore_12m  inf
# CCNSA                            CCNSA_monthly_avg_diff_lag_3m  inf
# CCNSA        CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_12m  inf
# CCNSA                CCNSA_max_spike_symlog_zscore_12m_lag_18m  inf
# CCNSA            CCNSA_max_spike_symlog_rolling_std_6m_lag_18m  inf
# CCNSA             CCNSA_max_spike_symlog_rolling_std_6m_lag_1m  inf
# CCNSA             CCNSA_max_spike_symlog_rolling_std_6m_lag_3m  inf
# CCNSA             CCNSA_max_spike_symlog_rolling_std_6m_lag_6m  inf
# CCNSA                        CCNSA_max_spike_symlog_zscore_12m  inf
# CCNSA                CCNSA_max_spike_symlog_zscore_12m_lag_12m  inf
# CCNSA                 CCNSA_max_spike_symlog_zscore_12m_lag_1m  inf
# CCNSA                    CCNSA_max_spike_symlog_rolling_std_6m  inf
# CCNSA                 CCNSA_max_spike_symlog_zscore_12m_lag_3m  inf
# CCNSA                 CCNSA_max_spike_symlog_zscore_12m_lag_6m  inf
# CCNSA                         CCNSA_max_spike_symlog_zscore_3m  inf
# CCNSA                 CCNSA_max_spike_symlog_zscore_3m_lag_12m  inf
# CCNSA                 CCNSA_max_spike_symlog_zscore_3m_lag_18m  inf
# CCNSA                  CCNSA_max_spike_symlog_zscore_3m_lag_1m  inf
# CCNSA            CCNSA_max_spike_symlog_rolling_std_6m_lag_12m  inf
# CCNSA            CCNSA_max_spike_symlog_rolling_mean_3m_lag_6m  inf
# CCNSA                  CCNSA_max_spike_symlog_zscore_3m_lag_6m  inf
# CCNSA         CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_18m  inf
# CCNSA        CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_18m  inf
# CCNSA         CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_1m  inf
# CCNSA         CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_3m  inf
# CCNSA         CCNSA_max_spike_symlog_pct_chg_zscore_12m_lag_6m  inf
# CCNSA                 CCNSA_max_spike_symlog_pct_chg_zscore_3m  inf
# CCNSA         CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_12m  inf
# CCNSA          CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_1m  inf
# CCNSA            CCNSA_max_spike_symlog_rolling_mean_3m_lag_3m  inf
# CCNSA          CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_3m  inf
# CCNSA          CCNSA_max_spike_symlog_pct_chg_zscore_3m_lag_6m  inf
# CCNSA                   CCNSA_max_spike_symlog_rolling_mean_3m  inf
# CCNSA           CCNSA_max_spike_symlog_rolling_mean_3m_lag_12m  inf
# CCNSA           CCNSA_max_spike_symlog_rolling_mean_3m_lag_18m  inf
# CCNSA            CCNSA_max_spike_symlog_rolling_mean_3m_lag_1m  inf
# CCNSA                  CCNSA_max_spike_symlog_zscore_3m_lag_3m  inf
# CCNSA                               CCNSA_max_spike_zscore_12m  inf
# CCNSA                            CCNSA_monthly_avg_diff_lag_1m  inf
# CCNSA                         CCNSA_monthly_avg_chg_6m_lag_12m  inf
# CCNSA                         CCNSA_monthly_avg_chg_3m_lag_12m  inf
# CCNSA                         CCNSA_monthly_avg_chg_3m_lag_18m  inf
# CCNSA                          CCNSA_monthly_avg_chg_3m_lag_1m  inf
# CCNSA                          CCNSA_monthly_avg_chg_3m_lag_3m  inf
# CCNSA                          CCNSA_monthly_avg_chg_3m_lag_6m  inf
# CCNSA                                 CCNSA_monthly_avg_chg_6m  inf
# CCNSA                         CCNSA_monthly_avg_chg_6m_lag_18m  inf
# CCNSA                         CCNSA_monthly_avg_chg_12m_lag_6m  inf
# CCNSA                          CCNSA_monthly_avg_chg_6m_lag_1m  inf
# CCNSA                          CCNSA_monthly_avg_chg_6m_lag_3m  inf
# CCNSA                          CCNSA_monthly_avg_chg_6m_lag_6m  inf
# CCNSA                                   CCNSA_monthly_avg_diff  inf
# CCNSA                           CCNSA_monthly_avg_diff_lag_12m  inf
# CCNSA                           CCNSA_monthly_avg_diff_lag_18m  inf
# CCNSA                                 CCNSA_monthly_avg_chg_3m  inf
# CCNSA                         CCNSA_monthly_avg_chg_12m_lag_3m  inf
# CCNSA                       CCNSA_max_spike_zscore_12m_lag_12m  inf
# CCNSA                        CCNSA_max_spike_zscore_3m_lag_18m  inf
# CCNSA                       CCNSA_max_spike_zscore_12m_lag_18m  inf
# CCNSA                        CCNSA_max_spike_zscore_12m_lag_1m  inf
# CCNSA                        CCNSA_max_spike_zscore_12m_lag_3m  inf
# CCNSA                        CCNSA_max_spike_zscore_12m_lag_6m  inf
# CCNSA                                CCNSA_max_spike_zscore_3m  inf
# CCNSA                        CCNSA_max_spike_zscore_3m_lag_12m  inf
# CCNSA                         CCNSA_max_spike_zscore_3m_lag_1m  inf
# CCNSA                         CCNSA_monthly_avg_chg_12m_lag_1m  inf
# CCNSA                         CCNSA_max_spike_zscore_3m_lag_3m  inf
# CCNSA                         CCNSA_max_spike_zscore_3m_lag_6m  inf
# CCNSA                                        CCNSA_monthly_avg  inf
# CCNSA                                CCNSA_monthly_avg_chg_12m  inf
# CCNSA                        CCNSA_monthly_avg_chg_12m_lag_12m  inf
# CCNSA                        CCNSA_monthly_avg_chg_12m_lag_18m  inf
# CCNSA                        CCNSA_weeks_high_zscore_3m_lag_6m  inf
#
#   >> 576 features with VIF > 10 (multicollinearity concern)
#
# ============================================================
# Weekly_Econ_Index (576 features)
# ============================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 print(f"{group_name} ({len(features)} features)")
#       6 print(f"{'='*60}")
# ----> 8 vif_df = compute_group_vif(wide, features, group_name)
#       9 if not vif_df.empty:
#      10     all_vif_results.append(vif_df)
#
# Cell In[5], line 31, in compute_group_vif(df_wide, feature_list, group_name, min_obs)
#      29 for col in [c for c in X_const.columns if c != '_const']:
#      30     try:
# ---> 31         vif = variance_inflation_factor(X_const.values, X_const.columns.get_loc(col))
#      32         vif_data.append({'group': group_name, 'feature': col, 'VIF': round(vif, 2)})
#      33     except Exception as e:
#
# File /opt/anaconda3/envs/nfp/lib/python3.12/site-packages/statsmodels/stats/outliers_influence.py:196, in variance_inflation_factor(exog, exog_idx)
#     194 mask = np.arange(k_vars) != exog_idx
#     195 x_noti = exog[:, mask]
# --> 196 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     197 vif = 1. / (1. - r_squared_i)
#     198 return vif
#
# File /opt/anaconda3/envs/nfp/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:333, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     328 if method == "pinv":
#     329     if not (hasattr(self, 'pinv_wexog') and
#     330             hasattr(self, 'normalized_cov_params') and
#     331             hasattr(self, 'rank')):
# --> 333         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     334         self.normalized_cov_params = np.dot(
#     335             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     337         # Cache these singular values for use later.
#
# File /opt/anaconda3/envs/nfp/lib/python3.12/site-packages/statsmodels/tools/tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File /opt/anaconda3/envs/nfp/lib/python3.12/site-packages/numpy/linalg/_linalg.py:1862, in svd(a, full_matrices, compute_uv, hermitian)
#    1858 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1859 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1860               invalid='call', over='ignore', divide='ignore',
#    1861               under='ignore'):
# -> 1862     u, s, vh = gufunc(a, signature=signature)
#    1863 u = u.astype(result_t, copy=False)
#    1864 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Level vs Diff Correlation Analysis
#
# For each base feature, how correlated is the level with its diff? Low correlation means both provide unique info.

# %%
# Identify base features (levels that have a corresponding _diff)
level_features = TRANSFORM_GROUPS['level']
diff_features = TRANSFORM_GROUPS['diff']

# Map level -> diff by checking if {level}_diff exists
correlation_analysis = []

for level_feat in level_features:
    diff_feat = f"{level_feat}_diff"
    z12_feat = f"{level_feat}_diff_zscore_12m"
    z3_feat = f"{level_feat}_diff_zscore_3m"
    
    row = {'base_feature': level_feat}
    
    # Level vs Diff correlation
    if diff_feat in wide.columns:
        valid = wide[[level_feat, diff_feat]].dropna()
        if len(valid) > 10:
            row['level_vs_diff_corr'] = round(valid[level_feat].corr(valid[diff_feat]), 3)
    
    # Diff vs Z-score 12m correlation
    if diff_feat in wide.columns and z12_feat in wide.columns:
        valid = wide[[diff_feat, z12_feat]].dropna()
        if len(valid) > 10:
            row['diff_vs_z12_corr'] = round(valid[diff_feat].corr(valid[z12_feat]), 3)
    
    # Diff vs Z-score 3m correlation
    if diff_feat in wide.columns and z3_feat in wide.columns:
        valid = wide[[diff_feat, z3_feat]].dropna()
        if len(valid) > 10:
            row['diff_vs_z3_corr'] = round(valid[diff_feat].corr(valid[z3_feat]), 3)
    
    # Z-score 12m vs Z-score 3m correlation
    if z12_feat in wide.columns and z3_feat in wide.columns:
        valid = wide[[z12_feat, z3_feat]].dropna()
        if len(valid) > 10:
            row['z12_vs_z3_corr'] = round(valid[z12_feat].corr(valid[z3_feat]), 3)
    
    if len(row) > 1:  # Only add if we found at least one correlation
        correlation_analysis.append(row)

corr_df = pd.DataFrame(correlation_analysis)
print("Level vs Diff vs Z-Score Correlation Analysis:")
print("="*100)
print(corr_df.to_string(index=False))

print(f"\n\nSummary Statistics:")
print(f"  Level vs Diff |r|: mean={corr_df['level_vs_diff_corr'].abs().mean():.3f}, "
      f"median={corr_df['level_vs_diff_corr'].abs().median():.3f}")
if 'diff_vs_z12_corr' in corr_df.columns:
    print(f"  Diff vs Z12 |r|:   mean={corr_df['diff_vs_z12_corr'].abs().mean():.3f}, "
          f"median={corr_df['diff_vs_z12_corr'].abs().median():.3f}")
if 'z12_vs_z3_corr' in corr_df.columns:
    print(f"  Z12 vs Z3 |r|:     mean={corr_df['z12_vs_z3_corr'].abs().mean():.3f}, "
          f"median={corr_df['z12_vs_z3_corr'].abs().median():.3f}")
# Out:
# Level vs Diff vs Z-Score Correlation Analysis:
# ====================================================================================================
#                    base_feature  level_vs_diff_corr  diff_vs_z12_corr  diff_vs_z3_corr  z12_vs_z3_corr
#                 CCNSA_max_spike               0.237             0.434            0.269           0.698
#               CCNSA_monthly_avg               0.208             0.477            0.281           0.684
#                CCNSA_weeks_high               0.062             0.964            0.788           0.782
#                  CCSA_max_spike               0.233             0.247            0.116           0.645
#                CCSA_monthly_avg               0.206             0.259            0.114           0.629
#                 CCSA_weeks_high               0.029             0.909            0.749           0.794
# Credit_Spreads_accel_volatility               0.482             0.812            0.628           0.807
#     Credit_Spreads_acceleration               0.844             0.836            0.678           0.837
#              Credit_Spreads_avg               0.134             0.707            0.432           0.672
#              Credit_Spreads_max               0.147             0.732            0.455           0.686
#      Credit_Spreads_monthly_chg               0.602             0.849            0.707           0.820
#   Credit_Spreads_vol_of_changes               0.441             0.818            0.641           0.808
#       Credit_Spreads_zscore_max               0.175             0.677            0.437           0.681
#    Financial_Stress_monthly_avg               0.265             0.650            0.446           0.771
#                 ICNSA_max_spike               0.390             0.534            0.379           0.823
#               ICNSA_monthly_avg               0.443             0.437            0.300           0.826
#                ICNSA_weeks_high               0.061             0.795            0.820           0.882
#                  ICSA_max_spike               0.375             0.291            0.154           0.771
#                ICSA_monthly_avg               0.433             0.260            0.137           0.748
#                 ICSA_weeks_high               0.028             0.863            0.715           0.784
#            Oil_Prices_30d_crash               0.590             0.646            0.492           0.835
#                 Oil_Prices_mean               0.076             0.800            0.568           0.750
#           Oil_Prices_volatility               0.506             0.539            0.369           0.782
#           Oil_Prices_zscore_min               0.136             0.863            0.636           0.760
#               Oil_worst_day_pct               0.679             0.330            0.207           0.804
#                SP500_30d_return               0.717             0.921            0.784           0.848
#                  SP500_best_day               0.481             0.855            0.656           0.793
#     SP500_consecutive_down_days               0.693             0.964            0.836           0.866
#      SP500_days_circuit_breaker               0.527             0.813            0.743           0.880
#               SP500_max_5d_drop               0.522             0.914            0.751           0.831
#              SP500_max_drawdown               0.217             0.891            0.663           0.765
#            SP500_monthly_return               0.716             0.917            0.780           0.849
#                SP500_volatility               0.349             0.814            0.596           0.772
#                 SP500_worst_day               0.508             0.881            0.716           0.821
#                   VIX_30d_spike               0.612             0.819            0.621           0.786
#                         VIX_max               0.327             0.854            0.634           0.761
#                VIX_max_5d_spike               0.648             0.837            0.682           0.827
#                        VIX_mean               0.276             0.812            0.572           0.735
#                  VIX_volatility               0.520             0.826            0.653           0.809
#   Weekly_Econ_Index_monthly_avg               0.189             0.608            0.357           0.721
#   Weekly_Econ_Index_monthly_max               0.196             0.654            0.456           0.747
#   Weekly_Econ_Index_monthly_min               0.189             0.657            0.414           0.745
#    Yield_Curve_accel_volatility               0.405             0.811            0.660           0.828
#        Yield_Curve_acceleration               0.776             0.775            0.611           0.827
#                 Yield_Curve_avg               0.106             0.749            0.528           0.703
#                 Yield_Curve_max               0.117             0.760              NaN             NaN
#         Yield_Curve_monthly_chg               0.653             0.855            0.718           0.834
#      Yield_Curve_vol_of_changes               0.384             0.790            0.638           0.814
#          Yield_Curve_zscore_max               0.109             0.753            0.542           0.724
#
#
# Summary Statistics:
#   Level vs Diff |r|: mean=0.368, median=0.375
#   Diff vs Z12 |r|:   mean=0.720, median=0.800
#   Z12 vs Z3 |r|:     mean=0.778, median=0.785

# %% [markdown]
# ## 6. Cross-Group Correlation Analysis
#
# Check for redundancy across different indicator types (e.g., ICSA vs ICNSA, Credit_Spreads vs Yield_Curve).

# %%
# Check cross-group correlations between level features
cross_group_pairs = [
    ('ICSA_monthly_avg', 'ICNSA_monthly_avg', 'ICSA vs ICNSA (avg)'),
    ('ICSA_max_spike', 'ICNSA_max_spike', 'ICSA vs ICNSA (spike)'),
    ('ICSA_weeks_high', 'ICNSA_weeks_high', 'ICSA vs ICNSA (weeks_high)'),
    ('CCSA_monthly_avg', 'CCNSA_monthly_avg', 'CCSA vs CCNSA (avg)'),
    ('CCSA_max_spike', 'CCNSA_max_spike', 'CCSA vs CCNSA (spike)'),
    ('CCSA_weeks_high', 'CCNSA_weeks_high', 'CCSA vs CCNSA (weeks_high)'),
    ('ICSA_monthly_avg', 'CCSA_monthly_avg', 'Initial vs Continued Claims'),
    ('Credit_Spreads_avg', 'Yield_Curve_avg', 'Credit Spreads vs Yield Curve'),
    ('VIX_mean', 'SP500_volatility', 'VIX vs SP500 Volatility'),
    ('VIX_mean', 'Credit_Spreads_avg', 'VIX vs Credit Spreads'),
    ('Financial_Stress_monthly_avg', 'VIX_mean', 'Financial Stress vs VIX'),
    ('Financial_Stress_monthly_avg', 'Credit_Spreads_avg', 'Financial Stress vs Credit Spreads'),
]

print("Cross-Group Level Correlations:")
print("="*70)
for feat1, feat2, label in cross_group_pairs:
    if feat1 in wide.columns and feat2 in wide.columns:
        valid = wide[[feat1, feat2]].dropna()
        if len(valid) > 10:
            r = valid[feat1].corr(valid[feat2])
            flag = " ** HIGH" if abs(r) > 0.9 else (" * moderate" if abs(r) > 0.7 else "")
            print(f"  {label:45s} r = {r:+.3f}{flag}")
    else:
        missing = [f for f in [feat1, feat2] if f not in wide.columns]
        print(f"  {label:45s} MISSING: {missing}")
# Out:
# Cross-Group Level Correlations:
# ======================================================================
#   ICSA vs ICNSA (avg)                           r = +0.976 ** HIGH
#   ICSA vs ICNSA (spike)                         r = +0.968 ** HIGH
#   ICSA vs ICNSA (weeks_high)                    r = +0.996 ** HIGH
#   CCSA vs CCNSA (avg)                           r = +0.982 ** HIGH
#   CCSA vs CCNSA (spike)                         r = +0.984 ** HIGH
#   CCSA vs CCNSA (weeks_high)                    r = +0.991 ** HIGH
#   Initial vs Continued Claims                   r = +0.762 * moderate
#   Credit Spreads vs Yield Curve                 r = +0.428
#   VIX vs SP500 Volatility                       r = +0.915 ** HIGH
#   VIX vs Credit Spreads                         r = +0.736 * moderate
#   Financial Stress vs VIX                       r = +0.824 * moderate
#   Financial Stress vs Credit Spreads            r = +0.831 * moderate

# %% [markdown]
# ## 7. Within-Group VIF Pruning
#
# For each series group, iteratively remove features with VIF > 10.

# %%
PROTECTED = {
    'VIX_panic_regime', 'VIX_high_regime',
    'SP500_bear_market', 'SP500_crash_month', 'SP500_circuit_breaker',
}

group_survivors = {}
group_removed = {}

for group_name, features in SERIES_GROUPS.items():
    print(f"\n{'='*60}")
    print(f"VIF Pruning: {group_name} ({len(features)} features)")
    print(f"{'='*60}")
    
    survivors, removed = iterative_vif_pruning(
        wide, features, threshold=10.0, protected=PROTECTED
    )
    group_survivors[group_name] = survivors
    group_removed[group_name] = removed
    
    print(f"\n  Kept {len(survivors)} features: {survivors}")
    print(f"  Removed {len(removed)} features")
# Out:
# ============================================================
# VIF Pruning: VIX (22 features)
# ============================================================
#   Iter 1: Removed VIX_max (VIF=121.6), 21 features remain
#   Iter 2: Removed VIX_max_diff (VIF=28.6), 20 features remain
#   Iter 3: Removed VIX_volatility_diff (VIF=18.9), 19 features remain
#   Iter 4: Removed VIX_volatility (VIF=13.5), 18 features remain
#   Iter 5: Removed VIX_max_diff_zscore_12m (VIF=11.3), 17 features remain
#   Iter 6: Removed VIX_30d_spike_diff_zscore_12m (VIF=10.3), 16 features remain
#
#   Kept 16 features: ['VIX_30d_spike', 'VIX_30d_spike_diff', 'VIX_30d_spike_diff_zscore_3m', 'VIX_high_regime', 'VIX_max_5d_spike', 'VIX_max_5d_spike_diff', 'VIX_max_5d_spike_diff_zscore_12m', 'VIX_max_5d_spike_diff_zscore_3m', 'VIX_max_diff_zscore_3m', 'VIX_mean', 'VIX_mean_diff', 'VIX_mean_diff_zscore_12m', 'VIX_mean_diff_zscore_3m', 'VIX_panic_regime', 'VIX_volatility_diff_zscore_12m', 'VIX_volatility_diff_zscore_3m']
#   Removed 6 features
#
# ============================================================
# VIF Pruning: SP500 (39 features)
# ============================================================
#   Iter 1: Removed SP500_30d_return (VIF=inf), 38 features remain
#   Iter 2: Removed SP500_30d_return_diff (VIF=inf), 37 features remain
#   Iter 3: Removed SP500_30d_return_diff_zscore_12m (VIF=inf), 36 features remain
#   Iter 4: Removed SP500_30d_return_diff_zscore_3m (VIF=inf), 35 features remain
#   Iter 5: Removed SP500_best_day (VIF=inf), 34 features remain
#   Iter 6: Removed SP500_days_circuit_breaker_diff_zscore_12m (VIF=4650.0), 33 features remain
#   Iter 7: Removed SP500_max_5d_drop_diff (VIF=929.6), 32 features remain
#   Iter 8: Removed SP500_max_drawdown_diff_zscore_12m (VIF=659.6), 31 features remain
#   Iter 9: Removed SP500_max_5d_drop_diff_zscore_12m (VIF=221.3), 30 features remain
#   Iter 10: Removed SP500_worst_day_diff (VIF=144.4), 29 features remain
#   Iter 11: Removed SP500_consecutive_down_days_diff (VIF=101.3), 28 features remain
#   Iter 12: Removed SP500_worst_day_diff_zscore_12m (VIF=71.0), 27 features remain
#   Iter 13: Removed SP500_volatility (VIF=64.4), 26 features remain
#   Iter 14: Removed SP500_monthly_return_diff (VIF=61.4), 25 features remain
#   Iter 15: Removed SP500_worst_day (VIF=48.6), 24 features remain
#   Iter 16: Removed SP500_volatility_diff (VIF=29.1), 23 features remain
#   Iter 17: Removed SP500_max_5d_drop (VIF=27.6), 22 features remain
#   Iter 18: Removed SP500_best_day_diff_zscore_12m (VIF=22.4), 21 features remain
#   Iter 19: Removed SP500_days_circuit_breaker_diff_zscore_3m (VIF=19.1), 20 features remain
#   Iter 20: Removed SP500_consecutive_down_days_diff_zscore_12m (VIF=12.4), 19 features remain
#   Iter 21: Removed SP500_max_drawdown_diff (VIF=11.6), 18 features remain
#   Iter 22: Removed SP500_monthly_return_diff_zscore_12m (VIF=10.2), 17 features remain
#
#   Kept 17 features: ['SP500_bear_market', 'SP500_best_day_diff', 'SP500_best_day_diff_zscore_3m', 'SP500_circuit_breaker', 'SP500_consecutive_down_days', 'SP500_consecutive_down_days_diff_zscore_3m', 'SP500_crash_month', 'SP500_days_circuit_breaker', 'SP500_days_circuit_breaker_diff', 'SP500_max_5d_drop_diff_zscore_3m', 'SP500_max_drawdown', 'SP500_max_drawdown_diff_zscore_3m', 'SP500_monthly_return', 'SP500_monthly_return_diff_zscore_3m', 'SP500_volatility_diff_zscore_12m', 'SP500_volatility_diff_zscore_3m', 'SP500_worst_day_diff_zscore_3m']
#   Removed 22 features
#
# ============================================================
# VIF Pruning: Credit_Spreads (28 features)
# ============================================================
#   Iter 1: Removed Credit_Spreads_max (VIF=846.8), 27 features remain
#   Iter 2: Removed Credit_Spreads_max_diff_zscore_12m (VIF=73.3), 26 features remain
#   Iter 3: Removed Credit_Spreads_vol_of_changes (VIF=48.5), 25 features remain
#   Iter 4: Removed Credit_Spreads_zscore_max_diff_zscore_3m (VIF=46.2), 24 features remain
#   Iter 5: Removed Credit_Spreads_max_diff (VIF=27.8), 23 features remain
#   Iter 6: Removed Credit_Spreads_vol_of_changes_diff (VIF=24.7), 22 features remain
#   Iter 7: Removed Credit_Spreads_accel_volatility_diff_zscore_12m (VIF=13.6), 21 features remain
#   Iter 8: Removed Credit_Spreads_monthly_chg (VIF=12.5), 20 features remain
#
#   Kept 20 features: ['Credit_Spreads_accel_volatility', 'Credit_Spreads_accel_volatility_diff', 'Credit_Spreads_accel_volatility_diff_zscore_3m', 'Credit_Spreads_acceleration', 'Credit_Spreads_acceleration_diff', 'Credit_Spreads_acceleration_diff_zscore_12m', 'Credit_Spreads_acceleration_diff_zscore_3m', 'Credit_Spreads_avg', 'Credit_Spreads_avg_diff', 'Credit_Spreads_avg_diff_zscore_12m', 'Credit_Spreads_avg_diff_zscore_3m', 'Credit_Spreads_max_diff_zscore_3m', 'Credit_Spreads_monthly_chg_diff', 'Credit_Spreads_monthly_chg_diff_zscore_12m', 'Credit_Spreads_monthly_chg_diff_zscore_3m', 'Credit_Spreads_vol_of_changes_diff_zscore_12m', 'Credit_Spreads_vol_of_changes_diff_zscore_3m', 'Credit_Spreads_zscore_max', 'Credit_Spreads_zscore_max_diff', 'Credit_Spreads_zscore_max_diff_zscore_12m']
#   Removed 8 features
#
# ============================================================
# VIF Pruning: Yield_Curve (28 features)
# ============================================================
#   Iter 1: Removed Yield_Curve_max (VIF=702.2), 27 features remain
#   Iter 2: Removed Yield_Curve_max_diff_zscore_3m (VIF=154.1), 26 features remain
#   Iter 3: Removed Yield_Curve_max_diff_zscore_12m (VIF=82.1), 25 features remain
#   Iter 4: Removed Yield_Curve_accel_volatility (VIF=52.4), 24 features remain
#   Iter 5: Removed Yield_Curve_max_diff (VIF=31.1), 23 features remain
#   Iter 6: Removed Yield_Curve_accel_volatility_diff_zscore_12m (VIF=16.1), 22 features remain
#   Iter 7: Removed Yield_Curve_avg_diff (VIF=12.9), 21 features remain
#   Iter 8: Removed Yield_Curve_zscore_max_diff_zscore_12m (VIF=11.5), 20 features remain
#   Iter 9: Removed Yield_Curve_vol_of_changes_diff (VIF=10.0), 19 features remain
#
#   Kept 19 features: ['Yield_Curve_accel_volatility_diff', 'Yield_Curve_accel_volatility_diff_zscore_3m', 'Yield_Curve_acceleration', 'Yield_Curve_acceleration_diff', 'Yield_Curve_acceleration_diff_zscore_12m', 'Yield_Curve_acceleration_diff_zscore_3m', 'Yield_Curve_avg', 'Yield_Curve_avg_diff_zscore_12m', 'Yield_Curve_avg_diff_zscore_3m', 'Yield_Curve_monthly_chg', 'Yield_Curve_monthly_chg_diff', 'Yield_Curve_monthly_chg_diff_zscore_12m', 'Yield_Curve_monthly_chg_diff_zscore_3m', 'Yield_Curve_vol_of_changes', 'Yield_Curve_vol_of_changes_diff_zscore_12m', 'Yield_Curve_vol_of_changes_diff_zscore_3m', 'Yield_Curve_zscore_max', 'Yield_Curve_zscore_max_diff', 'Yield_Curve_zscore_max_diff_zscore_3m']
#   Removed 9 features
#
# ============================================================
# VIF Pruning: Oil_Prices (20 features)
# ============================================================
#   Iter 1: Removed Oil_Prices_30d_crash_diff (VIF=39.7), 19 features remain
#   Iter 2: Removed Oil_Prices_30d_crash (VIF=23.1), 18 features remain
#   Iter 3: Removed Oil_worst_day_pct_diff (VIF=14.4), 17 features remain
#   Iter 4: Removed Oil_Prices_zscore_min_diff_zscore_12m (VIF=13.6), 16 features remain
#
#   Kept 16 features: ['Oil_Prices_30d_crash_diff_zscore_12m', 'Oil_Prices_30d_crash_diff_zscore_3m', 'Oil_Prices_mean', 'Oil_Prices_mean_diff', 'Oil_Prices_mean_diff_zscore_12m', 'Oil_Prices_mean_diff_zscore_3m', 'Oil_Prices_volatility', 'Oil_Prices_volatility_diff', 'Oil_Prices_volatility_diff_zscore_12m', 'Oil_Prices_volatility_diff_zscore_3m', 'Oil_Prices_zscore_min', 'Oil_Prices_zscore_min_diff', 'Oil_Prices_zscore_min_diff_zscore_3m', 'Oil_worst_day_pct', 'Oil_worst_day_pct_diff_zscore_12m', 'Oil_worst_day_pct_diff_zscore_3m']
#   Removed 4 features
#
# ============================================================
# VIF Pruning: ICSA (12 features)
# ============================================================
#   Iter 1: Removed ICSA_monthly_avg (VIF=532.0), 11 features remain
#   Iter 2: Removed ICSA_weeks_high_diff_zscore_12m (VIF=24.6), 10 features remain
#   Iter 3: Removed ICSA_monthly_avg_diff_zscore_12m (VIF=11.1), 9 features remain
#
#   Kept 9 features: ['ICSA_max_spike', 'ICSA_max_spike_diff', 'ICSA_max_spike_diff_zscore_12m', 'ICSA_max_spike_diff_zscore_3m', 'ICSA_monthly_avg_diff', 'ICSA_monthly_avg_diff_zscore_3m', 'ICSA_weeks_high', 'ICSA_weeks_high_diff', 'ICSA_weeks_high_diff_zscore_3m']
#   Removed 3 features
#
# ============================================================
# VIF Pruning: ICNSA (12 features)
# ============================================================
#   Iter 1: Removed ICNSA_monthly_avg (VIF=231.3), 11 features remain
#   Iter 2: Removed ICNSA_max_spike_diff_zscore_12m (VIF=52.8), 10 features remain
#   Iter 3: Removed ICNSA_max_spike_diff_zscore_3m (VIF=17.1), 9 features remain
#   Iter 4: Removed ICNSA_weeks_high_diff_zscore_3m (VIF=10.3), 8 features remain
#
#   Kept 8 features: ['ICNSA_max_spike', 'ICNSA_max_spike_diff', 'ICNSA_monthly_avg_diff', 'ICNSA_monthly_avg_diff_zscore_12m', 'ICNSA_monthly_avg_diff_zscore_3m', 'ICNSA_weeks_high', 'ICNSA_weeks_high_diff', 'ICNSA_weeks_high_diff_zscore_12m']
#   Removed 4 features
#
# ============================================================
# VIF Pruning: CCSA (12 features)
# ============================================================
#   Iter 1: Removed CCSA_max_spike (VIF=202.2), 11 features remain
#   Iter 2: Removed CCSA_max_spike_diff_zscore_12m (VIF=32.9), 10 features remain
#   Iter 3: Removed CCSA_weeks_high_diff (VIF=14.3), 9 features remain
#   Iter 4: Removed CCSA_monthly_avg_diff (VIF=10.8), 8 features remain
#
#   Kept 8 features: ['CCSA_max_spike_diff', 'CCSA_max_spike_diff_zscore_3m', 'CCSA_monthly_avg', 'CCSA_monthly_avg_diff_zscore_12m', 'CCSA_monthly_avg_diff_zscore_3m', 'CCSA_weeks_high', 'CCSA_weeks_high_diff_zscore_12m', 'CCSA_weeks_high_diff_zscore_3m']
#   Removed 4 features
#
# ============================================================
# VIF Pruning: CCNSA (12 features)
# ============================================================
#   Iter 1: Removed CCNSA_max_spike (VIF=200.7), 11 features remain
#   Iter 2: Removed CCNSA_weeks_high_diff (VIF=29.8), 10 features remain
#   Iter 3: Removed CCNSA_max_spike_diff_zscore_12m (VIF=23.1), 9 features remain
#   Iter 4: Removed CCNSA_monthly_avg_diff (VIF=13.3), 8 features remain
#
#   Kept 8 features: ['CCNSA_max_spike_diff', 'CCNSA_max_spike_diff_zscore_3m', 'CCNSA_monthly_avg', 'CCNSA_monthly_avg_diff_zscore_12m', 'CCNSA_monthly_avg_diff_zscore_3m', 'CCNSA_weeks_high', 'CCNSA_weeks_high_diff_zscore_12m', 'CCNSA_weeks_high_diff_zscore_3m']
#   Removed 4 features
#
# ============================================================
# VIF Pruning: Weekly_Econ_Index (12 features)
# ============================================================
#   Iter 1: Removed Weekly_Econ_Index_monthly_avg (VIF=1318.9), 11 features remain
#   Iter 2: Removed Weekly_Econ_Index_monthly_avg_diff (VIF=29.0), 10 features remain
#   Iter 3: Removed Weekly_Econ_Index_monthly_max (VIF=23.1), 9 features remain
#   Iter 4: Removed Weekly_Econ_Index_monthly_avg_diff_zscore_12m (VIF=14.0), 8 features remain
#
#   Kept 8 features: ['Weekly_Econ_Index_monthly_avg_diff_zscore_3m', 'Weekly_Econ_Index_monthly_max_diff', 'Weekly_Econ_Index_monthly_max_diff_zscore_12m', 'Weekly_Econ_Index_monthly_max_diff_zscore_3m', 'Weekly_Econ_Index_monthly_min', 'Weekly_Econ_Index_monthly_min_diff', 'Weekly_Econ_Index_monthly_min_diff_zscore_12m', 'Weekly_Econ_Index_monthly_min_diff_zscore_3m']
#   Removed 4 features
#
# ============================================================
# VIF Pruning: Financial_Stress (4 features)
# ============================================================
#
#   Kept 4 features: ['Financial_Stress_monthly_avg', 'Financial_Stress_monthly_avg_diff', 'Financial_Stress_monthly_avg_diff_zscore_12m', 'Financial_Stress_monthly_avg_diff_zscore_3m']
#   Removed 0 features

# %% [markdown]
# ## 8. Cross-Group VIF Analysis
#
# After within-group pruning, check VIF across ALL remaining features.

# %%
# Collect all survivors
all_survivors = []
for group_name, survivors in group_survivors.items():
    all_survivors.extend(survivors)

print(f"Total features after within-group pruning: {len(all_survivors)}")
print(f"\nComputing cross-group VIF...")

cross_vif = compute_group_vif(wide, all_survivors, 'cross_group')
if not cross_vif.empty:
    print(f"\nCross-Group VIF (all {len(cross_vif)} features):")
    print(cross_vif.to_string(index=False))
    
    high_cross = cross_vif[cross_vif['VIF'] > 10]
    print(f"\n{len(high_cross)} features with cross-group VIF > 10")
# Out:
# Total features after within-group pruning: 133
#
# Computing cross-group VIF...
#   WARNING: cross_group has only 27 complete rows (need 50)
#
# Cross-Group VIF (all 133 features):
#       group                                        feature     VIF
# cross_group                                 ICSA_max_spike 2035.69
# cross_group                          ICSA_monthly_avg_diff 1813.28
# cross_group                         Yield_Curve_zscore_max 1710.19
# cross_group                                ICNSA_max_spike 1621.17
# cross_group                         ICNSA_monthly_avg_diff 1536.72
# cross_group                                Yield_Curve_avg 1435.11
# cross_group                               CCSA_monthly_avg 1118.70
# cross_group                              CCNSA_monthly_avg 1011.95
# cross_group                            ICSA_max_spike_diff 1009.73
# cross_group                      Credit_Spreads_zscore_max  920.05
# cross_group                           ICNSA_max_spike_diff  824.41
# cross_group                              Oil_worst_day_pct  709.97
# cross_group                             Credit_Spreads_avg  705.36
# cross_group                            CCSA_max_spike_diff  541.54
# cross_group                           CCNSA_max_spike_diff  458.22
# cross_group                 Credit_Spreads_zscore_max_diff  153.41
# cross_group                        Credit_Spreads_avg_diff  135.30
# cross_group                   Financial_Stress_monthly_avg  125.27
# cross_group                                  VIX_mean_diff  119.48
# cross_group                          Oil_Prices_zscore_min  104.79
# cross_group              Financial_Stress_monthly_avg_diff  100.07
# cross_group                               ICNSA_weeks_high   93.47
# cross_group                             SP500_max_drawdown   90.05
# cross_group                     SP500_days_circuit_breaker   87.85
# cross_group                                       VIX_mean   84.92
# cross_group                     Oil_Prices_volatility_diff   84.12
# cross_group                                ICSA_weeks_high   80.23
# cross_group                                Oil_Prices_mean   73.94
# cross_group                CCSA_weeks_high_diff_zscore_12m   70.38
# cross_group                           Oil_Prices_mean_diff   69.00
# cross_group                     Oil_Prices_zscore_min_diff   66.61
# cross_group                SP500_days_circuit_breaker_diff   65.76
# cross_group                 CCSA_weeks_high_diff_zscore_3m   61.61
# cross_group                          Oil_Prices_volatility   54.57
# cross_group      Credit_Spreads_zscore_max_diff_zscore_12m   52.56
# cross_group           Credit_Spreads_accel_volatility_diff   50.92
# cross_group                CCNSA_weeks_high_diff_zscore_3m   48.05
# cross_group                       VIX_mean_diff_zscore_12m   47.98
# cross_group                                  VIX_30d_spike   46.89
# cross_group               CCNSA_weeks_high_diff_zscore_12m   45.88
# cross_group                Oil_Prices_mean_diff_zscore_12m   43.39
# cross_group                               CCNSA_weeks_high   41.81
# cross_group                   Yield_Curve_monthly_chg_diff   41.21
# cross_group              CCNSA_monthly_avg_diff_zscore_12m   38.45
# cross_group             Credit_Spreads_avg_diff_zscore_12m   38.16
# cross_group                             VIX_30d_spike_diff   37.98
# cross_group                Credit_Spreads_accel_volatility   32.97
# cross_group                    Yield_Curve_zscore_max_diff   32.74
# cross_group                          VIX_max_5d_spike_diff   32.62
# cross_group               VIX_max_5d_spike_diff_zscore_12m   32.56
# cross_group                 VIX_volatility_diff_zscore_12m   32.41
# cross_group                                CCSA_weeks_high   30.76
# cross_group                               VIX_panic_regime   30.52
# cross_group               ICNSA_weeks_high_diff_zscore_12m   30.46
# cross_group  Credit_Spreads_vol_of_changes_diff_zscore_12m   28.79
# cross_group               Credit_Spreads_acceleration_diff   28.56
# cross_group                Credit_Spreads_monthly_chg_diff   28.37
# cross_group                           ICSA_weeks_high_diff   27.64
# cross_group                          ICNSA_weeks_high_diff   27.37
# cross_group     Credit_Spreads_monthly_chg_diff_zscore_12m   27.22
# cross_group                               VIX_max_5d_spike   27.15
# cross_group                 ICSA_weeks_high_diff_zscore_3m   26.77
# cross_group               CCNSA_monthly_avg_diff_zscore_3m   26.74
# cross_group                  Yield_Curve_acceleration_diff   26.67
# cross_group                        Yield_Curve_monthly_chg   26.60
# cross_group    Credit_Spreads_acceleration_diff_zscore_12m   25.26
# cross_group        Yield_Curve_monthly_chg_diff_zscore_12m   24.57
# cross_group   Financial_Stress_monthly_avg_diff_zscore_12m   23.66
# cross_group                 Oil_Prices_mean_diff_zscore_3m   23.39
# cross_group              ICNSA_monthly_avg_diff_zscore_12m   21.99
# cross_group             Weekly_Econ_Index_monthly_max_diff   21.93
# cross_group       Yield_Curve_acceleration_diff_zscore_12m   21.75
# cross_group                          SP500_circuit_breaker   21.34
# cross_group   Credit_Spreads_vol_of_changes_diff_zscore_3m   21.09
# cross_group             Weekly_Econ_Index_monthly_min_diff   20.85
# cross_group                        VIX_mean_diff_zscore_3m   19.85
# cross_group                    Credit_Spreads_acceleration   19.77
# cross_group Credit_Spreads_accel_volatility_diff_zscore_3m   19.70
# cross_group                  VIX_volatility_diff_zscore_3m   19.11
# cross_group              Oil_worst_day_pct_diff_zscore_12m   18.66
# cross_group               SP500_volatility_diff_zscore_12m   18.56
# cross_group           Oil_Prices_30d_crash_diff_zscore_12m   18.40
# cross_group                 CCNSA_max_spike_diff_zscore_3m   18.15
# cross_group          Oil_Prices_volatility_diff_zscore_12m   17.94
# cross_group                VIX_max_5d_spike_diff_zscore_3m   16.82
# cross_group      Yield_Curve_vol_of_changes_diff_zscore_3m   16.22
# cross_group                              SP500_bear_market   15.52
# cross_group                  Weekly_Econ_Index_monthly_min   15.47
# cross_group                            SP500_best_day_diff   15.40
# cross_group               ICNSA_monthly_avg_diff_zscore_3m   14.86
# cross_group                           SP500_monthly_return   14.85
# cross_group     Yield_Curve_vol_of_changes_diff_zscore_12m   14.84
# cross_group           Oil_Prices_zscore_min_diff_zscore_3m   14.37
# cross_group                Yield_Curve_avg_diff_zscore_12m   13.93
# cross_group                         VIX_max_diff_zscore_3m   13.78
# cross_group            Oil_Prices_30d_crash_diff_zscore_3m   13.62
# cross_group  Weekly_Econ_Index_monthly_max_diff_zscore_12m   13.62
# cross_group  Weekly_Econ_Index_monthly_min_diff_zscore_12m   12.99
# cross_group                                VIX_high_regime   12.97
# cross_group                              SP500_crash_month   12.39
# cross_group      Credit_Spreads_monthly_chg_diff_zscore_3m   11.87
# cross_group              Credit_Spreads_max_diff_zscore_3m   11.84
# cross_group     Credit_Spreads_acceleration_diff_zscore_3m   11.69
# cross_group                       Yield_Curve_acceleration   11.68
# cross_group        Yield_Curve_acceleration_diff_zscore_3m   11.39
# cross_group              Yield_Curve_accel_volatility_diff   11.24
# cross_group          Yield_Curve_zscore_max_diff_zscore_3m   11.16
# cross_group                SP500_volatility_diff_zscore_3m   11.09
# cross_group                  ICSA_max_spike_diff_zscore_3m   10.93
# cross_group               Oil_worst_day_pct_diff_zscore_3m   10.72
# cross_group               CCSA_monthly_avg_diff_zscore_12m   10.61
# cross_group               SP500_max_5d_drop_diff_zscore_3m   10.45
# cross_group   Weekly_Econ_Index_monthly_avg_diff_zscore_3m   10.29
# cross_group         Yield_Curve_monthly_chg_diff_zscore_3m   10.29
# cross_group                     Yield_Curve_vol_of_changes   10.10
# cross_group                   VIX_30d_spike_diff_zscore_3m    9.96
# cross_group   Weekly_Econ_Index_monthly_min_diff_zscore_3m    9.94
# cross_group                 Yield_Curve_avg_diff_zscore_3m    9.78
# cross_group              Credit_Spreads_avg_diff_zscore_3m    9.76
# cross_group    Yield_Curve_accel_volatility_diff_zscore_3m    9.69
# cross_group           Oil_Prices_volatility_diff_zscore_3m    9.51
# cross_group                CCSA_monthly_avg_diff_zscore_3m    9.49
# cross_group              SP500_max_drawdown_diff_zscore_3m    9.45
# cross_group   Weekly_Econ_Index_monthly_max_diff_zscore_3m    9.39
# cross_group    Financial_Stress_monthly_avg_diff_zscore_3m    9.33
# cross_group                 ICSA_max_spike_diff_zscore_12m    9.28
# cross_group                ICSA_monthly_avg_diff_zscore_3m    9.14
# cross_group            SP500_monthly_return_diff_zscore_3m    7.61
# cross_group                  SP500_best_day_diff_zscore_3m    7.59
# cross_group                 SP500_worst_day_diff_zscore_3m    7.12
# cross_group                  CCSA_max_spike_diff_zscore_3m    7.01
# cross_group     SP500_consecutive_down_days_diff_zscore_3m    5.51
# cross_group                    SP500_consecutive_down_days    5.28
#
# 115 features with cross-group VIF > 10

# %%
# Final cross-group pruning
print("\nFinal Cross-Group VIF Pruning (threshold=10):")
print("="*60)

final_survivors, final_removed = iterative_vif_pruning(
    wide, all_survivors, threshold=10.0, protected=PROTECTED
)

print(f"\n\nFinal feature set: {len(final_survivors)} features")
print(f"Total removed in cross-group: {len(final_removed)}")
# Out:
# Final Cross-Group VIF Pruning (threshold=10):
# ============================================================
#   Iter 1: Removed VIX_30d_spike (VIF=inf), 132 features remain
#   Iter 2: Removed VIX_30d_spike_diff (VIF=inf), 131 features remain
#   Iter 3: Removed VIX_30d_spike_diff_zscore_3m (VIF=inf), 130 features remain
#   Iter 4: Removed VIX_max_5d_spike (VIF=inf), 129 features remain
#   Iter 5: Removed VIX_max_5d_spike_diff (VIF=inf), 128 features remain
#   Iter 6: Removed VIX_max_5d_spike_diff_zscore_12m (VIF=inf), 127 features remain
#   Iter 7: Removed VIX_max_5d_spike_diff_zscore_3m (VIF=inf), 126 features remain
#   Iter 8: Removed VIX_max_diff_zscore_3m (VIF=inf), 125 features remain
#   Iter 9: Removed VIX_mean (VIF=inf), 124 features remain
#   Iter 10: Removed VIX_mean_diff (VIF=inf), 123 features remain
#   Iter 11: Removed VIX_mean_diff_zscore_12m (VIF=inf), 122 features remain
#   Iter 12: Removed VIX_mean_diff_zscore_3m (VIF=inf), 121 features remain
#   Iter 13: Removed VIX_volatility_diff_zscore_12m (VIF=inf), 120 features remain
#   Iter 14: Removed VIX_volatility_diff_zscore_3m (VIF=inf), 119 features remain
#   Iter 15: Removed SP500_best_day_diff (VIF=inf), 118 features remain
#   Iter 16: Removed SP500_best_day_diff_zscore_3m (VIF=inf), 117 features remain
#   Iter 17: Removed SP500_consecutive_down_days (VIF=inf), 116 features remain
#   Iter 18: Removed SP500_consecutive_down_days_diff_zscore_3m (VIF=inf), 115 features remain
#   Iter 19: Removed SP500_days_circuit_breaker (VIF=inf), 114 features remain
#   Iter 20: Removed SP500_days_circuit_breaker_diff (VIF=inf), 113 features remain
#   Iter 21: Removed SP500_max_5d_drop_diff_zscore_3m (VIF=inf), 112 features remain
#   Iter 22: Removed SP500_max_drawdown (VIF=inf), 111 features remain
#   Iter 23: Removed SP500_max_drawdown_diff_zscore_3m (VIF=inf), 110 features remain
#   Iter 24: Removed SP500_monthly_return (VIF=inf), 109 features remain
#   Iter 25: Removed SP500_monthly_return_diff_zscore_3m (VIF=inf), 108 features remain
#   Iter 26: Removed SP500_volatility_diff_zscore_12m (VIF=inf), 107 features remain
#   Iter 27: Removed SP500_volatility_diff_zscore_3m (VIF=inf), 106 features remain
#   Iter 28: Removed SP500_worst_day_diff_zscore_3m (VIF=inf), 105 features remain
#   Iter 29: Removed Credit_Spreads_accel_volatility (VIF=inf), 104 features remain
#   Iter 30: Removed Credit_Spreads_accel_volatility_diff (VIF=inf), 103 features remain
#   Iter 31: Removed Credit_Spreads_accel_volatility_diff_zscore_3m (VIF=inf), 102 features remain
#   Iter 32: Removed Credit_Spreads_acceleration (VIF=inf), 101 features remain
#   Iter 33: Removed Credit_Spreads_acceleration_diff (VIF=inf), 100 features remain
#   Iter 34: Removed Credit_Spreads_acceleration_diff_zscore_12m (VIF=inf), 99 features remain
#   Iter 35: Removed Credit_Spreads_acceleration_diff_zscore_3m (VIF=inf), 98 features remain
#   Iter 36: Removed Credit_Spreads_avg (VIF=inf), 97 features remain
#   Iter 37: Removed Credit_Spreads_avg_diff (VIF=inf), 96 features remain
#   Iter 38: Removed Credit_Spreads_avg_diff_zscore_12m (VIF=inf), 95 features remain
#   Iter 39: Removed Credit_Spreads_avg_diff_zscore_3m (VIF=inf), 94 features remain
#   Iter 40: Removed Credit_Spreads_max_diff_zscore_3m (VIF=inf), 93 features remain
#   Iter 41: Removed Credit_Spreads_monthly_chg_diff (VIF=inf), 92 features remain
#   Iter 42: Removed Credit_Spreads_monthly_chg_diff_zscore_12m (VIF=inf), 91 features remain
#   Iter 43: Removed Credit_Spreads_monthly_chg_diff_zscore_3m (VIF=inf), 90 features remain
#   Iter 44: Removed Credit_Spreads_vol_of_changes_diff_zscore_12m (VIF=inf), 89 features remain
#   Iter 45: Removed Credit_Spreads_vol_of_changes_diff_zscore_3m (VIF=inf), 88 features remain
#   Iter 46: Removed Credit_Spreads_zscore_max (VIF=inf), 87 features remain
#   Iter 47: Removed Credit_Spreads_zscore_max_diff (VIF=inf), 86 features remain
#   Iter 48: Removed Credit_Spreads_zscore_max_diff_zscore_12m (VIF=inf), 85 features remain
#   Iter 49: Removed Yield_Curve_accel_volatility_diff (VIF=inf), 84 features remain
#   Iter 50: Removed Yield_Curve_accel_volatility_diff_zscore_3m (VIF=inf), 83 features remain
#   Iter 51: Removed Yield_Curve_acceleration (VIF=inf), 82 features remain
#   Iter 52: Removed Yield_Curve_acceleration_diff (VIF=inf), 81 features remain
#   Iter 53: Removed Yield_Curve_acceleration_diff_zscore_12m (VIF=inf), 80 features remain
#   Iter 54: Removed Yield_Curve_acceleration_diff_zscore_3m (VIF=inf), 79 features remain
#   Iter 55: Removed Yield_Curve_avg (VIF=inf), 78 features remain
#   Iter 56: Removed Yield_Curve_avg_diff_zscore_12m (VIF=inf), 77 features remain
#   Iter 57: Removed Yield_Curve_avg_diff_zscore_3m (VIF=inf), 76 features remain
#   Iter 58: Removed Yield_Curve_monthly_chg (VIF=inf), 75 features remain
#   Iter 59: Removed Yield_Curve_monthly_chg_diff (VIF=inf), 74 features remain
#   Iter 60: Removed Yield_Curve_monthly_chg_diff_zscore_12m (VIF=inf), 73 features remain
#   Iter 61: Removed Yield_Curve_monthly_chg_diff_zscore_3m (VIF=inf), 72 features remain
#   Iter 62: Removed Yield_Curve_vol_of_changes (VIF=inf), 71 features remain
#   Iter 63: Removed Yield_Curve_vol_of_changes_diff_zscore_12m (VIF=inf), 70 features remain
#   Iter 64: Removed Yield_Curve_vol_of_changes_diff_zscore_3m (VIF=inf), 69 features remain
#   Iter 65: Removed Yield_Curve_zscore_max (VIF=inf), 68 features remain
#   Iter 66: Removed Yield_Curve_zscore_max_diff (VIF=inf), 67 features remain
#   Iter 67: Removed Yield_Curve_zscore_max_diff_zscore_3m (VIF=inf), 66 features remain
#   Iter 68: Removed Oil_Prices_30d_crash_diff_zscore_12m (VIF=inf), 65 features remain
#   Iter 69: Removed Oil_Prices_30d_crash_diff_zscore_3m (VIF=inf), 64 features remain
#   Iter 70: Removed Oil_Prices_mean (VIF=inf), 63 features remain
#   Iter 71: Removed Oil_Prices_mean_diff (VIF=inf), 62 features remain
#   Iter 72: Removed Oil_Prices_mean_diff_zscore_12m (VIF=inf), 61 features remain
#   Iter 73: Removed Oil_Prices_mean_diff_zscore_3m (VIF=inf), 60 features remain
#   Iter 74: Removed Oil_Prices_volatility (VIF=inf), 59 features remain
#   Iter 75: Removed Oil_Prices_volatility_diff (VIF=inf), 58 features remain
#   Iter 76: Removed Oil_Prices_volatility_diff_zscore_12m (VIF=inf), 57 features remain
#   Iter 77: Removed Oil_Prices_volatility_diff_zscore_3m (VIF=inf), 56 features remain
#   Iter 78: Removed Oil_Prices_zscore_min (VIF=inf), 55 features remain
#   Iter 79: Removed Oil_Prices_zscore_min_diff (VIF=inf), 54 features remain
#   Iter 80: Removed Oil_Prices_zscore_min_diff_zscore_3m (VIF=inf), 53 features remain
#   Iter 81: Removed Oil_worst_day_pct (VIF=inf), 52 features remain
#   Iter 82: Removed Oil_worst_day_pct_diff_zscore_12m (VIF=inf), 51 features remain
#   Iter 83: Removed Oil_worst_day_pct_diff_zscore_3m (VIF=inf), 50 features remain
#   Iter 84: Removed ICSA_max_spike (VIF=inf), 49 features remain
#   Iter 85: Removed ICSA_max_spike_diff (VIF=inf), 48 features remain
#   Iter 86: Removed ICSA_max_spike_diff_zscore_12m (VIF=inf), 47 features remain
#   Iter 87: Removed ICSA_max_spike_diff_zscore_3m (VIF=inf), 46 features remain
#   Iter 88: Removed ICSA_monthly_avg_diff (VIF=inf), 45 features remain
#   Iter 89: Removed ICSA_monthly_avg_diff_zscore_3m (VIF=inf), 44 features remain
#   Iter 90: Removed ICSA_weeks_high (VIF=inf), 43 features remain
#   Iter 91: Removed ICSA_weeks_high_diff (VIF=inf), 42 features remain
#   Iter 92: Removed ICSA_weeks_high_diff_zscore_3m (VIF=inf), 41 features remain
#   Iter 93: Removed ICNSA_max_spike (VIF=inf), 40 features remain
#   Iter 94: Removed ICNSA_max_spike_diff (VIF=inf), 39 features remain
#   Iter 95: Removed ICNSA_monthly_avg_diff (VIF=inf), 38 features remain
#   Iter 96: Removed ICNSA_monthly_avg_diff_zscore_12m (VIF=inf), 37 features remain
#   Iter 97: Removed ICNSA_monthly_avg_diff_zscore_3m (VIF=inf), 36 features remain
#   Iter 98: Removed ICNSA_weeks_high (VIF=inf), 35 features remain
#   Iter 99: Removed ICNSA_weeks_high_diff (VIF=inf), 34 features remain
#   Iter 100: Removed ICNSA_weeks_high_diff_zscore_12m (VIF=inf), 33 features remain
#   Iter 101: Removed CCSA_max_spike_diff (VIF=inf), 32 features remain
#   Iter 102: Removed CCSA_max_spike_diff_zscore_3m (VIF=inf), 31 features remain
#   Iter 103: Removed CCSA_monthly_avg (VIF=inf), 30 features remain
#   Iter 104: Removed CCSA_monthly_avg_diff_zscore_12m (VIF=inf), 29 features remain
#   Iter 105: Removed CCSA_monthly_avg_diff_zscore_3m (VIF=inf), 28 features remain
#   Iter 106: Removed CCSA_weeks_high (VIF=inf), 27 features remain
#   Iter 107: Removed CCSA_weeks_high_diff_zscore_3m (VIF=inf), 26 features remain
#   Iter 108: Removed Weekly_Econ_Index_monthly_min (VIF=20221.6), 25 features remain
#   Iter 109: Removed Financial_Stress_monthly_avg_diff (VIF=4812.4), 24 features remain
#   Iter 110: Removed Weekly_Econ_Index_monthly_min_diff_zscore_12m (VIF=375.8), 23 features remain
#   Iter 111: Removed Weekly_Econ_Index_monthly_max_diff_zscore_12m (VIF=58.1), 22 features remain
#   Iter 112: Removed Weekly_Econ_Index_monthly_avg_diff_zscore_3m (VIF=53.6), 21 features remain
#   Iter 113: Removed CCNSA_weeks_high_diff_zscore_12m (VIF=33.7), 20 features remain
#   Iter 114: Removed CCNSA_monthly_avg_diff_zscore_12m (VIF=21.5), 19 features remain
#   Iter 115: Removed Weekly_Econ_Index_monthly_max_diff (VIF=14.7), 18 features remain
#   Iter 116: Removed Financial_Stress_monthly_avg (VIF=12.7), 17 features remain
#   Iter 117: Removed CCNSA_max_spike_diff (VIF=10.3), 16 features remain
#
#
# Final feature set: 16 features
# Total removed in cross-group: 117

# %% [markdown]
# ## 9. Final Summary & Recommendations

# %%
print("FINAL RECOMMENDED FEATURE SET")
print("=" * 60)
print(f"\nTotal features: {len(final_survivors)}")

# Categorize final features
final_by_group = {}
for feat in sorted(final_survivors):
    # Determine group
    found = False
    for group_name, group_feats in SERIES_GROUPS.items():
        # Check if this feature belongs to the group (could be a _diff or _zscore variant)
        for gf in group_feats:
            if feat == gf or feat.startswith(gf):
                final_by_group.setdefault(group_name, []).append(feat)
                found = True
                break
        if found:
            break
    if not found:
        final_by_group.setdefault('OTHER', []).append(feat)

for group_name in SERIES_GROUPS.keys():
    feats = final_by_group.get(group_name, [])
    if feats:
        print(f"\n{group_name} ({len(feats)} features):")
        for f in feats:
            transform = 'level'
            if f.endswith('_diff_zscore_12m'):
                transform = 'diff_zscore_12m'
            elif f.endswith('_diff_zscore_3m'):
                transform = 'diff_zscore_3m'
            elif f.endswith('_diff'):
                transform = 'diff'
            print(f"    {f:55s} [{transform}]")
# Out:
# FINAL RECOMMENDED FEATURE SET
# ============================================================
#
# Total features: 16
#
# VIX (2 features):
#     VIX_high_regime                                         [level]
#     VIX_panic_regime                                        [level]
#
# SP500 (3 features):
#     SP500_bear_market                                       [level]
#     SP500_circuit_breaker                                   [level]
#     SP500_crash_month                                       [level]
#
# CCSA (1 features):
#     CCSA_weeks_high_diff_zscore_12m                         [diff_zscore_12m]
#
# CCNSA (5 features):
#     CCNSA_max_spike_diff_zscore_3m                          [diff_zscore_3m]
#     CCNSA_monthly_avg                                       [level]
#     CCNSA_monthly_avg_diff_zscore_3m                        [diff_zscore_3m]
#     CCNSA_weeks_high                                        [level]
#     CCNSA_weeks_high_diff_zscore_3m                         [diff_zscore_3m]
#
# Weekly_Econ_Index (3 features):
#     Weekly_Econ_Index_monthly_max_diff_zscore_3m            [diff_zscore_3m]
#     Weekly_Econ_Index_monthly_min_diff                      [diff]
#     Weekly_Econ_Index_monthly_min_diff_zscore_3m            [diff_zscore_3m]
#
# Financial_Stress (2 features):
#     Financial_Stress_monthly_avg_diff_zscore_12m            [diff_zscore_12m]
#     Financial_Stress_monthly_avg_diff_zscore_3m             [diff_zscore_3m]

# %%
# Summary of what was removed and why
print("\nREMOVAL SUMMARY")
print("=" * 60)

print("\n--- Within-Group Removals ---")
total_within = 0
for group_name, removed in group_removed.items():
    if removed:
        print(f"\n{group_name}:")
        for feat, vif in removed:
            print(f"  Removed: {feat:50s} VIF={vif}")
        total_within += len(removed)
print(f"\nTotal within-group removals: {total_within}")

print("\n--- Cross-Group Removals ---")
if final_removed:
    for feat, vif in final_removed:
        print(f"  Removed: {feat:50s} VIF={vif}")
print(f"Total cross-group removals: {len(final_removed)}")

print(f"\n{'='*60}")
print(f"Started with:  {len(wide.columns)} features")
print(f"Removed:       {len(wide.columns) - len(final_survivors)} features")
print(f"Final set:     {len(final_survivors)} features")
# Out:
# REMOVAL SUMMARY
# ============================================================
#
# --- Within-Group Removals ---
#
# VIX:
#   Removed: VIX_max                                            VIF=121.55
#   Removed: VIX_max_diff                                       VIF=28.63
#   Removed: VIX_volatility_diff                                VIF=18.92
#   Removed: VIX_volatility                                     VIF=13.51
#   Removed: VIX_max_diff_zscore_12m                            VIF=11.26
#   Removed: VIX_30d_spike_diff_zscore_12m                      VIF=10.33
#
# SP500:
#   Removed: SP500_30d_return                                   VIF=inf
#   Removed: SP500_30d_return_diff                              VIF=inf
#   Removed: SP500_30d_return_diff_zscore_12m                   VIF=inf
#   Removed: SP500_30d_return_diff_zscore_3m                    VIF=inf
#   Removed: SP500_best_day                                     VIF=inf
#   Removed: SP500_days_circuit_breaker_diff_zscore_12m         VIF=4650.0
#   Removed: SP500_max_5d_drop_diff                             VIF=929.63
#   Removed: SP500_max_drawdown_diff_zscore_12m                 VIF=659.63
#   Removed: SP500_max_5d_drop_diff_zscore_12m                  VIF=221.31
#   Removed: SP500_worst_day_diff                               VIF=144.44
#   Removed: SP500_consecutive_down_days_diff                   VIF=101.25
#   Removed: SP500_worst_day_diff_zscore_12m                    VIF=71.0
#   Removed: SP500_volatility                                   VIF=64.35
#   Removed: SP500_monthly_return_diff                          VIF=61.44
#   Removed: SP500_worst_day                                    VIF=48.6
#   Removed: SP500_volatility_diff                              VIF=29.08
#   Removed: SP500_max_5d_drop                                  VIF=27.62
#   Removed: SP500_best_day_diff_zscore_12m                     VIF=22.4
#   Removed: SP500_days_circuit_breaker_diff_zscore_3m          VIF=19.15
#   Removed: SP500_consecutive_down_days_diff_zscore_12m        VIF=12.4
#   Removed: SP500_max_drawdown_diff                            VIF=11.58
#   Removed: SP500_monthly_return_diff_zscore_12m               VIF=10.24
#
# Credit_Spreads:
#   Removed: Credit_Spreads_max                                 VIF=846.77
#   Removed: Credit_Spreads_max_diff_zscore_12m                 VIF=73.31
#   Removed: Credit_Spreads_vol_of_changes                      VIF=48.54
#   Removed: Credit_Spreads_zscore_max_diff_zscore_3m           VIF=46.22
#   Removed: Credit_Spreads_max_diff                            VIF=27.84
#   Removed: Credit_Spreads_vol_of_changes_diff                 VIF=24.75
#   Removed: Credit_Spreads_accel_volatility_diff_zscore_12m    VIF=13.62
#   Removed: Credit_Spreads_monthly_chg                         VIF=12.5
#
# Yield_Curve:
#   Removed: Yield_Curve_max                                    VIF=702.16
#   Removed: Yield_Curve_max_diff_zscore_3m                     VIF=154.08
#   Removed: Yield_Curve_max_diff_zscore_12m                    VIF=82.12
#   Removed: Yield_Curve_accel_volatility                       VIF=52.41
#   Removed: Yield_Curve_max_diff                               VIF=31.12
#   Removed: Yield_Curve_accel_volatility_diff_zscore_12m       VIF=16.14
#   Removed: Yield_Curve_avg_diff                               VIF=12.9
#   Removed: Yield_Curve_zscore_max_diff_zscore_12m             VIF=11.46
#   Removed: Yield_Curve_vol_of_changes_diff                    VIF=10.04
#
# Oil_Prices:
#   Removed: Oil_Prices_30d_crash_diff                          VIF=39.65
#   Removed: Oil_Prices_30d_crash                               VIF=23.13
#   Removed: Oil_worst_day_pct_diff                             VIF=14.36
#   Removed: Oil_Prices_zscore_min_diff_zscore_12m              VIF=13.62
#
# ICSA:
#   Removed: ICSA_monthly_avg                                   VIF=531.99
#   Removed: ICSA_weeks_high_diff_zscore_12m                    VIF=24.58
#   Removed: ICSA_monthly_avg_diff_zscore_12m                   VIF=11.05
#
# ICNSA:
#   Removed: ICNSA_monthly_avg                                  VIF=231.26
#   Removed: ICNSA_max_spike_diff_zscore_12m                    VIF=52.81
#   Removed: ICNSA_max_spike_diff_zscore_3m                     VIF=17.13
#   Removed: ICNSA_weeks_high_diff_zscore_3m                    VIF=10.29
#
# CCSA:
#   Removed: CCSA_max_spike                                     VIF=202.17
#   Removed: CCSA_max_spike_diff_zscore_12m                     VIF=32.95
#   Removed: CCSA_weeks_high_diff                               VIF=14.3
#   Removed: CCSA_monthly_avg_diff                              VIF=10.85
#
# CCNSA:
#   Removed: CCNSA_max_spike                                    VIF=200.7
#   Removed: CCNSA_weeks_high_diff                              VIF=29.77
#   Removed: CCNSA_max_spike_diff_zscore_12m                    VIF=23.06
#   Removed: CCNSA_monthly_avg_diff                             VIF=13.26
#
# Weekly_Econ_Index:
#   Removed: Weekly_Econ_Index_monthly_avg                      VIF=1318.9
#   Removed: Weekly_Econ_Index_monthly_avg_diff                 VIF=29.04
#   Removed: Weekly_Econ_Index_monthly_max                      VIF=23.05
#   Removed: Weekly_Econ_Index_monthly_avg_diff_zscore_12m      VIF=13.99
#
# Total within-group removals: 68
#
# --- Cross-Group Removals ---
#   Removed: VIX_30d_spike                                      VIF=inf
#   Removed: VIX_30d_spike_diff                                 VIF=inf
#   Removed: VIX_30d_spike_diff_zscore_3m                       VIF=inf
#   Removed: VIX_max_5d_spike                                   VIF=inf
#   Removed: VIX_max_5d_spike_diff                              VIF=inf
#   Removed: VIX_max_5d_spike_diff_zscore_12m                   VIF=inf
#   Removed: VIX_max_5d_spike_diff_zscore_3m                    VIF=inf
#   Removed: VIX_max_diff_zscore_3m                             VIF=inf
#   Removed: VIX_mean                                           VIF=inf
#   Removed: VIX_mean_diff                                      VIF=inf
#   Removed: VIX_mean_diff_zscore_12m                           VIF=inf
#   Removed: VIX_mean_diff_zscore_3m                            VIF=inf
#   Removed: VIX_volatility_diff_zscore_12m                     VIF=inf
#   Removed: VIX_volatility_diff_zscore_3m                      VIF=inf
#   Removed: SP500_best_day_diff                                VIF=inf
#   Removed: SP500_best_day_diff_zscore_3m                      VIF=inf
#   Removed: SP500_consecutive_down_days                        VIF=inf
#   Removed: SP500_consecutive_down_days_diff_zscore_3m         VIF=inf
#   Removed: SP500_days_circuit_breaker                         VIF=inf
#   Removed: SP500_days_circuit_breaker_diff                    VIF=inf
#   Removed: SP500_max_5d_drop_diff_zscore_3m                   VIF=inf
#   Removed: SP500_max_drawdown                                 VIF=inf
#   Removed: SP500_max_drawdown_diff_zscore_3m                  VIF=inf
#   Removed: SP500_monthly_return                               VIF=inf
#   Removed: SP500_monthly_return_diff_zscore_3m                VIF=inf
#   Removed: SP500_volatility_diff_zscore_12m                   VIF=inf
#   Removed: SP500_volatility_diff_zscore_3m                    VIF=inf
#   Removed: SP500_worst_day_diff_zscore_3m                     VIF=inf
#   Removed: Credit_Spreads_accel_volatility                    VIF=inf
#   Removed: Credit_Spreads_accel_volatility_diff               VIF=inf
#   Removed: Credit_Spreads_accel_volatility_diff_zscore_3m     VIF=inf
#   Removed: Credit_Spreads_acceleration                        VIF=inf
#   Removed: Credit_Spreads_acceleration_diff                   VIF=inf
#   Removed: Credit_Spreads_acceleration_diff_zscore_12m        VIF=inf
#   Removed: Credit_Spreads_acceleration_diff_zscore_3m         VIF=inf
#   Removed: Credit_Spreads_avg                                 VIF=inf
#   Removed: Credit_Spreads_avg_diff                            VIF=inf
#   Removed: Credit_Spreads_avg_diff_zscore_12m                 VIF=inf
#   Removed: Credit_Spreads_avg_diff_zscore_3m                  VIF=inf
#   Removed: Credit_Spreads_max_diff_zscore_3m                  VIF=inf
#   Removed: Credit_Spreads_monthly_chg_diff                    VIF=inf
#   Removed: Credit_Spreads_monthly_chg_diff_zscore_12m         VIF=inf
#   Removed: Credit_Spreads_monthly_chg_diff_zscore_3m          VIF=inf
#   Removed: Credit_Spreads_vol_of_changes_diff_zscore_12m      VIF=inf
#   Removed: Credit_Spreads_vol_of_changes_diff_zscore_3m       VIF=inf
#   Removed: Credit_Spreads_zscore_max                          VIF=inf
#   Removed: Credit_Spreads_zscore_max_diff                     VIF=inf
#   Removed: Credit_Spreads_zscore_max_diff_zscore_12m          VIF=inf
#   Removed: Yield_Curve_accel_volatility_diff                  VIF=inf
#   Removed: Yield_Curve_accel_volatility_diff_zscore_3m        VIF=inf
#   Removed: Yield_Curve_acceleration                           VIF=inf
#   Removed: Yield_Curve_acceleration_diff                      VIF=inf
#   Removed: Yield_Curve_acceleration_diff_zscore_12m           VIF=inf
#   Removed: Yield_Curve_acceleration_diff_zscore_3m            VIF=inf
#   Removed: Yield_Curve_avg                                    VIF=inf
#   Removed: Yield_Curve_avg_diff_zscore_12m                    VIF=inf
#   Removed: Yield_Curve_avg_diff_zscore_3m                     VIF=inf
#   Removed: Yield_Curve_monthly_chg                            VIF=inf
#   Removed: Yield_Curve_monthly_chg_diff                       VIF=inf
#   Removed: Yield_Curve_monthly_chg_diff_zscore_12m            VIF=inf
#   Removed: Yield_Curve_monthly_chg_diff_zscore_3m             VIF=inf
#   Removed: Yield_Curve_vol_of_changes                         VIF=inf
#   Removed: Yield_Curve_vol_of_changes_diff_zscore_12m         VIF=inf
#   Removed: Yield_Curve_vol_of_changes_diff_zscore_3m          VIF=inf
#   Removed: Yield_Curve_zscore_max                             VIF=inf
#   Removed: Yield_Curve_zscore_max_diff                        VIF=inf
#   Removed: Yield_Curve_zscore_max_diff_zscore_3m              VIF=inf
#   Removed: Oil_Prices_30d_crash_diff_zscore_12m               VIF=inf
#   Removed: Oil_Prices_30d_crash_diff_zscore_3m                VIF=inf
#   Removed: Oil_Prices_mean                                    VIF=inf
#   Removed: Oil_Prices_mean_diff                               VIF=inf
#   Removed: Oil_Prices_mean_diff_zscore_12m                    VIF=inf
#   Removed: Oil_Prices_mean_diff_zscore_3m                     VIF=inf
#   Removed: Oil_Prices_volatility                              VIF=inf
#   Removed: Oil_Prices_volatility_diff                         VIF=inf
#   Removed: Oil_Prices_volatility_diff_zscore_12m              VIF=inf
#   Removed: Oil_Prices_volatility_diff_zscore_3m               VIF=inf
#   Removed: Oil_Prices_zscore_min                              VIF=inf
#   Removed: Oil_Prices_zscore_min_diff                         VIF=inf
#   Removed: Oil_Prices_zscore_min_diff_zscore_3m               VIF=inf
#   Removed: Oil_worst_day_pct                                  VIF=inf
#   Removed: Oil_worst_day_pct_diff_zscore_12m                  VIF=inf
#   Removed: Oil_worst_day_pct_diff_zscore_3m                   VIF=inf
#   Removed: ICSA_max_spike                                     VIF=inf
#   Removed: ICSA_max_spike_diff                                VIF=inf
#   Removed: ICSA_max_spike_diff_zscore_12m                     VIF=inf
#   Removed: ICSA_max_spike_diff_zscore_3m                      VIF=inf
#   Removed: ICSA_monthly_avg_diff                              VIF=inf
#   Removed: ICSA_monthly_avg_diff_zscore_3m                    VIF=inf
#   Removed: ICSA_weeks_high                                    VIF=inf
#   Removed: ICSA_weeks_high_diff                               VIF=inf
#   Removed: ICSA_weeks_high_diff_zscore_3m                     VIF=inf
#   Removed: ICNSA_max_spike                                    VIF=inf
#   Removed: ICNSA_max_spike_diff                               VIF=inf
#   Removed: ICNSA_monthly_avg_diff                             VIF=inf
#   Removed: ICNSA_monthly_avg_diff_zscore_12m                  VIF=inf
#   Removed: ICNSA_monthly_avg_diff_zscore_3m                   VIF=inf
#   Removed: ICNSA_weeks_high                                   VIF=inf
#   Removed: ICNSA_weeks_high_diff                              VIF=inf
#   Removed: ICNSA_weeks_high_diff_zscore_12m                   VIF=inf
#   Removed: CCSA_max_spike_diff                                VIF=inf
#   Removed: CCSA_max_spike_diff_zscore_3m                      VIF=inf
#   Removed: CCSA_monthly_avg                                   VIF=inf
#   Removed: CCSA_monthly_avg_diff_zscore_12m                   VIF=inf
#   Removed: CCSA_monthly_avg_diff_zscore_3m                    VIF=inf
#   Removed: CCSA_weeks_high                                    VIF=inf
#   Removed: CCSA_weeks_high_diff_zscore_3m                     VIF=inf
#   Removed: Weekly_Econ_Index_monthly_min                      VIF=20221.65
#   Removed: Financial_Stress_monthly_avg_diff                  VIF=4812.37
#   Removed: Weekly_Econ_Index_monthly_min_diff_zscore_12m      VIF=375.83
#   Removed: Weekly_Econ_Index_monthly_max_diff_zscore_12m      VIF=58.11
#   Removed: Weekly_Econ_Index_monthly_avg_diff_zscore_3m       VIF=53.64
#   Removed: CCNSA_weeks_high_diff_zscore_12m                   VIF=33.71
#   Removed: CCNSA_monthly_avg_diff_zscore_12m                  VIF=21.49
#   Removed: Weekly_Econ_Index_monthly_max_diff                 VIF=14.71
#   Removed: Financial_Stress_monthly_avg                       VIF=12.72
#   Removed: CCNSA_max_spike_diff                               VIF=10.26
# Total cross-group removals: 117
#
# ============================================================
# Started with:  201 features
# Removed:       185 features
# Final set:     16 features

# %%
# --- CUSTOM CROSS-GROUP VIF (NO STALEMATE + ENHANCED LOGGING) ---
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

print("\n" + "="*80)
print("  CUSTOM CROSS-GROUP VIF ANALYSIS (No Stalemate, Enhanced Logging)")
print("="*80 + "\n")

# --- 1. Preparation ---
# Ensure we have the target variable (SA Winsorized) for correlation checks
# Assuming `y_sa_all` or similar exists from earlier cells. 
# If not, try to reconstruct or use what we have.
# The user mentioned "winsorized MoM difference of our targets in the notebook".
# Let's look for variables like `target_sa`, `y_sa_all`, `target_sa_winsorized`.

# Attempt to find the target variable
y_target_ref = None
target_var_name = "Unknown"

# Check possible variable names in locals() - simplistic check since we are running in the NB
# We will trust `y_sa_all` exists if defined in earlier cells (Cell 16 in original, maybe here too?)
# If not, we fall back to something else or fail gracefully.
if 'y_sa_all' in locals():
    y_target_ref = y_sa_all
    target_var_name = "y_sa_all (Winsorized)"
elif 'target_sa' in locals() and 'y_mom' in target_sa:
    from utils.transforms import winsorize_covid_period
    y_target_ref = winsorize_covid_period(target_sa['y_mom'])
    target_var_name = "target_sa['y_mom'] (Winsorized)"
else:
    # Fallback: We need a target to make decisions!
    print("WARNING: Could not find 'y_sa_all' or 'target_sa'. Cannot prioritize by correlation!")
    # We will try to load it if possible, or just fail.
    # For now, let's assume the user ran the previous cells which likely set this up.
    pass

if y_target_ref is not None:
    print(f"Using Target Variable: {target_var_name}")

# Align Data
# 'wide' is the feature matrix (from Cell 4)
# 'all_survivors' is the list of features after within-group pruning (Cell 18)

X_combined = wide[all_survivors].copy()
common_idx = X_combined.dropna().index
if y_target_ref is not None:
    common_idx = common_idx.intersection(y_target_ref.dropna().index)

X_clean = X_combined.loc[common_idx]
y_clean = y_target_ref.loc[common_idx] if y_target_ref is not None else None

print(f"Data Shape: {X_clean.shape} (Common Rows with Target)")

# --- 2. Identify Champions & Categories ---
# Helper to get group
def get_feature_group(feat):
    for g, feats in SERIES_GROUPS.items():
        if feat in feats: return g
        # Also check if it's a derived feature starting with a known base
        for f in feats:
            if feat.startswith(f): return g
    return "Other"

feature_groups = {f: get_feature_group(f) for f in X_clean.columns}
groups_unique = set(feature_groups.values())

# Calculate correlations
corrs = X_clean.corrwith(y_clean).abs() if y_clean is not None else pd.Series(0, index=X_clean.columns)

# Identify Initial Champions (Best of each group)
champions = {}
for g in groups_unique:
    g_feats = [f for f in X_clean.columns if feature_groups[f] == g]
    if g_feats:
        # Find max correlation
        best_f = corrs[g_feats].idxmax()
        champions[g] = best_f
        print(f"  Group '{g}' Champion: {best_f} (Corr={corrs[best_f]:.4f})")

# --- 3. Iterative VIF Loop ---
# We track dropped champions and last survivors
dropped_champions = [] # List of dicts
category_last_survivor = {} # g -> feature when it was the last one dropped (if whole category wiped)

curr_features = X_clean.columns.tolist()
VIF_THRESHOLD = 10.0
iteration = 0

print(f"\nScanning for High VIF (> {VIF_THRESHOLD})...")

while len(curr_features) > 1:
    X_curr = X_clean[curr_features]
    
    # Calc VIF
    try:
        vifs = pd.Series(
            [variance_inflation_factor(X_curr.values, i) for i in range(X_curr.shape[1])],
            index=X_curr.columns
        )
    except Exception as e:
        print(f"  VIF Error: {e}. Stopping.")
        break
    
    max_vif = vifs.max()
    if max_vif <= VIF_THRESHOLD:
        print(f"  Max VIF = {max_vif:.2f} <= {VIF_THRESHOLD}. Converged.")
        break
        
    feat_max = vifs.idxmax()
    
    # Identification of partner
    curr_corr_mat = X_curr.corr().abs()
    partner = curr_corr_mat[feat_max].drop(feat_max).idxmax()
    corr_pair = curr_corr_mat.loc[feat_max, partner]
    
    # Decide who to drop
    # Rule: Drop the one with LOWER correlation to target
    corr_max = corrs[feat_max]
    corr_partner = corrs[partner]
    
    if corr_max < corr_partner:
        drop_cand = feat_max
        keep_cand = partner
        drop_corr = corr_max
        keep_corr = corr_partner
    else:
        drop_cand = partner
        keep_cand = feat_max
        drop_corr = corr_partner
        keep_corr = corr_max
        
    # LOGGING
    # Check if drop_cand was a champion
    drop_group = feature_groups[drop_cand]
    is_champion = (drop_cand == champions.get(drop_group))
    
    log_msg = f"  Iter {iteration+1}: Dropping {drop_cand} (VIF={vifs[drop_cand] if drop_cand==feat_max else 'Partner'}, Corr={drop_corr:.4f}) vs {keep_cand} (Corr={keep_corr:.4f}). PairCorr={corr_pair:.2f}"
    
    if is_champion:
        log_msg += " [CHAMPION DROPPED]"
        # Record stats
        dropped_champions.append({
            'Feature': drop_cand,
            'Group': drop_group,
            'Type': 'Champion',
            'VIF_at_Drop': vifs[drop_cand] if drop_cand in vifs else vifs.max(), # approx
            'Corr_SA_Winsorized': drop_corr,
            'Corr_NSA_Winsorized': np.nan, # We'll fill later if NSA avail
            'Dropped_By': keep_cand
        })
        
    print(log_msg)
    
    # Check if this is the LAST feature of the group
    remaining_in_group = [f for f in curr_features if feature_groups[f] == drop_group]
    if len(remaining_in_group) == 1:
        # This was the last survivor!
        print(f"    -> Category '{drop_group}' eliminated! Last survivor: {drop_cand}")
        category_last_survivor[drop_group] = drop_cand
        # Also record it
        dropped_champions.append({
            'Feature': drop_cand,
            'Group': drop_group,
            'Type': 'Last Survivor',
            'VIF_at_Drop': vifs[drop_cand] if drop_cand in vifs else vifs.max(),
            'Corr_SA_Winsorized': drop_corr,
            'Corr_NSA_Winsorized': np.nan,
            'Dropped_By': keep_cand
        })
        
    curr_features.remove(drop_cand)
    iteration += 1

# --- 4. Final Output Generation ---

# A. Final Table with VIF
final_vifs = [variance_inflation_factor(X_clean[curr_features].values, i) for i in range(len(curr_features))]
df_final = pd.DataFrame({
    'Feature': curr_features,
    'Group': [feature_groups[f] for f in curr_features],
    'VIF': final_vifs,
    'Corr_SA_Winsorized': [corrs[f] for f in curr_features]
}).sort_values('Corr_SA_Winsorized', ascending=False)

# Add NSA Correlations if available
# Assuming `y_nsa_all` exists or `target_nsa`
y_nsa_ref = None
if 'y_nsa_all' in locals():
    y_nsa_ref = y_nsa_all
elif 'target_nsa' in locals() and 'y_mom' in target_nsa:
    from utils.transforms import winsorize_covid_period
    y_nsa_ref = winsorize_covid_period(target_nsa['y_mom'])

if y_nsa_ref is not None:
    # Need to align indices separately for NSA correlation? 
    # Or just use common_idx? Common idx is usually subset of all. 
    # We'll use common_idx for simplicity/comparability.
    corrs_nsa = X_clean.corrwith(y_nsa_ref.loc[common_idx])
    df_final['Corr_NSA_Winsorized'] = df_final['Feature'].map(corrs_nsa)
    
    # Update dropped champions table too
    for rec in dropped_champions:
        rec['Corr_NSA_Winsorized'] = corrs_nsa.get(rec['Feature'], np.nan)

print("\n" + "="*80)
print("FINAL SELECTED FEATURES TABLE")
print("="*80)
display(df_final.style.format({
    'VIF': '{:.2f}',
    'Corr_SA_Winsorized': '{:.4f}',
    'Corr_NSA_Winsorized': '{:.4f}'
}).background_gradient(cmap='coolwarm', subset=['Corr_SA_Winsorized']))


# B. Dropped Champions / Last Survivors Table
if dropped_champions:
    df_dropped = pd.DataFrame(dropped_champions)
    # Deduplicate if a feature was both Champion and Last Survivor (keep Last Survivor tag?)
    # Or just show all events.
    
    print("\n" + "="*80)
    print("DROPPED CHAMPIONS & LAST SURVIVORS")
    print("="*80)
    display(df_dropped.style.format({
        'VIF_at_Drop': '{:.2f}',
        'Corr_SA_Winsorized': '{:.4f}',
        'Corr_NSA_Winsorized': '{:.4f}'
    }))
else:
    print("\nNo Champions or Category Last Survivors were dropped.")

# C. Summary
print(f"\nFinal Count: {len(df_final)} features.")
# Out:
# Final VIF Verification (should all be <= 10):
# ============================================================
#   WARNING: final has only 41 complete rows (need 50)
# group                                      feature  VIF
# final               CCNSA_max_spike_diff_zscore_3m 4.84
# final             CCNSA_monthly_avg_diff_zscore_3m 4.83
# final                             VIX_panic_regime 3.45
# final Financial_Stress_monthly_avg_diff_zscore_12m 2.54
# final                             CCNSA_weeks_high 2.51
# final                              VIX_high_regime 2.44
# final                        SP500_circuit_breaker 2.43
# final  Financial_Stress_monthly_avg_diff_zscore_3m 2.28
# final                            CCNSA_monthly_avg 2.19
# final              CCSA_weeks_high_diff_zscore_12m 2.02
# final              CCNSA_weeks_high_diff_zscore_3m 1.89
# final                            SP500_crash_month 1.81
# final           Weekly_Econ_Index_monthly_min_diff 1.73
# final                            SP500_bear_market 1.60
# final Weekly_Econ_Index_monthly_min_diff_zscore_3m 1.41
# final Weekly_Econ_Index_monthly_max_diff_zscore_3m 1.11
#
# Max VIF: 4.84 (PASS)
