# %% [markdown]
# # FRED Employment Feature Analysis
#
# Automated 7-stage feature selection pipeline for FRED employment data.
#
# **Data**: `data/fred_data_prepared/decades/` — wide-format parquet snapshots with ~50K
# pre-engineered features across ~312 employment sub-series.
#
# **Snapshots**:
# - **Pre-COVID**: December 2019
# - **Latest**: Most recent snapshot
#
# **Sector groups** (18 groups derived from BLS hierarchy):
# Government (federal, state, local), Private Goods (construction, manufacturing, mining),
# Private Services (trade, financial, professional, education, information, leisure, other),
# and top-level aggregates.
#
# **Pipeline stages**:
# 1. Group-wise Dual Filter (Purged Corr + LightGBM + VIF)
# 2. Boruta Feature Selection
# 3. Vintage Stability
# 4. Cluster Redundancy
# 5. Interaction Rescue
# 6. Sequential Forward Selection
# 7. Union MoM + Acc per variant → 2 JSON files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys
import warnings
warnings.filterwarnings('ignore')

# Add project root to path
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

from settings import DATA_PATH
from utils.transforms import winsorize_covid_period

# Styling
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 10
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.float_format', lambda x: '{:.4f}'.format(x))

# %% [markdown]
# ## 1. Load Data

# %%
# --- Paths ---
FRED_EMP_DIR = DATA_PATH / "fred_data_prepared" / "decades"
TARGET_DIR = DATA_PATH / "NFP_target"

# --- Load pre-COVID snapshot (Dec 2019) ---
pre_covid_path = FRED_EMP_DIR / "2010s" / "2019" / "2019-12.parquet"
snap_pre = pd.read_parquet(pre_covid_path)
snap_pre.index = pd.to_datetime(snap_pre.index)
snap_pre.index.name = 'date'
print(f"Pre-COVID snapshot: {snap_pre.shape[1]} features, "
      f"{snap_pre.index.min().date()} to {snap_pre.index.max().date()}")

# --- Find and load latest snapshot ---
latest_files = sorted(FRED_EMP_DIR.rglob('*.parquet'))
latest_path = latest_files[-1]
snap_latest = pd.read_parquet(latest_path)
snap_latest.index = pd.to_datetime(snap_latest.index)
snap_latest.index.name = 'date'
print(f"Latest snapshot: {latest_path.stem} -- {snap_latest.shape[1]} features, "
      f"{snap_latest.index.min().date()} to {snap_latest.index.max().date()}")

# --- Load NFP target data ---
target_nsa = pd.read_parquet(TARGET_DIR / "total_nsa_first_release.parquet")
target_sa  = pd.read_parquet(TARGET_DIR / "total_sa_first_release.parquet")

# Compute MoM difference and acceleration
for df in [target_nsa, target_sa]:
    df['ds'] = pd.to_datetime(df['ds'])
    df.sort_values('ds', inplace=True)
    df['y_mom'] = df['y'].diff()
    df['y_acc'] = df['y_mom'].diff()

target_nsa = target_nsa.dropna(subset=['y_mom']).set_index('ds')
target_sa  = target_sa.dropna(subset=['y_mom']).set_index('ds')

print(f"\nNSA target: {len(target_nsa)} months "
      f"({target_nsa.index.min().date()} to {target_nsa.index.max().date()})")
print(f"SA  target: {len(target_sa)} months "
      f"({target_sa.index.min().date()} to {target_sa.index.max().date()})")
# Out:
# Pre-COVID snapshot: 49536 features, 1939-02-01 to 2019-11-01
# Latest snapshot: 2026-02 -- 49536 features, 1939-02-01 to 2026-01-01
#
# NSA target: 432 months (1990-02-01 to 2026-01-01)
# SA  target: 432 months (1990-02-01 to 2026-01-01)

# %%
# --- 1b. Drop Short-History Features ---
MIN_VALID_OBS = 60

valid_counts = snap_latest.notna().sum()
short_features = valid_counts[valid_counts < MIN_VALID_OBS].sort_values()

if len(short_features) > 0:
    print(f"Flagged: {len(short_features)} features with < {MIN_VALID_OBS} valid data points")
    snap_latest = snap_latest.drop(columns=short_features.index)
    snap_pre = snap_pre.drop(columns=[c for c in short_features.index if c in snap_pre.columns])
    print(f"  snap_latest: {snap_latest.shape[1]} features remaining")
    print(f"  snap_pre:    {snap_pre.shape[1]} features remaining")
else:
    print(f"All features have >= {MIN_VALID_OBS} valid data points. No filtering needed.")

# Also drop zero-variance columns
zero_var = snap_latest.columns[snap_latest.std() == 0]
if len(zero_var) > 0:
    print(f"Dropping {len(zero_var)} zero-variance columns")
    snap_latest = snap_latest.drop(columns=zero_var)
    snap_pre = snap_pre.drop(columns=[c for c in zero_var if c in snap_pre.columns])

print(f"\nFinal: snap_latest {snap_latest.shape}, snap_pre {snap_pre.shape}")
# Out:
# All features have >= 60 valid data points. No filtering needed.
#
# Final: snap_latest (1044, 49536), snap_pre (970, 49536)

# %% [markdown]
# ## 2. Define Sector Groupings
#
# Group FRED employment features by BLS hierarchy sector.
#
# Groups are derived from the dot-separated naming convention:
# - `total.government.federal.*` → Government Federal
# - `total.private.goods.manufacturing.*` → Private Goods Manufacturing
# - `total.private.services.trade.*` → Private Services Trade
# - etc.

# %%
def get_sector(col):
    """Extract sector group from column name based on BLS hierarchy."""
    parts = col.split('.')
    if col.startswith('total.private.services'):
        if len(parts) >= 4:
            # 4th part may have _nsa or transformation suffixes
            base_part = parts[3].split('_')[0]
            return f'total.private.services.{base_part}'
        return 'total.private.services'
    elif col.startswith('total.private.goods'):
        if len(parts) >= 4:
            base_part = parts[3].split('_')[0]
            return f'total.private.goods.{base_part}'
        return 'total.private.goods'
    elif col.startswith('total.government'):
        if len(parts) >= 3:
            base_part = parts[2].split('_')[0]
            return f'total.government.{base_part}'
        return 'total.government'
    elif col.startswith('total.private'):
        return 'total.private'
    else:
        return 'total'

# Build sector groups from latest snapshot columns
from collections import defaultdict
series_groups = defaultdict(list)
for c in snap_latest.columns:
    sector = get_sector(c)
    series_groups[sector].append(c)

# Convert to regular dict
series_groups = dict(series_groups)

print("Sector Groups:")
total_feats = 0
for group in sorted(series_groups.keys()):
    n = len(series_groups[group])
    total_feats += n
    print(f"  {group}: {n} features")
print(f"\nTotal: {total_feats} features across {len(series_groups)} groups")
# Out:
# Sector Groups:
#   total: 384 features
#   total.government: 384 features
#   total.government.federal: 1152 features
#   total.government.local: 1152 features
#   total.government.state: 1152 features
#   total.private: 384 features
#   total.private.goods: 384 features
#   total.private.goods.construction: 2304 features
#   total.private.goods.manufacturing: 10368 features
#   total.private.goods.mining: 2304 features
#   total.private.services: 384 features
#   total.private.services.education: 3072 features
#   total.private.services.financial: 3840 features
#   total.private.services.information: 2688 features
#   total.private.services.leisure: 3072 features
#   total.private.services.other: 1536 features
#   total.private.services.professional: 4224 features
#   total.private.services.trade: 10752 features
#
# Total: 49536 features across 18 groups

# %% [markdown]
# ## 3. Helper Functions

# %%
def get_wide_group(snap_df, feature_list):
    """
    Extract a subset of columns from a wide-format snapshot.
    Drops all-NaN columns/rows.
    """
    available = [c for c in feature_list if c in snap_df.columns]
    if not available:
        return pd.DataFrame()
    wide = snap_df[available].copy()
    wide = wide.dropna(axis=1, how='all')
    wide = wide.dropna(axis=0, how='all')
    return wide


def compute_target_correlations(wide_df, target_series, target_label):
    """
    Compute correlation of each feature with the target.
    Returns DataFrame sorted by absolute correlation.
    """
    common_dates = wide_df.index.intersection(target_series.index)
    if len(common_dates) < 10:
        return pd.DataFrame(columns=['Feature', f'Corr with {target_label}', '|Correlation|', 'N'])

    target_aligned = target_series.loc[common_dates]
    features_aligned = wide_df.loc[common_dates]

    results = []
    for col in features_aligned.columns:
        valid = features_aligned[col].notna() & target_aligned.notna()
        if valid.sum() < 10:
            continue
        corr = features_aligned.loc[valid, col].corr(target_aligned[valid])
        results.append({
            'Feature': col,
            f'Corr with {target_label}': corr,
            '|Correlation|': abs(corr),
            'N': int(valid.sum())
        })

    df = pd.DataFrame(results)
    if not df.empty:
        df = df.sort_values('|Correlation|', ascending=False).reset_index(drop=True)
    return df

# %%
# --- Imports for Advanced Selection ---
import re
import lightgbm as lgb
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.cluster import hierarchy
from scipy.stats import spearmanr, pearsonr, binomtest
from tqdm.notebook import tqdm
import gc
import json

# Ensure reproducible randomness
SEED = 42
np.random.seed(SEED)

# --- LightGBM shared params ---
LGB_PARAMS = {
    'objective': 'regression', 'metric': 'l2', 'n_estimators': 100,
    'learning_rate': 0.05, 'num_leaves': 31, 'verbose': -1,
    'n_jobs': 1, 'random_state': SEED,
}

# --- LightGBM column-name sanitization helpers ---
# FRED employment columns contain dots (.) in hierarchical names which
# LightGBM may reject as special JSON characters.

def _sanitize_col(name):
    """Replace characters that LightGBM rejects."""
    return re.sub(r'[^A-Za-z0-9_]', '_', str(name))

def _sanitize_df(df):
    """Return (sanitized_df, clean_to_orig mapping) for LightGBM compat."""
    clean_to_orig = {}
    new_cols = []
    for c in df.columns:
        clean = _sanitize_col(c)
        base = clean
        i = 2
        while clean in clean_to_orig:
            clean = f"{base}_{i}"
            i += 1
        clean_to_orig[clean] = c
        new_cols.append(clean)
    out = df.copy()
    out.columns = new_cols
    return out, clean_to_orig

def _lgb_fit(X, y, params=None):
    """Fit LightGBM with sanitized column names. Returns (model, clean_to_orig)."""
    if params is None:
        params = LGB_PARAMS
    X_clean, mapping = _sanitize_df(X)
    model = lgb.LGBMRegressor(**params)
    model.fit(X_clean, y)
    return model, mapping

def _lgb_importances(model, mapping):
    """Get feature importances mapped back to original column names."""
    clean_names = model.feature_name_
    imp_vals = model.feature_importances_
    return pd.Series({mapping[c]: v for c, v in zip(clean_names, imp_vals)})

def _lgb_predict(model, X, mapping):
    """Predict with sanitized column names."""
    orig_to_clean = {v: k for k, v in mapping.items()}
    X_clean = X.rename(columns=orig_to_clean)
    return model.predict(X_clean)

# %%
from scipy.stats import t as t_dist


def _purged_expanding_corr(feature_series, target_series, min_window=60, purge_months=3):
    """
    Compute weighted-average correlation using expanding windows with a purge gap.
    Handles staggered start dates: only uses dates where the feature has data.
    """
    common = feature_series.dropna().index.intersection(target_series.dropna().index)
    common = common.sort_values()

    if len(common) < min_window:
        return np.nan, 0

    eval_points = np.linspace(min_window, len(common) - 1, min(5, len(common) - min_window), dtype=int)
    eval_points = sorted(set(eval_points))

    if not eval_points:
        return np.nan, 0

    correlations = []
    window_sizes = []
    for end_idx in eval_points:
        train_end = max(0, end_idx - purge_months)
        if train_end < min_window // 2:
            continue

        train_dates = common[:train_end]
        x_train = feature_series.loc[train_dates]
        y_train = target_series.loc[train_dates]

        if len(x_train) >= 30 and x_train.std() > 0:
            r = x_train.corr(y_train)
            if not np.isnan(r):
                correlations.append(r)
                window_sizes.append(len(x_train))

    if not correlations:
        return np.nan, 0

    weights = np.sqrt(window_sizes)
    weighted_corr = np.average(correlations, weights=weights)
    effective_n = int(np.mean(window_sizes))

    return weighted_corr, effective_n


def _lgb_screen_group(wide_df, target_series, top_k=15):
    """
    LightGBM-based group screening: catches features useful for tree splits
    even if they have zero marginal correlation with the target.
    """
    common = wide_df.index.intersection(target_series.index)
    if len(common) < 50:
        return []

    X = wide_df.loc[common]
    y = target_series.loc[common]

    # Recency check
    last_date = X.index.max()
    recent_cutoff = last_date - pd.DateOffset(months=3)
    recency_mask = X.apply(lambda col: col.last_valid_index() >= recent_cutoff)
    X = X.loc[:, recency_mask]

    if X.shape[1] == 0:
        return []

    model, mapping = _lgb_fit(X, y)
    imp = _lgb_importances(model, mapping)
    nonzero = imp[imp > 0].sort_values(ascending=False)
    return nonzero.head(top_k).index.tolist()


def filter_group_data_purged(wide_df, target_series, group_name, vif_threshold=10, fdr_alpha=0.10):
    """
    Group-wise filter with DUAL screening paths:

    Path A (Linear): Purged expanding-window correlation + BH-FDR significance
    Path B (Non-linear): LightGBM gain importance pre-screen

    The UNION of both paths goes through VIF reduction.
    """
    common = wide_df.index.intersection(target_series.index)
    X_local = wide_df.loc[common].copy()
    y_local = target_series.loc[common]

    if X_local.empty:
        return []

    # Recency check
    last_date = X_local.index.max()
    recent_cutoff = last_date - pd.DateOffset(months=3)
    recency_mask = X_local.apply(lambda col: col.last_valid_index() >= recent_cutoff)
    X_local = X_local.loc[:, recency_mask]

    if X_local.shape[1] == 0:
        return []

    # === Path A: Purged Expanding-Window Correlation + BH-FDR ===
    feature_pvalues = {}
    for col in X_local.columns:
        avg_corr, eff_n = _purged_expanding_corr(X_local[col], y_local)

        if np.isnan(avg_corr) or eff_n < 60:
            continue

        t_stat = avg_corr * np.sqrt((eff_n - 2) / (1 - avg_corr**2 + 1e-12))
        p_value = 2 * (1 - t_dist.cdf(abs(t_stat), df=eff_n - 2))
        feature_pvalues[col] = p_value

    corr_features = []
    if feature_pvalues:
        sorted_features = sorted(feature_pvalues.items(), key=lambda x: x[1])
        n_tests = len(sorted_features)
        for rank, (feat, pval) in enumerate(sorted_features, 1):
            bh_threshold = (rank / n_tests) * fdr_alpha
            if pval <= bh_threshold:
                corr_features.append(feat)
            else:
                break

    # === Path B: LightGBM Gain Importance Pre-Screen ===
    lgb_features = _lgb_screen_group(X_local, y_local, top_k=15)

    # === Union of both paths ===
    passed_features = sorted(set(corr_features) | set(lgb_features))

    if not passed_features:
        return []

    # 3. Iterative Pruning for VIF (need dense matrix)
    X_vif = X_local[passed_features].copy()

    target_rows = 100
    current_rows = X_vif.dropna()
    while len(current_rows) < target_rows and X_vif.shape[1] > 1:
        nan_counts = X_vif.isna().sum()
        worst_col = nan_counts.idxmax()
        X_vif = X_vif.drop(columns=[worst_col])
        current_rows = X_vif.dropna()

    X_vif = X_vif.dropna()
    y_vif = y_local.loc[X_vif.index]

    if len(X_vif) < 50 or X_vif.shape[1] == 0:
        return passed_features[:15]

    if X_vif.shape[1] > 60:
        corrs = X_vif.corrwith(y_vif).abs()
        top_60 = corrs.nlargest(60).index
        X_vif = X_vif[top_60]

    # 4. VIF Iterative Reduction
    while X_vif.shape[1] > 1:
        try:
            vifs = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
            max_vif = max(vifs)
            if max_vif <= vif_threshold:
                break

            max_idx = vifs.index(max_vif)
            feat_max = X_vif.columns[max_idx]

            curr_corr = X_vif.corr().abs()
            partner = curr_corr[feat_max].drop(feat_max).idxmax()

            if abs(X_vif[feat_max].corr(y_vif)) < abs(X_vif[partner].corr(y_vif)):
                drop_col = feat_max
            else:
                drop_col = partner

            X_vif = X_vif.drop(columns=[drop_col])
        except Exception as e:
            print(f"  [Group {group_name}] VIF Error: {e}")
            break

    return X_vif.columns.tolist()

# %%
def _block_permute(y, block_size=6, rng=None):
    """Permute target by shuffling contiguous blocks (preserves autocorrelation)."""
    if rng is None:
        rng = np.random.RandomState(SEED)

    n = len(y)
    values = y.values if hasattr(y, 'values') else np.array(y)

    n_full_blocks = n // block_size
    blocks = [values[i*block_size:(i+1)*block_size] for i in range(n_full_blocks)]
    remainder = values[n_full_blocks*block_size:]
    if len(remainder) > 0:
        blocks.append(remainder)

    order = rng.permutation(len(blocks))
    shuffled = np.concatenate([blocks[i] for i in order])

    return shuffled[:n]


def get_boruta_importance(X, y, n_runs=100, block_size=6, alpha=0.05):
    """
    Boruta-style feature selection with shadow features.
    Compares each real feature to the 75th percentile of all shadow importances.
    """
    common = X.index.intersection(y.index)
    X_curr = X.loc[common]
    y_curr = y.loc[common]

    n_features = X_curr.shape[1]
    feature_names = X_curr.columns.tolist()

    hits = np.zeros(n_features, dtype=int)

    for run in tqdm(range(n_runs), desc="Boruta Runs", leave=False):
        rng = np.random.RandomState(SEED + run)

        shadow_data = {}
        for col in feature_names:
            col_vals = X_curr[col].values.copy()
            valid_mask = ~np.isnan(col_vals) if np.issubdtype(col_vals.dtype, np.floating) else np.ones(len(col_vals), dtype=bool)
            valid_vals = col_vals[valid_mask].copy()
            rng.shuffle(valid_vals)
            col_vals[valid_mask] = valid_vals
            shadow_data[f'_shadow_{col}'] = col_vals

        shadow_df = pd.DataFrame(shadow_data, index=X_curr.index)
        X_combined = pd.concat([X_curr, shadow_df], axis=1)

        model, mapping = _lgb_fit(X_combined, y_curr)
        importances = _lgb_importances(model, mapping)

        shadow_cols = [c for c in importances.index if c.startswith('_shadow_')]
        shadow_threshold = np.percentile(importances[shadow_cols].values, 75)

        for i, feat in enumerate(feature_names):
            if importances.get(feat, 0) > shadow_threshold:
                hits[i] += 1

    confirmed = []
    tentative = []

    for i, feat in enumerate(feature_names):
        p_val = binomtest(hits[i], n=n_runs, p=0.25, alternative='greater').pvalue
        if p_val < alpha:
            confirmed.append(feat)
        elif p_val < alpha * 5:
            tentative.append(feat)

    print(f"   Boruta: {len(confirmed)} confirmed, {len(tentative)} tentative "
          f"(hit rates: min={hits.min()}/{n_runs}, max={hits.max()}/{n_runs})")

    return confirmed + tentative

# %%
def get_vintage_stability(feature_list, target_series, snapshots_dir, min_presence=2):
    """
    Check feature importance stability across historical snapshots.
    Exponential recency weighting: {2010:1, 2014:2, 2018:4, 2022:8, Latest:16}

    For wide-format data: loads each vintage parquet and extracts matching columns.
    """
    years = ['2010', '2014', '2018', '2022', 'Latest']
    weights = {'2010': 1, '2014': 2, '2018': 4, '2022': 8, 'Latest': 16}

    scores = pd.DataFrame(np.nan, index=feature_list, columns=years)

    for year in years:
        if year == 'Latest':
            X_wide = get_wide_group(snap_latest, feature_list)
        else:
            decade = year[:3] + "0s"
            path = snapshots_dir / decade / year / f"{year}-12.parquet"
            if not path.exists():
                continue
            snap = pd.read_parquet(path)
            snap.index = pd.to_datetime(snap.index)
            snap.index.name = 'date'
            X_wide = get_wide_group(snap, feature_list)

        if X_wide.empty:
            continue

        X_wide = winsorize_covid_period(X_wide)

        common = X_wide.index.intersection(target_series.index)
        if len(common) < 50:
            continue

        model, mapping = _lgb_fit(X_wide.loc[common], target_series.loc[common])
        imp = _lgb_importances(model, mapping)
        if imp.sum() > 0:
            imp = imp / imp.sum()
            for feat in imp.index:
                scores.loc[feat, year] = imp[feat]

    weight_series = pd.Series(weights)

    results = {}
    for feat in feature_list:
        feat_scores = scores.loc[feat].dropna()
        if len(feat_scores) == 0:
            continue

        nonzero_count = (feat_scores > 0).sum()

        if nonzero_count < min_presence:
            continue

        available_weights = weight_series[feat_scores.index]
        weighted_score = (feat_scores * available_weights).sum() / available_weights.sum()
        results[feat] = weighted_score

    result_series = pd.Series(results)

    latest_scores = scores['Latest'].dropna()
    latest_nonzero = latest_scores[latest_scores > 0].index
    result_series = result_series[result_series.index.isin(latest_nonzero)]

    return result_series.sort_values(ascending=False)

# %%
def cluster_redundancy(X, feature_list, target_series, max_clusters=50, min_overlap=30):
    """
    Hierarchical clustering to remove redundant features.
    NaN-aware pairwise Spearman correlations.
    """
    if len(feature_list) <= max_clusters:
        return feature_list

    X_curr = X[feature_list].copy()
    common = X_curr.index.intersection(target_series.index)
    X_curr = X_curr.loc[common]
    y_curr = target_series.loc[common]

    valid_target = y_curr.notna()
    X_curr = X_curr.loc[valid_target]
    y_curr = y_curr.loc[valid_target]

    corr = X_curr.corr(method='spearman')
    corr = corr.fillna(0)

    for i, col_i in enumerate(feature_list):
        for j, col_j in enumerate(feature_list):
            if i >= j:
                continue
            overlap = (X_curr[col_i].notna() & X_curr[col_j].notna()).sum()
            if overlap < min_overlap:
                corr.loc[col_i, col_j] = 0
                corr.loc[col_j, col_i] = 0

    dist_matrix = 1 - corr.abs().values
    np.fill_diagonal(dist_matrix, 0)

    dist_matrix = np.maximum(dist_matrix, 0)
    dist_matrix = (dist_matrix + dist_matrix.T) / 2

    from scipy.spatial.distance import squareform
    condensed = squareform(dist_matrix, checks=False)

    linkage = hierarchy.ward(condensed)
    cluster_ids = hierarchy.fcluster(linkage, t=max_clusters, criterion='maxclust')

    X_imputed = X_curr.fillna(X_curr.median())
    mi = mutual_info_regression(X_imputed, y_curr, random_state=SEED)
    mi_series = pd.Series(mi, index=feature_list)

    selected = []
    for cluster_id in np.unique(cluster_ids):
        members = [feature_list[i] for i, c in enumerate(cluster_ids) if c == cluster_id]
        best = mi_series[members].idxmax()
        selected.append(best)

    return selected

# %%
def _extract_split_pairs(model, mapping):
    """Extract parent-child split pairs from LightGBM trees."""
    from collections import Counter
    pair_counts = Counter()

    clean_names = model.feature_name_

    booster = model.booster_
    for tree_idx in range(booster.num_trees()):
        tree_info = booster.dump_model()['tree_info'][tree_idx]

        def _walk(node, parent_feature=None):
            if 'split_feature' not in node:
                return

            feat_idx = node['split_feature']
            if feat_idx < len(clean_names):
                clean_name = clean_names[feat_idx]
                feat_name = mapping.get(clean_name, clean_name)
            else:
                feat_name = f'feature_{feat_idx}'

            if parent_feature is not None and parent_feature != feat_name:
                pair = tuple(sorted([parent_feature, feat_name]))
                pair_counts[pair] += 1

            if 'left_child' in node:
                _walk(node['left_child'], feat_name)
            if 'right_child' in node:
                _walk(node['right_child'], feat_name)

        _walk(tree_info['tree_structure'])

    return pair_counts


def interaction_rescue(X, y, confirmed_features, rejected_pool, n_splits=8, gap=3, top_k=10):
    """
    Two-phase interaction rescue:
    Phase 1: Single-feature conditional test
    Phase 2: Split-pair detection from LightGBM trees
    """
    common = X.index.intersection(y.index)
    X_curr = X.loc[common]
    y_curr = y.loc[common]

    rejected = [f for f in rejected_pool if f in X_curr.columns and f not in confirmed_features]

    if not rejected:
        return []

    tscv = TimeSeriesSplit(n_splits=n_splits, gap=gap)

    def _cv_mae(feature_set):
        X_sub = X_curr[feature_set]
        maes = []
        for train_idx, test_idx in tscv.split(X_sub):
            model, mapping = _lgb_fit(X_sub.iloc[train_idx], y_curr.iloc[train_idx])
            preds = _lgb_predict(model, X_sub.iloc[test_idx], mapping)
            maes.append(np.mean(np.abs(y_curr.iloc[test_idx].values - preds)))
        return np.mean(maes)

    baseline_mae = _cv_mae(confirmed_features)

    # === Phase 1: Single-feature conditional rescue ===
    single_improvements = {}
    for feat in tqdm(rejected, desc="Phase 1: Single-feature scan", leave=False):
        trial_mae = _cv_mae(confirmed_features + [feat])
        improvement = (baseline_mae - trial_mae) / (baseline_mae + 1e-12)
        if improvement > 0:
            single_improvements[feat] = improvement

    single_rescued = sorted(single_improvements.items(), key=lambda x: x[1], reverse=True)[:top_k]

    for feat, imp in single_rescued:
        print(f"   Rescued (single): {feat} (delta MAE = {imp:.4f})")

    # === Phase 2: Split-pair detection ===
    all_feats = [f for f in X_curr.columns if f in confirmed_features or f in rejected]

    model_full, mapping_full = _lgb_fit(
        X_curr[all_feats], y_curr,
        params={**LGB_PARAMS, 'n_estimators': 200, 'num_leaves': 63, 'max_depth': 6}
    )

    pair_counts = _extract_split_pairs(model_full, mapping_full)

    rejected_set = set(rejected)
    pair_rescued = []

    for (feat_a, feat_b), count in pair_counts.most_common():
        if len(pair_rescued) >= top_k:
            break

        new_feats = []
        if feat_a in rejected_set and feat_a not in [f for f, _ in single_rescued]:
            new_feats.append(feat_a)
        if feat_b in rejected_set and feat_b not in [f for f, _ in single_rescued]:
            new_feats.append(feat_b)

        if not new_feats:
            continue

        trial_feats = confirmed_features + [f for f, _ in single_rescued] + new_feats
        trial_feats = list(dict.fromkeys(trial_feats))

        baseline_with_singles = confirmed_features + [f for f, _ in single_rescued]
        baseline_with_singles = list(dict.fromkeys(baseline_with_singles))
        baseline_singles_mae = _cv_mae(baseline_with_singles)
        trial_mae = _cv_mae(trial_feats)

        improvement = (baseline_singles_mae - trial_mae) / (baseline_singles_mae + 1e-12)
        if improvement > 0:
            for f in new_feats:
                if f not in [pf for pf, _ in pair_rescued]:
                    pair_rescued.append((f, improvement))
                    print(f"   Rescued (pair w/ {feat_a if f != feat_a else feat_b}, "
                          f"co-occur={count}): {f} (delta MAE = {improvement:.4f})")

    all_rescued = [f for f, _ in single_rescued] + [f for f, _ in pair_rescued]
    seen = set()
    result = []
    for f in all_rescued:
        if f not in seen:
            seen.add(f)
            result.append(f)

    return result


def sequential_forward_selection(X, y, candidate_features, boruta_hits=None,
                                   n_splits=8, gap=3, min_improvement=0.001,
                                   patience=3, min_features=5):
    """Sequential Forward Selection using walk-forward CV."""
    common = X.index.intersection(y.index)
    X_curr = X.loc[common]
    y_curr = y.loc[common]

    tscv = TimeSeriesSplit(n_splits=n_splits, gap=gap)

    def _cv_mae(feature_set):
        if not feature_set:
            return float('inf')

        X_sub = X_curr[feature_set]
        maes = []
        for train_idx, test_idx in tscv.split(X_sub):
            X_train, X_test = X_sub.iloc[train_idx], X_sub.iloc[test_idx]
            y_train, y_test = y_curr.iloc[train_idx], y_curr.iloc[test_idx]

            model, mapping = _lgb_fit(X_train, y_train)
            preds = _lgb_predict(model, X_test, mapping)
            maes.append(np.mean(np.abs(y_test.values - preds)))

        return np.mean(maes)

    if boruta_hits is not None:
        candidates = sorted(candidate_features, key=lambda f: boruta_hits.get(f, 0), reverse=True)
    else:
        candidates = list(candidate_features)

    best_single_mae = float('inf')
    best_single = candidates[0]
    for feat in candidates[:min(20, len(candidates))]:
        mae = _cv_mae([feat])
        if mae < best_single_mae:
            best_single_mae = mae
            best_single = feat

    selected = [best_single]
    current_mae = best_single_mae
    remaining = [f for f in candidates if f != best_single]
    consecutive_failures = 0

    print(f"   SFS start: {best_single} (MAE={current_mae:.2f})")

    while remaining:
        best_next = None
        best_next_mae = current_mae

        for feat in remaining:
            trial = selected + [feat]
            mae = _cv_mae(trial)
            if mae < best_next_mae:
                best_next_mae = mae
                best_next = feat

        if best_next is None:
            consecutive_failures += 1
            if len(selected) >= min_features and consecutive_failures >= patience:
                print(f"   SFS stop: no improvement for {patience} rounds")
                break
            forced = remaining[0]
            selected.append(forced)
            remaining.remove(forced)
            print(f"   SFS +{forced} (forced, MAE~{current_mae:.2f}, below min_features={min_features})")
            continue

        improvement = (current_mae - best_next_mae) / (current_mae + 1e-12)

        if improvement < min_improvement:
            consecutive_failures += 1
            if len(selected) >= min_features and consecutive_failures >= patience:
                print(f"   SFS stop: {patience} consecutive improvements < {min_improvement:.4f}")
                break
            selected.append(best_next)
            remaining.remove(best_next)
            current_mae = best_next_mae
            print(f"   SFS +{best_next} (MAE={current_mae:.2f}, delta={improvement:.4f}, "
                  f"patience {consecutive_failures}/{patience})")
        else:
            consecutive_failures = 0
            selected.append(best_next)
            remaining.remove(best_next)
            current_mae = best_next_mae
            print(f"   SFS +{best_next} (MAE={current_mae:.2f}, delta={improvement:.4f})")

    print(f"   SFS final: {len(selected)} features, MAE={current_mae:.2f}")
    return selected


# ===========================================================================
#  MAIN PIPELINE -- 7 Stages
# ===========================================================================

# --- TARGET VERIFICATION ---
if target_nsa['y_mom'].isna().all() or (target_nsa['y_mom'] == target_nsa['y']).any():
    raise ValueError("Target y_mom does not look like a difference/change variable!")

targets = {
    'NSA': target_nsa['y_mom'], 'SA': target_sa['y_mom'],
    'NSA_Acc': target_nsa['y_acc'], 'SA_Acc': target_sa['y_acc'],
}
final_results = {}

for t_name, y_target in targets.items():
    print(f"\n{'='*60}")
    print(f"  PIPELINE START: {t_name}")
    print(f"{'='*60}")

    # --- COVID Consistency ---
    y_target = winsorize_covid_period(y_target)

    # ===== Stage 1: Group-wise Dual Filter (Linear + LightGBM) =====
    stage1_candidates = []
    print("1. Group-wise Dual Filter (Purged Corr + LightGBM screen + VIF)...")
    for group_name, feature_list in sorted(series_groups.items()):
        wide_group = get_wide_group(snap_latest, feature_list)
        if wide_group.empty:
            continue
        wide_group = winsorize_covid_period(wide_group)

        selected = filter_group_data_purged(wide_group, y_target, group_name)
        stage1_candidates.extend(selected)
        if selected:
            print(f"   [{group_name}] {len(feature_list)} -> {len(selected)}")

    stage1_candidates = sorted(list(set(stage1_candidates)))
    print(f"   > Stage 1 Survivors: {len(stage1_candidates)} features")

    if len(stage1_candidates) == 0:
        print("   WARNING: No features survived Stage 1. Skipping pipeline.")
        final_results[t_name] = []
        continue

    # ===== Stage 2: Boruta Importance =====
    print("2. Boruta Feature Selection (shadow features)...")
    X_stage2 = get_wide_group(snap_latest, stage1_candidates)
    X_stage2 = winsorize_covid_period(X_stage2)

    stage2_candidates = get_boruta_importance(X_stage2, y_target, n_runs=100)
    print(f"   > Stage 2 Survivors: {len(stage2_candidates)} features")

    if len(stage2_candidates) == 0:
        print("   WARNING: No features survived Boruta. Falling back to Stage 1 top 30.")
        common = X_stage2.index.intersection(y_target.index)
        corrs = X_stage2.loc[common].corrwith(y_target.loc[common]).abs()
        stage2_candidates = corrs.nlargest(30).index.tolist()

    # ===== Stage 3: Vintage Stability =====
    print("3. Vintage Stability (exponential recency weights, min 2 snapshots)...")
    weighted_scores = get_vintage_stability(stage2_candidates, y_target, FRED_EMP_DIR)

    if len(weighted_scores) == 0:
        print("   WARNING: No features survived vintage stability. Using all Stage 2.")
        stage3_candidates = stage2_candidates
    else:
        threshold = weighted_scores.median() * 0.5
        stage3_candidates = weighted_scores[weighted_scores > threshold].index.tolist()
    print(f"   > Stage 3 Survivors: {len(stage3_candidates)} features")

    # ===== Stage 4: Cluster Redundancy =====
    print("4. Cluster Redundancy Check (NaN-aware Spearman)...")
    stage4_candidates = cluster_redundancy(X_stage2, stage3_candidates, y_target, max_clusters=50)
    print(f"   > Stage 4 Survivors: {len(stage4_candidates)} features")

    # ===== Stage 5: Interaction Rescue (two-phase) =====
    print("5. Interaction Rescue (single-feature + split-pair detection)...")
    rescued = interaction_rescue(
        X_stage2, y_target,
        confirmed_features=stage4_candidates,
        rejected_pool=stage1_candidates,
        top_k=10
    )
    stage5_candidates = stage4_candidates + rescued
    seen = set()
    stage5_candidates = [f for f in stage5_candidates if f not in seen and not seen.add(f)]
    print(f"   > Stage 5 Candidates: {len(stage5_candidates)} "
          f"({len(stage4_candidates)} confirmed + {len(rescued)} rescued)")

    # ===== Stage 6: Sequential Forward Selection =====
    print("6. Sequential Forward Selection (walk-forward CV with embargo)...")
    final_list = sequential_forward_selection(
        X_stage2, y_target, stage5_candidates,
        n_splits=8, gap=3,
        min_improvement=0.001,
        patience=3,
        min_features=5,
    )
    print(f"   > Final Count: {len(final_list)}")

    final_results[t_name] = final_list
    print(f"Selected features ({t_name}):")
    for i, f in enumerate(final_list):
        print(f"  {i+1:2d}. {f}")

    gc.collect()

# ===== Stage 7: Union MoM + Acc per variant, save 2 files =====
print(f"\n{'='*60}")
print("Merging MoM + Acceleration features (union) and saving...")

merged_results = {}
for variant in ['nsa', 'sa']:
    mom_key = variant.upper()
    acc_key = f"{variant.upper()}_Acc"

    mom_feats = set(final_results.get(mom_key, []))
    acc_feats = set(final_results.get(acc_key, []))
    union_feats = sorted(mom_feats | acc_feats)

    merged_results[variant] = union_feats

    print(f"\n  {variant.upper()}: {len(mom_feats)} MoM + {len(acc_feats)} Acc "
          f"-> {len(union_feats)} union ({len(mom_feats & acc_feats)} overlap)")
    for i, f in enumerate(union_feats):
        src = []
        if f in mom_feats:
            src.append("MoM")
        if f in acc_feats:
            src.append("Acc")
        print(f"    {i+1:2d}. {f}  [{', '.join(src)}]")

for variant, feats in merged_results.items():
    fname = f"selected_features_fred_employment_{variant}.json"
    with open(PROJECT_ROOT / 'notebooks' / fname, 'w') as f:
        json.dump(feats, f, indent=4)
    print(f"  Saved {fname}: {len(feats)} features")

print("\nDone.")
# Out:
# ============================================================
#   PIPELINE START: NSA
# ============================================================
# 1. Group-wise Dual Filter (Purged Corr + LightGBM screen + VIF)...
#    [total] 384 -> 24
#    [total.government] 384 -> 12
#    [total.government.federal] 1152 -> 28
#    [total.government.local] 1152 -> 9
#    [total.government.state] 1152 -> 8
#    [total.private] 384 -> 32
#    [total.private.goods] 384 -> 25
#    [total.private.goods.construction] 2304 -> 12
#    [total.private.goods.manufacturing] 10368 -> 29
#    [total.private.goods.mining] 2304 -> 22
#    [total.private.services] 384 -> 31
#    [total.private.services.education] 3072 -> 18
#    [total.private.services.financial] 3840 -> 13
#    [total.private.services.information] 2688 -> 24
#    [total.private.services.leisure] 3072 -> 16
#    [total.private.services.other] 1536 -> 24
#    [total.private.services.professional] 4224 -> 19
#    [total.private.services.trade] 10752 -> 20
#    > Stage 1 Survivors: 366 features
# 2. Boruta Feature Selection (shadow features)...
# Boruta Runs:   0%|          | 0/100 [00:00<?, ?it/s]
#    Boruta: 100 confirmed, 11 tentative (hit rates: min=0/100, max=100/100)
#    > Stage 2 Survivors: 111 features
# 3. Vintage Stability (exponential recency weights, min 2 snapshots)...
#    > Stage 3 Survivors: 106 features
# 4. Cluster Redundancy Check (NaN-aware Spearman)...
#    > Stage 4 Survivors: 50 features
# 5. Interaction Rescue (single-feature + split-pair detection)...
# Phase 1: Single-feature scan:   0%|          | 0/316 [00:00<?, ?it/s]
#    Rescued (single): total.private.services.trade_transportation_utilities.transportation_warehousing_nsa_zscore_12m_lag_12m (delta MAE = 0.0229)
#    Rescued (single): total_nsa_symlog_diff_zscore_12m_lag_6m (delta MAE = 0.0223)
#    Rescued (single): total.private.services.other.personal_nsa (delta MAE = 0.0195)
#    Rescued (single): total.private.goods_nsa (delta MAE = 0.0157)
#    Rescued (single): total_nsa_lag_12m (delta MAE = 0.0152)
#    Rescued (single): total_nsa_lag_6m (delta MAE = 0.0151)
#    Rescued (single): total_nsa_symlog_diff (delta MAE = 0.0128)
#    Rescued (single): total.private.services.trade_transportation_utilities_nsa_symlog_diff_zscore_12m_lag_12m (delta MAE = 0.0127)
#    Rescued (single): total.private.goods_nsa_symlog_pct_chg_zscore_3m_lag_18m (delta MAE = 0.0126)
#    Rescued (single): total.private.services.other.religious_nsa_symlog_rolling_std_6m_lag_6m (delta MAE = 0.0107)
#    Rescued (pair w/ total_nsa, co-occur=12): total_nsa_chg_3m_lag_12m (delta MAE = 0.0020)
#    Rescued (pair w/ total_nsa, co-occur=10): total.private.services.other.personal_nsa_symlog_diff_zscore_12m_lag_18m (delta MAE = 0.0007)
#    Rescued (pair w/ total.private.services.professional_business.professional_technical.consulting_nsa_zscore_12m_lag_12m, co-occur=8): total.private.services.information_nsa_diff_zscore_12m_lag_12m (delta MAE = 0.0039)
#    Rescued (pair w/ total.private.services.information_nsa_diff_zscore_12m_lag_12m, co-occur=8): total.private.services.professional_business.professional_technical.consulting_nsa_zscore_12m_lag_12m (delta MAE = 0.0039)
#    Rescued (pair w/ total_nsa, co-occur=6): total.private.services_nsa_symlog_zscore_3m_lag_18m (delta MAE = 0.0023)
#    Rescued (pair w/ total_nsa, co-occur=6): total.private.services.education_health.health_social.health_care.ambulatory_nsa_symlog (delta MAE = 0.0002)
#    Rescued (pair w/ total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_zscore_12m_lag_12m, co-occur=6): total.private.services.education_health.health_social_nsa_symlog_chg_3m (delta MAE = 0.0049)
#    Rescued (pair w/ total.private.services.education_health.health_social_nsa_symlog_chg_3m, co-occur=6): total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_zscore_12m_lag_12m (delta MAE = 0.0049)
#    Rescued (pair w/ total.private.goods.manufacturing_nsa_diff_zscore_12m_lag_12m, co-occur=6): total.private.services.trade_transportation_utilities.wholesale_nsa_diff_zscore_12m_lag_12m (delta MAE = 0.0070)
#    Rescued (pair w/ total_nsa, co-occur=5): total.private.services.education_health.education_nsa_symlog_rolling_mean_3m_lag_6m (delta MAE = 0.0021)
#    > Stage 5 Candidates: 70 (50 confirmed + 20 rescued)
# 6. Sequential Forward Selection (walk-forward CV with embargo)...
#    SFS start: total.private.services_nsa (MAE=472.69)
#    SFS +total_nsa (MAE=209.44, delta=0.5569)
#    SFS +total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_zscore_12m_lag_12m (MAE=186.33, delta=0.1104)
#    SFS +total_nsa_lag_6m (MAE=180.62, delta=0.0307)
#    SFS +total_nsa_lag_12m (MAE=175.56, delta=0.0280)
#    SFS +total_nsa_symlog_diff (MAE=169.81, delta=0.0328)
#    SFS +total.private.goods.manufacturing_nsa_diff_zscore_12m_lag_12m (MAE=165.68, delta=0.0243)
#    SFS +total.private.services.trade_transportation_utilities_nsa (MAE=163.63, delta=0.0124)
#    SFS +total_nsa_chg_3m_lag_12m (MAE=160.22, delta=0.0208)
#    SFS +total.private.services.other.religious_nsa_diff_zscore_3m_lag_12m (MAE=157.82, delta=0.0150)
#    SFS +total.private_nsa_symlog_diff_zscore_12m_lag_6m (MAE=157.17, delta=0.0042)
#    SFS +total_nsa_symlog_diff_zscore_3m_lag_1m (MAE=156.98, delta=0.0012)
#    SFS +total.private.services.information.publishing_nsa_zscore_12m_lag_12m (MAE=156.65, delta=0.0021)
#    SFS +total.government.federal.except_postal_nsa_symlog_zscore_12m_lag_12m (MAE=156.40, delta=0.0016)
#    SFS +total.private.services.leisure_hospitality.accommodation_food.food_services_nsa (forced, MAE~156.40, below min_features=5)
#    SFS +total.private.services.professional_business.admin_waste.admin_support_nsa (forced, MAE~156.40, below min_features=5)
#    SFS stop: no improvement for 3 rounds
#    SFS final: 16 features, MAE=156.40
#    > Final Count: 16
# Selected features (NSA):
#    1. total.private.services_nsa
#    2. total_nsa
#    3. total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_zscore_12m_lag_12m
#    4. total_nsa_lag_6m
#    5. total_nsa_lag_12m
#    6. total_nsa_symlog_diff
#    7. total.private.goods.manufacturing_nsa_diff_zscore_12m_lag_12m
#    8. total.private.services.trade_transportation_utilities_nsa
#    9. total_nsa_chg_3m_lag_12m
#   10. total.private.services.other.religious_nsa_diff_zscore_3m_lag_12m
#   11. total.private_nsa_symlog_diff_zscore_12m_lag_6m
#   12. total_nsa_symlog_diff_zscore_3m_lag_1m
#   13. total.private.services.information.publishing_nsa_zscore_12m_lag_12m
#   14. total.government.federal.except_postal_nsa_symlog_zscore_12m_lag_12m
#   15. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa
#   16. total.private.services.professional_business.admin_waste.admin_support_nsa
#
# ============================================================
#   PIPELINE START: SA
# ============================================================
# 1. Group-wise Dual Filter (Purged Corr + LightGBM screen + VIF)...
#    [total] 384 -> 36
#    [total.government] 384 -> 12
#    [total.government.federal] 1152 -> 24
#    [total.government.local] 1152 -> 17
#    [total.government.state] 1152 -> 12
#    [total.private] 384 -> 35
#    [total.private.goods] 384 -> 41
#    [total.private.goods.construction] 2304 -> 26
#    [total.private.goods.manufacturing] 10368 -> 40
#    [total.private.goods.mining] 2304 -> 16
#    [total.private.services] 384 -> 35
#    [total.private.services.education] 3072 -> 20
#    [total.private.services.financial] 3840 -> 30
#    [total.private.services.information] 2688 -> 31
#    [total.private.services.leisure] 3072 -> 19
#    [total.private.services.other] 1536 -> 35
#    [total.private.services.professional] 4224 -> 31
#    [total.private.services.trade] 10752 -> 42
#    > Stage 1 Survivors: 502 features
# 2. Boruta Feature Selection (shadow features)...
# Boruta Runs:   0%|          | 0/100 [00:00<?, ?it/s]
#    Boruta: 112 confirmed, 9 tentative (hit rates: min=0/100, max=100/100)
#    > Stage 2 Survivors: 121 features
# 3. Vintage Stability (exponential recency weights, min 2 snapshots)...
#    > Stage 3 Survivors: 118 features
# 4. Cluster Redundancy Check (NaN-aware Spearman)...
#    > Stage 4 Survivors: 50 features
# 5. Interaction Rescue (single-feature + split-pair detection)...
# Phase 1: Single-feature scan:   0%|          | 0/452 [00:00<?, ?it/s]
#    Rescued (single): total.private.services.trade_transportation_utilities.retail.furniture_symlog_rolling_mean_3m (delta MAE = 0.0383)
#    Rescued (single): total.private.goods.construction.buildings.residential_symlog_rolling_mean_3m_lag_3m (delta MAE = 0.0330)
#    Rescued (single): total.private.services_rolling_mean_3m_lag_3m (delta MAE = 0.0270)
#    Rescued (single): total.private.services.trade_transportation_utilities.wholesale_symlog (delta MAE = 0.0215)
#    Rescued (single): total.private (delta MAE = 0.0209)
#    Rescued (single): total.private.goods.construction.buildings_symlog_rolling_mean_3m_lag_6m (delta MAE = 0.0183)
#    Rescued (single): total.private.services.financial.real_estate.rental_leasing (delta MAE = 0.0181)
#    Rescued (single): total.private_symlog_rolling_mean_3m_lag_6m (delta MAE = 0.0146)
#    Rescued (single): total.private.goods.construction.specialty_symlog_rolling_mean_3m_lag_3m (delta MAE = 0.0141)
#    Rescued (single): total.private.services.trade_transportation_utilities.retail_symlog_rolling_mean_3m (delta MAE = 0.0135)
#    Rescued (pair w/ total, co-occur=7): total.private.services.leisure_hospitality.accommodation_food (delta MAE = 0.0071)
#    Rescued (pair w/ total.government.federal.except_postal_symlog_rolling_mean_3m, co-occur=5): total.private.goods_symlog_lag_12m (delta MAE = 0.0025)
#    Rescued (pair w/ total, co-occur=4): total.private.services.professional_business.management_companies_symlog (delta MAE = 0.0064)
#    Rescued (pair w/ total.private_nsa_symlog_pct_chg_rolling_mean_3m_lag_3m, co-occur=4): total.private_nsa_symlog_chg_12m_lag_18m (delta MAE = 0.0049)
#    Rescued (pair w/ total.private_nsa_symlog_chg_12m_lag_18m, co-occur=4): total.private_nsa_symlog_pct_chg_rolling_mean_3m_lag_3m (delta MAE = 0.0049)
#    Rescued (pair w/ total_chg_6m, co-occur=4): total_nsa_symlog_rolling_mean_3m (delta MAE = 0.0067)
#    Rescued (pair w/ total.government.local.education_nsa_symlog_zscore_3m_lag_1m, co-occur=4): total.private.goods.construction (delta MAE = 0.0145)
#    Rescued (pair w/ total.private.goods.mining_logging.logging_symlog_pct_chg_zscore_3m_lag_3m, co-occur=4): total.private.services.information.publishing_nsa (delta MAE = 0.0102)
#    Rescued (pair w/ total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa, co-occur=4): total.private.services.other.repair_nsa_symlog_rolling_mean_3m (delta MAE = 0.0105)
#    Rescued (pair w/ total.private.services.other.repair_nsa_symlog_rolling_mean_3m, co-occur=4): total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa (delta MAE = 0.0105)
#    > Stage 5 Candidates: 70 (50 confirmed + 20 rescued)
# 6. Sequential Forward Selection (walk-forward CV with embargo)...
#    SFS start: total (MAE=158.69)
#    SFS +total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa (MAE=155.16, delta=0.0223)
#    SFS +total.private.goods.mining_logging.logging_symlog_pct_chg_zscore_3m_lag_3m (MAE=154.62, delta=0.0035)
#    SFS +total.private.services.trade_transportation_utilities.wholesale_symlog (MAE=150.90, delta=0.0241)
#    SFS +total_symlog_chg_6m_lag_6m (MAE=148.69, delta=0.0147)
#    SFS +total_nsa (MAE=147.62, delta=0.0072)
#    SFS +total.private.services.financial.real_estate.rental_leasing (MAE=147.00, delta=0.0042)
#    SFS +total.private.services.other.personal_symlog_rolling_mean_3m (MAE=145.76, delta=0.0084)
#    SFS +total.private.services.trade_transportation_utilities.wholesale.nondurable_symlog_rolling_mean_3m (MAE=144.80, delta=0.0066)
#    SFS +total.private.services.leisure_hospitality.accommodation_food.accommodation_symlog_rolling_mean_3m (forced, MAE~144.80, below min_features=5)
#    SFS +total.private.services.information.publishing_nsa (MAE=144.04, delta=0.0053)
#    SFS +total.private.goods.manufacturing.durable.nonmetallic_lag_1m (MAE=143.26, delta=0.0054)
#    SFS +total.private.goods.mining_logging.mining.except_oil_gas_rolling_std_6m_lag_1m (MAE=143.15, delta=0.0007, patience 1/3)
#    SFS +total.private.services.trade_transportation_utilities.transportation_warehousing.support_symlog (forced, MAE~143.15, below min_features=5)
#    SFS stop: no improvement for 3 rounds
#    SFS final: 14 features, MAE=143.15
#    > Final Count: 14
# Selected features (SA):
#    1. total
#    2. total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa
#    3. total.private.goods.mining_logging.logging_symlog_pct_chg_zscore_3m_lag_3m
#    4. total.private.services.trade_transportation_utilities.wholesale_symlog
#    5. total_symlog_chg_6m_lag_6m
#    6. total_nsa
#    7. total.private.services.financial.real_estate.rental_leasing
#    8. total.private.services.other.personal_symlog_rolling_mean_3m
#    9. total.private.services.trade_transportation_utilities.wholesale.nondurable_symlog_rolling_mean_3m
#   10. total.private.services.leisure_hospitality.accommodation_food.accommodation_symlog_rolling_mean_3m
#   11. total.private.services.information.publishing_nsa
#   12. total.private.goods.manufacturing.durable.nonmetallic_lag_1m
#   13. total.private.goods.mining_logging.mining.except_oil_gas_rolling_std_6m_lag_1m
#   14. total.private.services.trade_transportation_utilities.transportation_warehousing.support_symlog
#
# ============================================================
#   PIPELINE START: NSA_Acc
# ============================================================
# 1. Group-wise Dual Filter (Purged Corr + LightGBM screen + VIF)...
#    [total] 384 -> 21
#    [total.government] 384 -> 14
#    [total.government.federal] 1152 -> 29
#    [total.government.local] 1152 -> 11
#    [total.government.state] 1152 -> 8
#    [total.private] 384 -> 26
#    [total.private.goods] 384 -> 23
#    [total.private.goods.construction] 2304 -> 15
#    [total.private.goods.manufacturing] 10368 -> 23
#    [total.private.goods.mining] 2304 -> 18
#    [total.private.services] 384 -> 29
#    [total.private.services.education] 3072 -> 16
#    [total.private.services.financial] 3840 -> 17
#    [total.private.services.information] 2688 -> 27
#    [total.private.services.leisure] 3072 -> 22
#    [total.private.services.other] 1536 -> 23
#    [total.private.services.professional] 4224 -> 23
#    [total.private.services.trade] 10752 -> 19
#    > Stage 1 Survivors: 364 features
# 2. Boruta Feature Selection (shadow features)...
# Boruta Runs:   0%|          | 0/100 [00:00<?, ?it/s]
#    Boruta: 122 confirmed, 11 tentative (hit rates: min=0/100, max=100/100)
#    > Stage 2 Survivors: 133 features
# 3. Vintage Stability (exponential recency weights, min 2 snapshots)...
#    > Stage 3 Survivors: 118 features
# 4. Cluster Redundancy Check (NaN-aware Spearman)...
#    > Stage 4 Survivors: 50 features
# 5. Interaction Rescue (single-feature + split-pair detection)...
# Phase 1: Single-feature scan:   0%|          | 0/314 [00:00<?, ?it/s]
#    Rescued (single): total.government.local.education_nsa_pct_chg_zscore_3m_lag_1m (delta MAE = 0.0200)
#    Rescued (single): total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa_diff_zscore_12m (delta MAE = 0.0191)
#    Rescued (single): total.private.services_nsa_symlog_diff_zscore_3m_lag_18m (delta MAE = 0.0173)
#    Rescued (single): total.private.goods.manufacturing.durable_nsa_diff_zscore_12m_lag_6m (delta MAE = 0.0167)
#    Rescued (single): total.private.services.leisure_hospitality.arts.amusements_nsa_symlog_diff_zscore_3m_lag_1m (delta MAE = 0.0154)
#    Rescued (single): total.private.services.trade_transportation_utilities.retail.health_personal_nsa_lag_1m (delta MAE = 0.0149)
#    Rescued (single): total.government.local_nsa_diff (delta MAE = 0.0148)
#    Rescued (single): total.private_nsa_symlog_diff_zscore_3m_lag_18m (delta MAE = 0.0143)
#    Rescued (single): total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_diff_zscore_3m (delta MAE = 0.0142)
#    Rescued (single): total.private.services.education_health.health_social.health_care.ambulatory_nsa_symlog_diff_zscore_12m_lag_12m (delta MAE = 0.0132)
#    Rescued (pair w/ total_nsa_diff, co-occur=18): total.private.services.professional_business.admin_waste.admin_support_nsa_diff (delta MAE = 0.0134)
#    Rescued (pair w/ total_nsa_diff, co-occur=10): total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa_diff (delta MAE = 0.0053)
#    Rescued (pair w/ total_nsa_diff, co-occur=6): total.private.goods.construction.buildings_nsa_symlog_zscore_3m (delta MAE = 0.0051)
#    Rescued (pair w/ total.private.services_nsa_symlog_diff_zscore_12m_lag_1m, co-occur=6): total.private.services.financial.finance_insurance_nsa_chg_3m_lag_1m (delta MAE = 0.0014)
#    Rescued (pair w/ total.private.services.financial.finance_insurance_nsa_chg_3m_lag_1m, co-occur=6): total.private.services_nsa_symlog_diff_zscore_12m_lag_1m (delta MAE = 0.0014)
#    Rescued (pair w/ total.private.services.trade_transportation_utilities.wholesale_nsa_diff, co-occur=6): total.private.goods.manufacturing.durable.nonmetallic_nsa_diff (delta MAE = 0.0012)
#    Rescued (pair w/ total_nsa_diff, co-occur=5): total.government.state.education_nsa_symlog_diff_lag_6m (delta MAE = 0.0042)
#    Rescued (pair w/ total_nsa_diff, co-occur=5): total.private.services.professional_business.admin_waste_nsa_diff_zscore_3m_lag_12m (delta MAE = 0.0050)
#    Rescued (pair w/ total_nsa_diff, co-occur=5): total.private.services.other.religious_nsa_diff_zscore_3m_lag_12m (delta MAE = 0.0027)
#    Rescued (pair w/ total.private.services.professional_business.management_companies_nsa_diff, co-occur=5): total.private.services.other.personal_nsa_diff_zscore_12m (delta MAE = 0.0071)
#    Rescued (pair w/ total.private.services.other.personal_nsa_diff_zscore_12m, co-occur=5): total.private.services.professional_business.management_companies_nsa_diff (delta MAE = 0.0071)
#    > Stage 5 Candidates: 71 (50 confirmed + 21 rescued)
# 6. Sequential Forward Selection (walk-forward CV with embargo)...
#    SFS start: total.private.services.trade_transportation_utilities.wholesale_nsa_diff (MAE=756.64)
#    SFS +total_nsa_diff (MAE=320.80, delta=0.5760)
#    SFS +total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_symlog_diff_zscore_12m_lag_6m (MAE=293.06, delta=0.0865)
#    SFS +total.private.services.leisure_hospitality.arts.performing_nsa_symlog_diff_zscore_12m (MAE=277.73, delta=0.0523)
#    SFS +total.government.local_nsa_diff (MAE=267.19, delta=0.0380)
#    SFS +total.private.goods_nsa_diff_zscore_12m (MAE=259.55, delta=0.0286)
#    SFS +total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa_diff_zscore_12m (MAE=255.01, delta=0.0175)
#    SFS +total_nsa_zscore_12m_lag_12m (MAE=250.36, delta=0.0183)
#    SFS +total.private.services.professional_business.admin_waste_nsa_diff_zscore_3m_lag_12m (MAE=247.48, delta=0.0115)
#    SFS +total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_diff_zscore_3m (MAE=244.11, delta=0.0136)
#    SFS +total.private.services.education_health_nsa_diff (MAE=241.96, delta=0.0088)
#    SFS +total.private.services_nsa_zscore_12m_lag_12m (MAE=238.80, delta=0.0131)
#    SFS +total_nsa_rolling_mean_3m_lag_1m (MAE=237.19, delta=0.0067)
#    SFS +total.private.services.other.repair_nsa_diff (MAE=235.78, delta=0.0059)
#    SFS +total.private.services.information.publishing_nsa_diff_zscore_12m_lag_1m (MAE=234.87, delta=0.0039)
#    SFS +total.government_nsa_symlog_pct_chg_lag_12m (MAE=234.54, delta=0.0014)
#    SFS +total.private.services.information.publishing_nsa_diff_zscore_3m (MAE=234.01, delta=0.0022)
#    SFS +total.private_nsa_diff (MAE=232.54, delta=0.0063)
#    SFS +total.government.federal_nsa_diff_zscore_12m (forced, MAE~232.54, below min_features=5)
#    SFS +total.government.federal_nsa_diff_zscore_12m_lag_12m (forced, MAE~232.54, below min_features=5)
#    SFS stop: no improvement for 3 rounds
#    SFS final: 20 features, MAE=232.54
#    > Final Count: 20
# Selected features (NSA_Acc):
#    1. total.private.services.trade_transportation_utilities.wholesale_nsa_diff
#    2. total_nsa_diff
#    3. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_symlog_diff_zscore_12m_lag_6m
#    4. total.private.services.leisure_hospitality.arts.performing_nsa_symlog_diff_zscore_12m
#    5. total.government.local_nsa_diff
#    6. total.private.goods_nsa_diff_zscore_12m
#    7. total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa_diff_zscore_12m
#    8. total_nsa_zscore_12m_lag_12m
#    9. total.private.services.professional_business.admin_waste_nsa_diff_zscore_3m_lag_12m
#   10. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_diff_zscore_3m
#   11. total.private.services.education_health_nsa_diff
#   12. total.private.services_nsa_zscore_12m_lag_12m
#   13. total_nsa_rolling_mean_3m_lag_1m
#   14. total.private.services.other.repair_nsa_diff
#   15. total.private.services.information.publishing_nsa_diff_zscore_12m_lag_1m
#   16. total.government_nsa_symlog_pct_chg_lag_12m
#   17. total.private.services.information.publishing_nsa_diff_zscore_3m
#   18. total.private_nsa_diff
#   19. total.government.federal_nsa_diff_zscore_12m
#   20. total.government.federal_nsa_diff_zscore_12m_lag_12m
#
# ============================================================
#   PIPELINE START: SA_Acc
# ============================================================
# 1. Group-wise Dual Filter (Purged Corr + LightGBM screen + VIF)...
#    [total] 384 -> 19
#    [total.government] 384 -> 15
#    [total.government.federal] 1152 -> 14
#    [total.government.local] 1152 -> 15
#    [total.government.state] 1152 -> 15
#    [total.private] 384 -> 20
#    [total.private.goods] 384 -> 14
#    [total.private.goods.construction] 2304 -> 21
#    [total.private.goods.manufacturing] 10368 -> 15
#    [total.private.goods.mining] 2304 -> 15
#    [total.private.services] 384 -> 25
#    [total.private.services.education] 3072 -> 17
#    [total.private.services.financial] 3840 -> 14
#    [total.private.services.information] 2688 -> 15
#    [total.private.services.leisure] 3072 -> 15
#    [total.private.services.other] 1536 -> 15
#    [total.private.services.professional] 4224 -> 15
#    [total.private.services.trade] 10752 -> 14
#    > Stage 1 Survivors: 293 features
# 2. Boruta Feature Selection (shadow features)...
# Boruta Runs:   0%|          | 0/100 [00:00<?, ?it/s]
#    Boruta: 142 confirmed, 10 tentative (hit rates: min=0/100, max=100/100)
#    > Stage 2 Survivors: 152 features
# 3. Vintage Stability (exponential recency weights, min 2 snapshots)...
#    > Stage 3 Survivors: 144 features
# 4. Cluster Redundancy Check (NaN-aware Spearman)...
#    > Stage 4 Survivors: 50 features
# 5. Interaction Rescue (single-feature + split-pair detection)...
# Phase 1: Single-feature scan:   0%|          | 0/243 [00:00<?, ?it/s]
#    Rescued (single): total.private.goods.manufacturing.durable.transportation_equipment_diff (delta MAE = 0.0101)
#    Rescued (single): total.private.services.information.data_processing_nsa_symlog_diff_zscore_12m (delta MAE = 0.0091)
#    Rescued (single): total.government.state_chg_3m_lag_3m (delta MAE = 0.0080)
#    Rescued (single): total.private.services.leisure_hospitality.accommodation_food.food_services_pct_chg_zscore_3m_lag_1m (delta MAE = 0.0057)
#    Rescued (single): total.private.services_nsa_symlog_pct_chg_zscore_3m_lag_3m (delta MAE = 0.0050)
#    Rescued (single): total.government.local.education_chg_3m_lag_1m (delta MAE = 0.0049)
#    Rescued (single): total.government.local.excluding_education_symlog_pct_chg_zscore_3m_lag_1m (delta MAE = 0.0049)
#    Rescued (single): total.private.services_chg_6m_lag_12m (delta MAE = 0.0048)
#    Rescued (single): total.private.services.professional_business.professional_technical.consulting_nsa_rolling_mean_3m_lag_1m (delta MAE = 0.0048)
#    Rescued (single): total.private.goods.manufacturing.durable.computer_electronic.computer_peripheral_nsa_diff_zscore_3m_lag_3m (delta MAE = 0.0047)
#    Rescued (pair w/ total.government.local.excluding_education_lag_1m, co-occur=2): total.private.services.information.telecommunications_nsa_symlog_pct_chg_lag_6m (delta MAE = 0.0028)
#    Rescued (pair w/ total.private_nsa_symlog_rolling_std_6m_lag_18m, co-occur=2): total.private.services.information.broadcasting_nsa_chg_12m_lag_1m (delta MAE = 0.0002)
#    Rescued (pair w/ total.private.services.information.broadcasting_nsa_chg_12m_lag_1m, co-occur=2): total.private_nsa_symlog_rolling_std_6m_lag_18m (delta MAE = 0.0002)
#    Rescued (pair w/ total.private_nsa_symlog_rolling_std_6m_lag_18m, co-occur=2): total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_symlog_diff_zscore_3m_lag_18m (delta MAE = 0.0031)
#    Rescued (pair w/ total.private_diff, co-occur=1): total.private.goods.construction.buildings_nsa_symlog_zscore_3m_lag_6m (delta MAE = 0.0066)
#    Rescued (pair w/ total.government.local_nsa_chg_12m_lag_18m, co-occur=1): total.private.services.trade_transportation_utilities_symlog_pct_chg_zscore_3m_lag_3m (delta MAE = 0.0023)
#    Rescued (pair w/ total.government.federal.postal_symlog_pct_chg_zscore_3m_lag_6m, co-occur=1): total.private.goods.construction_nsa_pct_chg_rolling_mean_3m_lag_3m (delta MAE = 0.0004)
#    Rescued (pair w/ total.private_nsa_symlog_rolling_std_6m_lag_18m, co-occur=1): total.private.goods.mining_logging.mining.support_nsa_symlog_diff_zscore_3m (delta MAE = 0.0048)
#    Rescued (pair w/ total.government.federal_nsa_pct_chg_zscore_3m_lag_3m, co-occur=1): total.government.federal.postal_nsa_diff_zscore_3m_lag_6m (delta MAE = 0.0023)
#    Rescued (pair w/ total.private_nsa_symlog_rolling_std_6m_lag_18m, co-occur=1): total.private.goods.construction_symlog_diff (delta MAE = 0.0001)
#    > Stage 5 Candidates: 70 (50 confirmed + 20 rescued)
# 6. Sequential Forward Selection (walk-forward CV with embargo)...
#    SFS start: total.private_diff (MAE=192.75)
#    SFS +total.private.goods.construction.specialty_nsa_rolling_std_6m_lag_18m (forced, MAE~192.75, below min_features=5)
#    SFS +total.private.services.professional_business.professional_technical.computer_systems_nsa_diff_zscore_3m_lag_18m (MAE=192.18, delta=0.0029)
#    SFS +total.private.services.other_nsa_symlog_diff_zscore_3m_lag_6m (MAE=190.53, delta=0.0086)
#    SFS +total.private.goods.construction_symlog_diff (MAE=189.03, delta=0.0079)
#    SFS +total_symlog_pct_chg_zscore_12m_lag_12m (MAE=187.90, delta=0.0060)
#    SFS +total.private.services.leisure_hospitality.arts.museums_nsa_diff_zscore_3m_lag_12m (MAE=187.25, delta=0.0035)
#    SFS +total.private.goods.construction.buildings.nonresidential_nsa_rolling_std_6m (MAE=186.51, delta=0.0040)
#    SFS +total.private.goods.mining_logging.mining_pct_chg_zscore_3m_lag_1m (MAE=186.49, delta=0.0001, patience 1/3)
#    SFS +total.private.goods.mining_logging.mining.support_rolling_std_6m_lag_1m (MAE=186.20, delta=0.0016)
#    SFS +total.private.services.other.religious_nsa_pct_chg_zscore_3m (MAE=186.16, delta=0.0002, patience 1/3)
#    SFS +total.private.goods.manufacturing.durable.computer_electronic.computer_peripheral_nsa_diff_zscore_3m_lag_3m (MAE=184.71, delta=0.0078)
#    SFS +total.government.federal.postal_nsa_diff_zscore_3m_lag_6m (MAE=184.64, delta=0.0004, patience 1/3)
#    SFS +total.private.services.professional_business.professional_technical.consulting_nsa_rolling_mean_3m_lag_1m (MAE=183.76, delta=0.0048)
#    SFS +total.private.services.education_health.health_social.health_care.ambulatory_nsa_symlog_rolling_std_6m_lag_18m (forced, MAE~183.76, below min_features=5)
#    SFS +total.private.services.education_health.health_social_nsa_symlog_diff_zscore_3m_lag_12m (forced, MAE~183.76, below min_features=5)
#    SFS stop: no improvement for 3 rounds
#    SFS final: 16 features, MAE=183.76
#    > Final Count: 16
# Selected features (SA_Acc):
#    1. total.private_diff
#    2. total.private.goods.construction.specialty_nsa_rolling_std_6m_lag_18m
#    3. total.private.services.professional_business.professional_technical.computer_systems_nsa_diff_zscore_3m_lag_18m
#    4. total.private.services.other_nsa_symlog_diff_zscore_3m_lag_6m
#    5. total.private.goods.construction_symlog_diff
#    6. total_symlog_pct_chg_zscore_12m_lag_12m
#    7. total.private.services.leisure_hospitality.arts.museums_nsa_diff_zscore_3m_lag_12m
#    8. total.private.goods.construction.buildings.nonresidential_nsa_rolling_std_6m
#    9. total.private.goods.mining_logging.mining_pct_chg_zscore_3m_lag_1m
#   10. total.private.goods.mining_logging.mining.support_rolling_std_6m_lag_1m
#   11. total.private.services.other.religious_nsa_pct_chg_zscore_3m
#   12. total.private.goods.manufacturing.durable.computer_electronic.computer_peripheral_nsa_diff_zscore_3m_lag_3m
#   13. total.government.federal.postal_nsa_diff_zscore_3m_lag_6m
#   14. total.private.services.professional_business.professional_technical.consulting_nsa_rolling_mean_3m_lag_1m
#   15. total.private.services.education_health.health_social.health_care.ambulatory_nsa_symlog_rolling_std_6m_lag_18m
#   16. total.private.services.education_health.health_social_nsa_symlog_diff_zscore_3m_lag_12m
#
# ============================================================
# Merging MoM + Acceleration features (union) and saving...
#
#   NSA: 16 MoM + 20 Acc -> 36 union (0 overlap)
#      1. total.government.federal.except_postal_nsa_symlog_zscore_12m_lag_12m  [MoM]
#      2. total.government.federal_nsa_diff_zscore_12m  [Acc]
#      3. total.government.federal_nsa_diff_zscore_12m_lag_12m  [Acc]
#      4. total.government.local_nsa_diff  [Acc]
#      5. total.government_nsa_symlog_pct_chg_lag_12m  [Acc]
#      6. total.private.goods.manufacturing_nsa_diff_zscore_12m_lag_12m  [MoM]
#      7. total.private.goods_nsa_diff_zscore_12m  [Acc]
#      8. total.private.services.education_health_nsa_diff  [Acc]
#      9. total.private.services.information.publishing_nsa_diff_zscore_12m_lag_1m  [Acc]
#     10. total.private.services.information.publishing_nsa_diff_zscore_3m  [Acc]
#     11. total.private.services.information.publishing_nsa_zscore_12m_lag_12m  [MoM]
#     12. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa  [MoM]
#     13. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_diff_zscore_3m  [Acc]
#     14. total.private.services.leisure_hospitality.accommodation_food.food_services_nsa_symlog_diff_zscore_12m_lag_6m  [Acc]
#     15. total.private.services.leisure_hospitality.arts.performing_nsa_symlog_diff_zscore_12m  [Acc]
#     16. total.private.services.other.religious_nsa_diff_zscore_3m_lag_12m  [MoM]
#     17. total.private.services.other.repair_nsa_diff  [Acc]
#     18. total.private.services.professional_business.admin_waste.admin_support_nsa  [MoM]
#     19. total.private.services.professional_business.admin_waste_nsa_diff_zscore_3m_lag_12m  [Acc]
#     20. total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa_diff_zscore_12m  [Acc]
#     21. total.private.services.trade_transportation_utilities.wholesale.nondurable_nsa_zscore_12m_lag_12m  [MoM]
#     22. total.private.services.trade_transportation_utilities.wholesale_nsa_diff  [Acc]
#     23. total.private.services.trade_transportation_utilities_nsa  [MoM]
#     24. total.private.services_nsa  [MoM]
#     25. total.private.services_nsa_zscore_12m_lag_12m  [Acc]
#     26. total.private_nsa_diff  [Acc]
#     27. total.private_nsa_symlog_diff_zscore_12m_lag_6m  [MoM]
#     28. total_nsa  [MoM]
#     29. total_nsa_chg_3m_lag_12m  [MoM]
#     30. total_nsa_diff  [Acc]
#     31. total_nsa_lag_12m  [MoM]
#     32. total_nsa_lag_6m  [MoM]
#     33. total_nsa_rolling_mean_3m_lag_1m  [Acc]
#     34. total_nsa_symlog_diff  [MoM]
#     35. total_nsa_symlog_diff_zscore_3m_lag_1m  [MoM]
#     36. total_nsa_zscore_12m_lag_12m  [Acc]
#
#   SA: 14 MoM + 16 Acc -> 30 union (0 overlap)
#      1. total  [MoM]
#      2. total.government.federal.postal_nsa_diff_zscore_3m_lag_6m  [Acc]
#      3. total.private.goods.construction.buildings.nonresidential_nsa_rolling_std_6m  [Acc]
#      4. total.private.goods.construction.specialty_nsa_rolling_std_6m_lag_18m  [Acc]
#      5. total.private.goods.construction_symlog_diff  [Acc]
#      6. total.private.goods.manufacturing.durable.computer_electronic.computer_peripheral_nsa_diff_zscore_3m_lag_3m  [Acc]
#      7. total.private.goods.manufacturing.durable.nonmetallic_lag_1m  [MoM]
#      8. total.private.goods.mining_logging.logging_symlog_pct_chg_zscore_3m_lag_3m  [MoM]
#      9. total.private.goods.mining_logging.mining.except_oil_gas_rolling_std_6m_lag_1m  [MoM]
#     10. total.private.goods.mining_logging.mining.support_rolling_std_6m_lag_1m  [Acc]
#     11. total.private.goods.mining_logging.mining_pct_chg_zscore_3m_lag_1m  [Acc]
#     12. total.private.services.education_health.health_social.health_care.ambulatory_nsa_symlog_rolling_std_6m_lag_18m  [Acc]
#     13. total.private.services.education_health.health_social_nsa_symlog_diff_zscore_3m_lag_12m  [Acc]
#     14. total.private.services.financial.real_estate.rental_leasing  [MoM]
#     15. total.private.services.information.publishing_nsa  [MoM]
#     16. total.private.services.leisure_hospitality.accommodation_food.accommodation_symlog_rolling_mean_3m  [MoM]
#     17. total.private.services.leisure_hospitality.arts.museums_nsa_diff_zscore_3m_lag_12m  [Acc]
#     18. total.private.services.other.personal_symlog_rolling_mean_3m  [MoM]
#     19. total.private.services.other.religious_nsa_pct_chg_zscore_3m  [Acc]
#     20. total.private.services.other_nsa_symlog_diff_zscore_3m_lag_6m  [Acc]
#     21. total.private.services.professional_business.professional_technical.computer_systems_nsa_diff_zscore_3m_lag_18m  [Acc]
#     22. total.private.services.professional_business.professional_technical.consulting_nsa_rolling_mean_3m_lag_1m  [Acc]
#     23. total.private.services.trade_transportation_utilities.retail.motor_vehicles_nsa  [MoM]
#     24. total.private.services.trade_transportation_utilities.transportation_warehousing.support_symlog  [MoM]
#     25. total.private.services.trade_transportation_utilities.wholesale.nondurable_symlog_rolling_mean_3m  [MoM]
#     26. total.private.services.trade_transportation_utilities.wholesale_symlog  [MoM]
#     27. total.private_diff  [Acc]
#     28. total_nsa  [MoM]
#     29. total_symlog_chg_6m_lag_6m  [MoM]
#     30. total_symlog_pct_chg_zscore_12m_lag_12m  [Acc]
#   Saved selected_features_fred_employment_nsa.json: 36 features
#   Saved selected_features_fred_employment_sa.json: 30 features
#
# Done.
